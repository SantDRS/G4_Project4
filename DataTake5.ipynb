# %% [markdown]
# # Smart Travel App
# ## Group 4, Project 4
# ### Team: Dominique Villarreal, Enrique Garcia, Jose Santos
# ### Project Due Date: June 12, 2023

# %% [markdown]
# ## Setup Environment

# %%
import json
import pandas as pd
import pprint as pp
import requests
import time

# %% [markdown]
# ## Exploring the Yelp API

# %%
# Confirm Category Alias & Parent Aliases

url = "https://api.yelp.com/v3/categories"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
}

response = requests.get(url, headers=headers)

data = json.loads(response.text)

categories = [(category['alias'], category['parent_aliases']) for category in data['categories']]
categories_sorted = sorted(categories, key=lambda x: (x[1], x[0]))

pp.pprint(categories_sorted)
# Out:
# [('active', []),
#  ('arts', []),
#  ('auto', []),
#  ('beautysvc', []),
#  ('bicycles', []),
#  ('education', []),
#  ('eventservices', []),
#  ('financialservices', []),
#  ('food', []),
#  ('health', []),
#  ('homeservices', []),
#  ('hotelstravel', []),
#  ('localflavor', []),
#  ('localservices', []),
#  ('massmedia', []),
#  ('nightlife', []),
#  ('pets', []),
#  ('professional', []),
#  ('publicservicesgovt', []),
#  ('religiousorgs', []),
#  ('restaurants', []),
#  ('shopping', []),
#  ('airsoft', ['active']),
#  ('amateursportsteams', ['active']),
#  ('amusementparks', ['active']),
#  ('aquariums', ['active']),
#  ('archery', ['active']),
#  ('atvrentals', ['active']),
#  ('axethrowing', ['active']),
#  ('badminton', ['active']),
#  ('baseballfields', ['active']),
#  ('basketballcourts', ['active']),
#  ('bathing_area', ['active']),
#  ('battingcages', ['active']),
#  ('beachequipmentrental', ['active']),
#  ('beaches', ['active']),
#  ('beachvolleyball', ['active']),
#  ('bicyclepaths', ['active']),
#  ('bikeparking', ['active']),
#  ('bikerentals', ['active']),
#  ('boating', ['active']),
#  ('bobsledding', ['active']),
#  ('bocceball', ['active']),
#  ('bowling', ['active']),
#  ('bubblesoccer', ['active']),
#  ('bungeejumping', ['active']),
#  ('canyoneering', ['active']),
#  ('carousels', ['active']),
#  ('challengecourses', ['active']),
#  ('climbing', ['active']),
#  ('cyclingclasses', ['active']),
#  ('dartarenas', ['active']),
#  ('daycamps', ['active']),
#  ('discgolf', ['active']),
#  ('diving', ['active']),
#  ('escapegames', ['active']),
#  ('experiences', ['active']),
#  ('fencing', ['active']),
#  ('fishing', ['active']),
#  ('fitness', ['active']),
#  ('flyboarding', ['active']),
#  ('football', ['active']),
#  ('gliding', ['active']),
#  ('gokarts', ['active']),
#  ('golf', ['active']),
#  ('gun_ranges', ['active']),
#  ('gymnastics', ['active']),
#  ('handball', ['active']),
#  ('hanggliding', ['active']),
#  ('hiking', ['active']),
#  ('horsebackriding', ['active']),
#  ('horseracing', ['active']),
#  ('hot_air_balloons', ['active']),
#  ('indoor_playcenter', ['active']),
#  ('jetskis', ['active']),
#  ('kids_activities', ['active']),
#  ('kiteboarding', ['active']),
#  ('lakes', ['active']),
#  ('lasertag', ['active']),
#  ('lawn_bowling', ['active']),
#  ('leisure_centers', ['active']),
#  ('mini_golf', ['active']),
#  ('mountainbiking', ['active']),
#  ('nudist', ['active']),
#  ('paddleboarding', ['active']),
#  ('paintball', ['active']),
#  ('paragliding', ['active']),
#  ('parasailing', ['active']),
#  ('parks', ['active']),
#  ('pickleball', ['active']),
#  ('playgrounds', ['active']),
#  ('publicplazas', ['active']),
#  ('races', ['active']),
#  ('racingexperience', ['active']),
#  ('rafting', ['active']),
#  ('recreation', ['active']),
#  ('rock_climbing', ['active']),
#  ('sailing', ['active']),
#  ('scavengerhunts', ['active']),
#  ('scooterrentals', ['active']),
#  ('seniorcenters', ['active']),
#  ('skatingrinks', ['active']),
#  ('skiing', ['active']),
#  ('skydiving', ['active']),
#  ('sledding', ['active']),
#  ('snorkeling', ['active']),
#  ('spinclasses', ['active']),
#  ('sport_equipment_hire', ['active']),
#  ('sports_clubs', ['active']),
#  ('squash', ['active']),
#  ('summer_camps', ['active']),
#  ('surfing', ['active']),
#  ('surflifesaving', ['active']),
#  ('swimmingpools', ['active']),
#  ('tennis', ['active']),
#  ('trampoline', ['active']),
#  ('tubing', ['active']),
#  ('volleyball', ['active']),
#  ('waterparks', ['active']),
#  ('wildlifehunting', ['active']),
#  ('zipline', ['active']),
#  ('zoos', ['active']),
#  ('zorbing', ['active']),
#  ('stripclubs', ['adultentertainment']),
#  ('stripteasedancers', ['adultentertainment']),
#  ('senegalese', ['african']),
#  ('southafrican', ['african']),
#  ('airportterminals', ['airports']),
#  ('arabpizza', ['arabian']),
#  ('glassblowing', ['artclasses']),
#  ('arcades', ['arts']),
#  ('bettingcenters', ['arts']),
#  ('bingo', ['arts']),
#  ('cabaret', ['arts']),
#  ('casinos', ['arts']),
#  ('castles', ['arts']),
#  ('choirs', ['arts']),
#  ('countryclubs', ['arts']),
#  ('culturalcenter', ['arts']),
#  ('eatertainment', ['arts']),
#  ('farms', ['arts']),
#  ('festivals', ['arts']),
#  ('gardens', ['arts']),
#  ('hauntedhouses', ['arts']),
#  ('lancenters', ['arts']),
#  ('mahjong', ['arts']),
#  ('makerspaces', ['arts']),
#  ('marchingbands', ['arts']),
#  ('movietheaters', ['arts']),
#  ('museums', ['arts']),
#  ('observatories', ['arts']),
#  ('opera', ['arts']),
#  ('pachinko', ['arts']),
#  ('paintandsip', ['arts']),
#  ('planetarium', ['arts']),
#  ('psychic_astrology', ['arts']),
#  ('racetracks', ['arts']),
#  ('rodeo', ['arts']),
#  ('social_clubs', ['arts']),
#  ('sportsbetting', ['arts']),
#  ('sportsteams', ['arts']),
#  ('stadiumsarenas', ['arts']),
#  ('streetart', ['arts']),
#  ('studiotaping', ['arts']),
#  ('tablaoflamenco', ['arts']),
#  ('theater', ['arts']),
#  ('ticketsales', ['arts']),
#  ('virtualrealitycenters', ['arts']),
#  ('wineries', ['arts', 'food']),
#  ('jazzandblues', ['arts', 'nightlife']),
#  ('musicvenues', ['arts', 'nightlife']),
#  ('galleries', ['arts', 'shopping']),
#  ('artsupplies', ['artsandcrafts']),
#  ('ateliers', ['artsandcrafts']),
#  ('cookingclasses', ['artsandcrafts']),
#  ('costumes', ['artsandcrafts']),
#  ('embroideryandcrochet', ['artsandcrafts']),
#  ('fabricstores', ['artsandcrafts']),
#  ('framing', ['artsandcrafts']),
#  ('paintyourownpottery', ['artsandcrafts']),
#  ('aircraftdealers', ['auto']),
#  ('aircraftrepairs', ['auto']),
#  ('auto_detailing', ['auto']),
#  ('autocustomization', ['auto']),
#  ('autodamageassessment', ['auto']),
#  ('autoelectric', ['auto']),
#  ('autoglass', ['auto']),
#  ('autoloanproviders', ['auto']),
#  ('autopartssupplies', ['auto']),
#  ('autorepair', ['auto']),
#  ('autosecurity', ['auto']),
#  ('autoupholstery', ['auto']),
#  ('aviationservices', ['auto']),
#  ('boatdealers', ['auto']),
#  ('boatpartsandsupplies', ['auto']),
#  ('bodyshops', ['auto']),
#  ('car_dealers', ['auto']),
#  ('carauctions', ['auto']),
#  ('carbrokers', ['auto']),
#  ('carbuyers', ['auto']),
#  ('carshares', ['auto']),
#  ('carwash', ['auto']),
#  ('evchargingstations', ['auto']),
#  ('fueldocks', ['auto']),
#  ('gasstations', ['auto']),
#  ('golfcartdealers', ['auto']),
#  ('hybridcarrepair', ['auto']),
#  ('interlocksystems', ['auto']),
#  ('marinas', ['auto']),
#  ('mobiledentrepair', ['auto']),
#  ('mobilityequipment', ['auto']),
#  ('motodealers', ['auto']),
#  ('motorcycledealers', ['auto']),
#  ('motorcyclerepair', ['auto']),
#  ('motorepairs', ['auto']),
#  ('oilchange', ['auto']),
#  ('parking', ['auto']),
#  ('registrationservices', ['auto']),
#  ('roadsideassist', ['auto']),
#  ('rv_dealers', ['auto']),
#  ('rvrepair', ['auto']),
#  ('service_stations', ['auto']),
#  ('servicestations', ['auto']),
#  ('smog_check_stations', ['auto']),
#  ('stereo_installation', ['auto']),
#  ('tires', ['auto']),
#  ('towing', ['auto']),
#  ('trailerdealers', ['auto']),
#  ('trailerrental', ['auto']),
#  ('trailerrepair', ['auto']),
#  ('transmissionrepair', ['auto']),
#  ('truck_rental', ['auto']),
#  ('truckdealers', ['auto']),
#  ('truckrepair', ['auto']),
#  ('usedcardealers', ['auto']),
#  ('vehicleshipping', ['auto']),
#  ('vehiclewraps', ['auto']),
#  ('wheelrimrepair', ['auto']),
#  ('windshieldinstallrepair', ['auto']),
#  ('carwindowtinting', ['autoglass']),
#  ('motorcyclepartsandsupplies', ['autopartssupplies']),
#  ('diyautoshop', ['autorepair']),
#  ('absinthebars', ['bars']),
#  ('airportlounges', ['bars']),
#  ('beachbars', ['bars']),
#  ('beerbar', ['bars']),
#  ('champagne_bars', ['bars']),
#  ('cigarbars', ['bars']),
#  ('cocktailbars', ['bars']),
#  ('divebars', ['bars']),
#  ('drivethrubars', ['bars']),
#  ('gaybars', ['bars']),
#  ('hookah_bars', ['bars']),
#  ('hotel_bar', ['bars']),
#  ('irish_pubs', ['bars']),
#  ('lounges', ['bars']),
#  ('pubs', ['bars']),
#  ('pulquerias', ['bars']),
#  ('sakebars', ['bars']),
#  ('speakeasies', ['bars']),
#  ('sportsbars', ['bars']),
#  ('tabac', ['bars']),
#  ('tikibars', ['bars']),
#  ('vermouthbars', ['bars']),
#  ('whiskeybars', ['bars']),
#  ('wine_bars', ['bars']),
#  ('acnetreatment', ['beautysvc']),
#  ('barbers', ['beautysvc']),
#  ('eroticmassage', ['beautysvc']),
#  ('eyebrowservices', ['beautysvc']),
#  ('eyelashservice', ['beautysvc']),
#  ('footcare', ['beautysvc']),
#  ('hair', ['beautysvc']),
#  ('hairloss', ['beautysvc']),
#  ('hairremoval', ['beautysvc']),
#  ('hotsprings', ['beautysvc']),
#  ('makeupartists', ['beautysvc']),
#  ('massage', ['beautysvc']),
#  ('othersalons', ['beautysvc']),
#  ('permanentmakeup', ['beautysvc']),
#  ('piercing', ['beautysvc']),
#  ('rolfing', ['beautysvc']),
#  ('skincare', ['beautysvc']),
#  ('spas', ['beautysvc']),
#  ('tanning', ['beautysvc']),
#  ('tattoo', ['beautysvc']),
#  ('teethwhitening', ['beautysvc']),
#  ('hair_extensions', ['beautysvc', 'hair']),
#  ('cosmetics', ['beautysvc', 'shopping']),
#  ('flemish', ['belgian']),
#  ('bikeassociations', ['bicycles']),
#  ('bikerepair', ['bicycles']),
#  ('bikeshop', ['bicycles']),
#  ('specialbikes', ['bicycles']),
#  ('brazilianempanadas', ['brazilian']),
#  ('centralbrazilian', ['brazilian']),
#  ('northeasternbrazilian', ['brazilian']),
#  ('northernbrazilian', ['brazilian']),
#  ('rodizios', ['brazilian']),
#  ('pancakes', ['breakfast_brunch']),
#  ('brewpubs', ['breweries']),
#  ('psychoanalysts', ['c_and_mh']),
#  ('psychologists', ['c_and_mh']),
#  ('psychotherapists', ['c_and_mh']),
#  ('sextherapists', ['c_and_mh']),
#  ('sophrologists', ['c_and_mh']),
#  ('sportspsychologists', ['c_and_mh']),
#  ('themedcafes', ['cafes']),
#  ('cannabistours', ['cannabis_clinics']),
#  ('dominican', ['caribbean']),
#  ('haitian', ['caribbean']),
#  ('puertorican', ['caribbean']),
#  ('trinidadian', ['caribbean']),
#  ('cantonese', ['chinese']),
#  ('congee', ['chinese']),
#  ('dimsum', ['chinese']),
#  ('fuzhou', ['chinese']),
#  ('hainan', ['chinese']),
#  ('hakka', ['chinese']),
#  ('henghwa', ['chinese']),
#  ('hokkien', ['chinese']),
#  ('hunan', ['chinese']),
#  ('pekinese', ['chinese']),
#  ('shanghainese', ['chinese']),
#  ('szechuan', ['chinese']),
#  ('teochew', ['chinese']),
#  ('faithbasedcpc', ['crisispregnancycenters']),
#  ('dentalhygeiniststorefront', ['dentalhygienists']),
#  ('dentalhygienistsmobile', ['dentalhygienists']),
#  ('cosmeticdentists', ['dentists']),
#  ('endodontists', ['dentists']),
#  ('generaldentistry', ['dentists']),
#  ('oralsurgeons', ['dentists']),
#  ('orthodontists', ['dentists']),
#  ('pediatric_dentists', ['dentists']),
#  ('periodontists', ['dentists']),
#  ('diagnosticimaging', ['diagnosticservices']),
#  ('laboratorytesting', ['diagnosticservices']),
#  ('freediving', ['diving']),
#  ('scuba', ['diving']),
#  ('gyudon', ['donburi']),
#  ('oyakodon', ['donburi']),
#  ('adultedu', ['education']),
#  ('artclasses', ['education']),
#  ('collegecounseling', ['education']),
#  ('collegeuniv', ['education']),
#  ('educationservices', ['education']),
#  ('elementaryschools', ['education']),
#  ('highschools', ['education']),
#  ('montessori', ['education']),
#  ('preschools', ['education']),
#  ('privateschools', ['education']),
#  ('privatetutors', ['education']),
#  ('religiousschools', ['education']),
#  ('specialed', ['education']),
#  ('specialtyschools', ['education']),
#  ('tastingclasses', ['education']),
#  ('testprep', ['education']),
#  ('tutoring', ['education']),
#  ('waldorfschools', ['education']),
#  ('willstrustsprobates', ['estateplanning']),
#  ('balloonservices', ['eventservices']),
#  ('bartenders', ['eventservices']),
#  ('boatcharters', ['eventservices']),
#  ('caricatures', ['eventservices']),
#  ('catering', ['eventservices']),
#  ('clowns', ['eventservices']),
#  ('djs', ['eventservices']),
#  ('eventplanning', ['eventservices']),
#  ('facepainting', ['eventservices']),
#  ('floraldesigners', ['eventservices']),
#  ('gametruckrental', ['eventservices']),
#  ('golfcartrentals', ['eventservices']),
#  ('hennaartists', ['eventservices']),
#  ('magicians', ['eventservices']),
#  ('mohels', ['eventservices']),
#  ('musicians', ['eventservices']),
#  ('officiants', ['eventservices']),
#  ('partybikerentals', ['eventservices']),
#  ('partybusrentals', ['eventservices']),
#  ('partycharacters', ['eventservices']),
#  ('partyequipmentrentals', ['eventservices']),
#  ('partysupplies', ['eventservices']),
#  ('personalchefs', ['eventservices']),
#  ('photoboothrentals', ['eventservices']),
#  ('photographers', ['eventservices']),
#  ('silentdisco', ['eventservices']),
#  ('sommelierservices', ['eventservices']),
#  ('teambuilding', ['eventservices']),
#  ('triviahosts', ['eventservices']),
#  ('valetservices', ['eventservices']),
#  ('venues', ['eventservices']),
#  ('videographers', ['eventservices']),
#  ('wedding_planning', ['eventservices']),
#  ('weddingchappels', ['eventservices']),
#  ('stationery', ['eventservices', 'artsandcrafts', 'flowers']),
#  ('hotels', ['eventservices', 'hotelstravel']),
#  ('attractionfarms', ['farms']),
#  ('pickyourown', ['farms']),
#  ('ranches', ['farms']),
#  ('accessories', ['fashion']),
#  ('ceremonialclothing', ['fashion']),
#  ('childcloth', ['fashion']),
#  ('clothingrental', ['fashion']),
#  ('formalwear', ['fashion']),
#  ('furclothing', ['fashion']),
#  ('hats', ['fashion']),
#  ('kimonos', ['fashion']),
#  ('leather', ['fashion']),
#  ('lingerie', ['fashion']),
#  ('maternity', ['fashion']),
#  ('menscloth', ['fashion']),
#  ('plus_size_fashion', ['fashion']),
#  ('shoes', ['fashion']),
#  ('sleepwear', ['fashion']),
#  ('stockings', ['fashion']),
#  ('surfshop', ['fashion']),
#  ('swimwear', ['fashion']),
#  ('tradclothing', ['fashion']),
#  ('vintage', ['fashion']),
#  ('womenscloth', ['fashion']),
#  ('sportswear', ['fashion', 'sportgoods']),
#  ('funfair', ['festivals']),
#  ('generalfestivals', ['festivals']),
#  ('tradefairs', ['festivals']),
#  ('xmasmarkets', ['festivals']),
#  ('banks', ['financialservices']),
#  ('businessfinancing', ['financialservices']),
#  ('currencyexchange', ['financialservices']),
#  ('debtrelief', ['financialservices']),
#  ('financialadvising', ['financialservices']),
#  ('installmentloans', ['financialservices']),
#  ('insurance', ['financialservices']),
#  ('investing', ['financialservices']),
#  ('mortgagelenders', ['financialservices']),
#  ('paydayloans', ['financialservices']),
#  ('taxservices', ['financialservices']),
#  ('titleloans', ['financialservices']),
#  ('aerialfitness', ['fitness']),
#  ('barreclasses', ['fitness']),
#  ('bootcamps', ['fitness']),
#  ('boxing', ['fitness']),
#  ('cardioclasses', ['fitness']),
#  ('dancestudio', ['fitness']),
#  ('emstraining', ['fitness']),
#  ('golflessons', ['fitness']),
#  ('gyms', ['fitness']),
#  ('healthtrainers', ['fitness']),
#  ('martialarts', ['fitness']),
#  ('meditationcenters', ['fitness']),
#  ('pilates', ['fitness']),
#  ('qigong', ['fitness']),
#  ('selfdefenseclasses', ['fitness']),
#  ('taichi', ['fitness']),
#  ('yoga', ['fitness']),
#  ('swimminglessons', ['fitness', 'specialtyschools']),
#  ('florists', ['flowers']),
#  ('flowersonly', ['flowers']),
#  ('giftshops', ['flowers']),
#  ('acaibowls', ['food']),
#  ('backshop', ['food']),
#  ('bagels', ['food']),
#  ('bakeries', ['food']),
#  ('beer_and_wine', ['food']),
#  ('bento', ['food']),
#  ('beverage_stores', ['food']),
#  ('breweries', ['food']),
#  ('bubbletea', ['food']),
#  ('butcher', ['food']),
#  ('cakeshop', ['food']),
#  ('chimneycakes', ['food']),
#  ('churros', ['food']),
#  ('cideries', ['food']),
#  ('coffee', ['food']),
#  ('coffeeroasteries', ['food']),
#  ('coffeeteasupplies', ['food']),
#  ('convenience', ['food']),
#  ('csa', ['food']),
#  ('cupcakes', ['food']),
#  ('customcakes', ['food']),
#  ('delicatessen', ['food']),
#  ('desserts', ['food']),
#  ('distilleries', ['food']),
#  ('diyfood', ['food']),
#  ('donairs', ['food']),
#  ('donuts', ['food']),
#  ('empanadas', ['food']),
#  ('ethicgrocery', ['food']),
#  ('ethnicgrocery', ['food']),
#  ('farmersmarket', ['food']),
#  ('fishmonger', ['food']),
#  ('fooddeliveryservices', ['food']),
#  ('foodtrucks', ['food']),
#  ('friterie', ['food']),
#  ('gelato', ['food']),
#  ('gluhwein', ['food']),
#  ('gourmet', ['food']),
#  ('grocery', ['food']),
#  ('hawkercentre', ['food']),
#  ('honey', ['food']),
#  ('icecream', ['food']),
#  ('importedfood', ['food']),
#  ('internetcafe', ['food']),
#  ('intlgrocery', ['food']),
#  ('jpsweets', ['food']),
#  ('juicebars', ['food']),
#  ('kombucha', ['food']),
#  ('meaderies', ['food']),
#  ('milkshakebars', ['food']),
#  ('nasilemak', ['food']),
#  ('organic_stores', ['food']),
#  ('panzerotti', ['food']),
#  ('piadina', ['food']),
#  ('poke', ['food']),
#  ('pretzels', ['food']),
#  ('salumerie', ['food']),
#  ('shavedice', ['food']),
#  ('shavedsnow', ['food']),
#  ('smokehouse', ['food']),
#  ('streetvendors', ['food']),
#  ('sugarshacks', ['food']),
#  ('tea', ['food']),
#  ('torshi', ['food']),
#  ('tortillas', ['food']),
#  ('waterstores', ['food']),
#  ('zapiekanka', ['food']),
#  ('eltern_cafes', ['food', 'restaurants']),
#  ('kiosk', ['food', 'shopping']),
#  ('alsatian', ['french']),
#  ('auvergnat', ['french']),
#  ('berrichon', ['french']),
#  ('bourguignon', ['french']),
#  ('mauritius', ['french']),
#  ('nicois', ['french']),
#  ('provencal', ['french']),
#  ('reunion', ['french']),
#  ('cremationservices', ['funeralservices']),
#  ('mortuaryservices', ['funeralservices']),
#  ('hydroponics', ['gardening']),
#  ('baden', ['german']),
#  ('easterngerman', ['german']),
#  ('franconian', ['german']),
#  ('hessian', ['german']),
#  ('northerngerman', ['german']),
#  ('palatine', ['german']),
#  ('rhinelandian', ['german']),
#  ('candy', ['gourmet']),
#  ('cheese', ['gourmet']),
#  ('chocolate', ['gourmet']),
#  ('dagashi', ['gourmet']),
#  ('driedfruit', ['gourmet']),
#  ('ethnicmarkets', ['gourmet']),
#  ('frozenfood', ['gourmet']),
#  ('healthmarkets', ['gourmet']),
#  ('herbsandspices', ['gourmet']),
#  ('macarons', ['gourmet']),
#  ('markets', ['gourmet']),
#  ('meats', ['gourmet']),
#  ('oliveoil', ['gourmet']),
#  ('pastashops', ['gourmet']),
#  ('popcorn', ['gourmet']),
#  ('seafoodmarkets', ['gourmet']),
#  ('tofu', ['gourmet']),
#  ('circuittraininggyms', ['gyms']),
#  ('intervaltraininggyms', ['gyms']),
#  ('blowoutservices', ['hair']),
#  ('hairstylists', ['hair']),
#  ('kidshairsalons', ['hair']),
#  ('menshair', ['hair']),
#  ('laser_hair_removal', ['hairremoval']),
#  ('sugaring', ['hairremoval']),
#  ('threadingservices', ['hairremoval']),
#  ('waxing', ['hairremoval']),
#  ('acupuncture', ['health']),
#  ('alternativemedicine', ['health']),
#  ('animalassistedtherapy', ['health']),
#  ('assistedliving', ['health']),
#  ('ayurveda', ['health']),
#  ('behavioranalysts', ['health']),
#  ('blooddonation', ['health']),
#  ('bodycontouring', ['health']),
#  ('c_and_mh', ['health']),
#  ('cannabis_clinics', ['health']),
#  ('cannabiscollective', ['health']),
#  ('cannabisreferrals', ['health']),
#  ('chiropractors', ['health']),
#  ('colonics', ['health']),
#  ('conciergemedicine', ['health']),
#  ('crisispregnancycenters', ['health']),
#  ('cryotherapy', ['health']),
#  ('dentalhygienists', ['health']),
#  ('dentists', ['health']),
#  ('diagnosticservices', ['health']),
#  ('dialysisclinics', ['health']),
#  ('dietitians', ['health']),
#  ('doulas', ['health']),
#  ('emergencyrooms', ['health']),
#  ('floatspa', ['health']),
#  ('habilitativeservices', ['health']),
#  ('halfwayhouses', ['health']),
#  ('halotherapy', ['health']),
#  ('healthcoach', ['health']),
#  ('healthinsurance', ['health']),
#  ('hearing_aids', ['health']),
#  ('hearingaidproviders', ['health']),
#  ('herbalshops', ['health']),
#  ('homehealthcare', ['health']),
#  ('hospice', ['health']),
#  ('hospitals', ['health']),
#  ('hydrotherapy', ['health']),
#  ('hypnosis', ['health']),
#  ('ivhydration', ['health']),
#  ('lactationservices', ['health']),
#  ('laserlasikeyes', ['health']),
#  ('liceservices', ['health']),
#  ('massage_therapy', ['health']),
#  ('medcenters', ['health']),
#  ('medicalfoot', ['health']),
#  ('medicaltransportation', ['health']),
#  ('memorycare', ['health']),
#  ('midwives', ['health']),
#  ('nursepractitioner', ['health']),
#  ('nutritionists', ['health']),
#  ('occupationaltherapy', ['health']),
#  ('optometrists', ['health']),
#  ('organdonorservices', ['health']),
#  ('orthotics', ['health']),
#  ('oxygenbars', ['health']),
#  ('personalcare', ['health']),
#  ('pharmacy', ['health']),
#  ('physicaltherapy', ['health']),
#  ('physicians', ['health']),
#  ('placentaencapsulation', ['health']),
#  ('postpartumcare', ['health']),
#  ('prenatal', ['health']),
#  ('prosthetics', ['health']),
#  ('prosthodontists', ['health']),
#  ('psychotechnicaltests', ['health']),
#  ('reflexology', ['health']),
#  ('rehabilitation_center', ['health']),
#  ('reiki', ['health']),
#  ('reproductivehealthservices', ['health']),
#  ('retirement_homes', ['health']),
#  ('saunas', ['health']),
#  ('skillednursing', ['health']),
#  ('sleepspecialists', ['health']),
#  ('speech_therapists', ['health']),
#  ('spermclinic', ['health']),
#  ('tcm', ['health']),
#  ('ultrasoundimagingcenters', ['health']),
#  ('urgent_care', ['health']),
#  ('weightlosscenters', ['health']),
#  ('medicalspa', ['health', 'beautysvc']),
#  ('appliances', ['homeandgarden']),
#  ('candlestores', ['homeandgarden']),
#  ('christmastrees', ['homeandgarden']),
#  ('furniture', ['homeandgarden']),
#  ('gardening', ['homeandgarden']),
#  ('grillingequipment', ['homeandgarden']),
#  ('hardware', ['homeandgarden']),
#  ('holidaydecorations', ['homeandgarden']),
#  ('homedecor', ['homeandgarden']),
#  ('hottubandpool', ['homeandgarden']),
#  ('kitchenandbath', ['homeandgarden']),
#  ('lightingstores', ['homeandgarden']),
#  ('linens', ['homeandgarden']),
#  ('materialeelettrico', ['homeandgarden']),
#  ('mattresses', ['homeandgarden']),
#  ('outdoorfurniture', ['homeandgarden']),
#  ('paintstores', ['homeandgarden']),
#  ('playsets', ['homeandgarden']),
#  ('pumpkinpatches', ['homeandgarden']),
#  ('rugs', ['homeandgarden']),
#  ('shedsandoutdoorstorage', ['homeandgarden']),
#  ('tableware', ['homeandgarden']),
#  ('artificialturf', ['homeservices']),
#  ('blinds', ['homeservices']),
#  ('buildingsupplies', ['homeservices']),
#  ('cabinetry', ['homeservices']),
#  ('carpenters', ['homeservices']),
#  ('carpeting', ['homeservices']),
#  ('carpetinstallation', ['homeservices']),
#  ('childproofing', ['homeservices']),
#  ('chimneysweeps', ['homeservices']),
#  ('contractors', ['homeservices']),
#  ('countertopinstall', ['homeservices']),
#  ('damagerestoration', ['homeservices']),
#  ('decksrailing', ['homeservices']),
#  ('demolitionservices', ['homeservices']),
#  ('doorsales', ['homeservices']),
#  ('drywall', ['homeservices']),
#  ('electricians', ['homeservices']),
#  ('excavationservices', ['homeservices']),
#  ('fencesgates', ['homeservices']),
#  ('fireplace', ['homeservices']),
#  ('fireprotection', ['homeservices']),
#  ('firewood', ['homeservices']),
#  ('flooring', ['homeservices']),
#  ('foundationrepair', ['homeservices']),
#  ('furnitureassembly', ['homeservices']),
#  ('garage_door_services', ['homeservices']),
#  ('gardeners', ['homeservices']),
#  ('glassandmirrors', ['homeservices']),
#  ('groutservices', ['homeservices']),
#  ('gutterservices', ['homeservices']),
#  ('handyman', ['homeservices']),
#  ('home_inspectors', ['homeservices']),
#  ('home_organization', ['homeservices']),
#  ('homeautomation', ['homeservices']),
#  ('homecleaning', ['homeservices']),
#  ('homeenergyauditors', ['homeservices']),
#  ('homenetworkinstall', ['homeservices']),
#  ('hometheatreinstallation', ['homeservices']),
#  ('homewindowtinting', ['homeservices']),
#  ('housesitters', ['homeservices']),
#  ('hvac', ['homeservices']),
#  ('insulationinstallation', ['homeservices']),
#  ('interiordesign', ['homeservices']),
#  ('irrigation', ['homeservices']),
#  ('landscapearchitects', ['homeservices']),
#  ('landscaping', ['homeservices']),
#  ('lighting', ['homeservices']),
#  ('locksmiths', ['homeservices']),
#  ('masonry_concrete', ['homeservices']),
#  ('mobile_home_repair', ['homeservices']),
#  ('movers', ['homeservices']),
#  ('packingservices', ['homeservices']),
#  ('painters', ['homeservices']),
#  ('patiocoverings', ['homeservices']),
#  ('plumbing', ['homeservices']),
#  ('poolcleaners', ['homeservices']),
#  ('poolservice', ['homeservices']),
#  ('pressurewashers', ['homeservices']),
#  ('realestate', ['homeservices']),
#  ('refinishing', ['homeservices']),
#  ('roofing', ['homeservices']),
#  ('roofinspectors', ['homeservices']),
#  ('saunainstallation', ['homeservices']),
#  ('seasonaldecorservices', ['homeservices']),
#  ('securitysystems', ['homeservices']),
#  ('shutters', ['homeservices']),
#  ('solarinstallation', ['homeservices']),
#  ('solarpanelcleaning', ['homeservices']),
#  ('structuralengineers', ['homeservices']),
#  ('stucco', ['homeservices']),
#  ('televisionserviceproviders', ['homeservices']),
#  ('tiling', ['homeservices']),
#  ('treeservices', ['homeservices']),
#  ('utilities', ['homeservices']),
#  ('vinylsiding', ['homeservices']),
#  ('wallpapering', ['homeservices']),
#  ('waterheaterinstallrepair', ['homeservices']),
#  ('waterproofing', ['homeservices']),
#  ('waterpurification', ['homeservices']),
#  ('windowsinstallation', ['homeservices']),
#  ('windowwashing', ['homeservices']),
#  ('agriturismi', ['hotels']),
#  ('mountainhuts', ['hotels']),
#  ('pensions', ['hotels']),
#  ('residences', ['hotels']),
#  ('reststops', ['hotels']),
#  ('ryokan', ['hotels']),
#  ('airports', ['hotelstravel']),
#  ('bedbreakfast', ['hotelstravel']),
#  ('campgrounds', ['hotelstravel']),
#  ('carrental', ['hotelstravel']),
#  ('guesthouses', ['hotelstravel']),
#  ('healthretreats', ['hotelstravel']),
#  ('hostels', ['hotelstravel']),
#  ('motorcycle_rental', ['hotelstravel']),
#  ('resorts', ['hotelstravel']),
#  ('rvparks', ['hotelstravel']),
#  ('rvrental', ['hotelstravel']),
#  ('skiresorts', ['hotelstravel']),
#  ('tours', ['hotelstravel']),
#  ('trainstations', ['hotelstravel']),
#  ('transport', ['hotelstravel']),
#  ('travelservices', ['hotelstravel']),
#  ('vacation_rentals', ['hotelstravel']),
#  ('vacationrentalagents', ['hotelstravel']),
#  ('autoinsurance', ['insurance']),
#  ('homeinsurance', ['insurance']),
#  ('lifeinsurance', ['insurance']),
#  ('abruzzese', ['italian']),
#  ('altoatesine', ['italian']),
#  ('apulian', ['italian']),
#  ('calabrian', ['italian']),
#  ('cucinacampana', ['italian']),
#  ('emilian', ['italian']),
#  ('friulan', ['italian']),
#  ('ligurian', ['italian']),
#  ('lumbard', ['italian']),
#  ('napoletana', ['italian']),
#  ('piemonte', ['italian']),
#  ('roman', ['italian']),
#  ('sardinian', ['italian']),
#  ('sicilian', ['italian']),
#  ('tuscan', ['italian']),
#  ('venetian', ['italian']),
#  ('datarecovery', ['itservices']),
#  ('mobilephonerepair', ['itservices']),
#  ('telecommunications', ['itservices']),
#  ('blowfish', ['japanese']),
#  ('conveyorsushi', ['japanese']),
#  ('donburi', ['japanese']),
#  ('handrolls', ['japanese']),
#  ('horumon', ['japanese']),
#  ('izakaya', ['japanese']),
#  ('japacurry', ['japanese']),
#  ('kaiseki', ['japanese']),
#  ('kushikatsu', ['japanese']),
#  ('oden', ['japanese']),
#  ('okinawan', ['japanese']),
#  ('okonomiyaki', ['japanese']),
#  ('onigiri', ['japanese']),
#  ('ramen', ['japanese']),
#  ('robatayaki', ['japanese']),
#  ('soba', ['japanese']),
#  ('sukiyaki', ['japanese']),
#  ('takoyaki', ['japanese']),
#  ('tempura', ['japanese']),
#  ('teppanyaki', ['japanese']),
#  ('tonkatsu', ['japanese']),
#  ('udon', ['japanese']),
#  ('unagi', ['japanese']),
#  ('westernjapanese', ['japanese']),
#  ('yakiniku', ['japanese']),
#  ('yakitori', ['japanese']),
#  ('taiyaki', ['jpsweets']),
#  ('dumpsterrental', ['junkremovalandhauling']),
#  ('kitchensupplies', ['kitchenandbath']),
#  ('lawnservices', ['landscaping']),
#  ('colombian', ['latin']),
#  ('salvadoran', ['latin']),
#  ('venezuelan', ['latin']),
#  ('dryclean', ['laundryservices']),
#  ('laundromat', ['laundryservices']),
#  ('bankruptcy', ['lawyers']),
#  ('businesslawyers', ['lawyers']),
#  ('consumerlaw', ['lawyers']),
#  ('contractlaw', ['lawyers']),
#  ('criminaldefense', ['lawyers']),
#  ('disabilitylaw', ['lawyers']),
#  ('divorce', ['lawyers']),
#  ('duilawyers', ['lawyers']),
#  ('elderlaw', ['lawyers']),
#  ('employmentlawyers', ['lawyers']),
#  ('entertainmentlaw', ['lawyers']),
#  ('estateplanning', ['lawyers']),
#  ('general_litigation', ['lawyers']),
#  ('immigrationlawyers', ['lawyers']),
#  ('iplaw', ['lawyers']),
#  ('medicallaw', ['lawyers']),
#  ('personal_injury', ['lawyers']),
#  ('realestatelawyers', ['lawyers']),
#  ('socialsecuritylaw', ['lawyers']),
#  ('taxlaw', ['lawyers']),
#  ('trafficticketinglaw', ['lawyers']),
#  ('workerscomplaw', ['lawyers']),
#  ('courtreporters', ['legalservices']),
#  ('processservers', ['legalservices']),
#  ('parklets', ['localflavor']),
#  ('publicart', ['localflavor']),
#  ('unofficialyelpevents', ['localflavor']),
#  ('yelpevents', ['localflavor']),
#  ('3dprinting', ['localservices']),
#  ('adoptionservices', ['localservices']),
#  ('airductcleaning', ['localservices']),
#  ('appraisalservices', ['localservices']),
#  ('artinstallation', ['localservices']),
#  ('artrestoration', ['localservices']),
#  ('awnings', ['localservices']),
#  ('bailbondsmen', ['localservices']),
#  ('bike_repair_maintenance', ['localservices']),
#  ('biohazardcleanup', ['localservices']),
#  ('bookbinding', ['localservices']),
#  ('busrental', ['localservices']),
#  ('calligraphy', ['localservices']),
#  ('carpet_cleaning', ['localservices']),
#  ('carpetdyeing', ['localservices']),
#  ('childcare', ['localservices']),
#  ('clockrepair', ['localservices']),
#  ('communitybookbox', ['localservices']),
#  ('communitygardens', ['localservices']),
#  ('copyshops', ['localservices']),
#  ('couriers', ['localservices']),
#  ('craneservices', ['localservices']),
#  ('donationcenter', ['localservices']),
#  ('drycleaninglaundry', ['localservices']),
#  ('eldercareplanning', ['localservices']),
#  ('electronicsrepair', ['localservices']),
#  ('elevatorservices', ['localservices']),
#  ('engraving', ['localservices']),
#  ('enviroabatement', ['localservices']),
#  ('environmentaltesting', ['localservices']),
#  ('farmequipmentrepair', ['localservices']),
#  ('fingerprinting', ['localservices']),
#  ('forestry', ['localservices']),
#  ('funeralservices', ['localservices']),
#  ('furniturerepair', ['localservices']),
#  ('generatorinstallrepair', ['localservices']),
#  ('gestorias', ['localservices']),
#  ('grillservices', ['localservices']),
#  ('gunsmith', ['localservices']),
#  ('hazardouswastedisposal', ['localservices']),
#  ('homeappliancerepair', ['localservices']),
#  ('hydrojetting', ['localservices']),
#  ('icedelivery', ['localservices']),
#  ('internetbooth', ['localservices']),
#  ('itservices', ['localservices']),
#  ('jewelryrepair', ['localservices']),
#  ('junkremovalandhauling', ['localservices']),
#  ('junkyards', ['localservices']),
#  ('knifesharpening', ['localservices']),
#  ('laundryservices', ['localservices']),
#  ('machinerental', ['localservices']),
#  ('machineshops', ['localservices']),
#  ('mailboxcenters', ['localservices']),
#  ('metaldetectorservices', ['localservices']),
#  ('metalfabricators', ['localservices']),
#  ('mistingsystemservices', ['localservices']),
#  ('musicinstrumentservices', ['localservices']),
#  ('nannys', ['localservices']),
#  ('nonprofit', ['localservices']),
#  ('notaries', ['localservices']),
#  ('outdoorpowerequipmentservices', ['localservices']),
#  ('pest_control', ['localservices']),
#  ('portabletoiletservices', ['localservices']),
#  ('powdercoating', ['localservices']),
#  ('propane', ['localservices']),
#  ('record_labels', ['localservices']),
#  ('recording_studios', ['localservices']),
#  ('recyclingcenter', ['localservices']),
#  ('rentfurniture', ['localservices']),
#  ('reupholstery', ['localservices']),
#  ('sandblasting', ['localservices']),
#  ('screen_printing_tshirt_printing', ['localservices']),
#  ('screenprinting', ['localservices']),
#  ('selfstorage', ['localservices']),
#  ('septicservices', ['localservices']),
#  ('sewingalterations', ['localservices']),
#  ('shipping_centers', ['localservices']),
#  ('shoerepair', ['localservices']),
#  ('shoeshine', ['localservices']),
#  ('smokingareas', ['localservices']),
#  ('snowremoval', ['localservices']),
#  ('snuggleservices', ['localservices']),
#  ('stonemasons', ['localservices']),
#  ('tvmounting', ['localservices']),
#  ('watch_repair', ['localservices']),
#  ('waterdelivery', ['localservices']),
#  ('welldrilling', ['localservices']),
#  ('wildlifecontrol', ['localservices']),
#  ('youth_club', ['localservices']),
#  ('mamak', ['malaysian']),
#  ('nyonya', ['malaysian']),
#  ('brazilianjiujitsu', ['martialarts']),
#  ('chinesemartialarts', ['martialarts']),
#  ('karate', ['martialarts']),
#  ('kickboxing', ['martialarts']),
#  ('muaythai', ['martialarts']),
#  ('taekwondo', ['martialarts']),
#  ('printmedia', ['massmedia']),
#  ('radiostations', ['massmedia']),
#  ('televisionstations', ['massmedia']),
#  ('bulkbilling', ['medcenters']),
#  ('osteopaths', ['medcenters']),
#  ('walkinclinics', ['medcenters']),
#  ('bookstores', ['media']),
#  ('comicbooks', ['media']),
#  ('mags', ['media']),
#  ('musicvideo', ['media']),
#  ('videoandgames', ['media']),
#  ('videogamestores', ['media']),
#  ('vinyl_records', ['media']),
#  ('aestheticians', ['medicalspa']),
#  ('falafel', ['mediterranean']),
#  ('easternmexican', ['mexican']),
#  ('jaliscan', ['mexican']),
#  ('northernmexican', ['mexican']),
#  ('oaxacan', ['mexican']),
#  ('pueblan', ['mexican']),
#  ('tacos', ['mexican']),
#  ('tamales', ['mexican']),
#  ('yucatan', ['mexican']),
#  ('egyptian', ['mideastern']),
#  ('lebanese', ['mideastern']),
#  ('driveintheater', ['movietheaters']),
#  ('outdoormovies', ['movietheaters']),
#  ('artmuseums', ['museums']),
#  ('childrensmuseums', ['museums']),
#  ('guitarstores', ['musicinstrumentservices']),
#  ('pianoservices', ['musicinstrumentservices']),
#  ('pianostores', ['musicinstrumentservices']),
#  ('vocalcoach', ['musicinstrumentservices']),
#  ('adultentertainment', ['nightlife']),
#  ('barcrawl', ['nightlife']),
#  ('bars', ['nightlife']),
#  ('beergardens', ['nightlife']),
#  ('clubcrawl', ['nightlife']),
#  ('coffeeshops', ['nightlife']),
#  ('comedyclubs', ['nightlife']),
#  ('countrydancehalls', ['nightlife']),
#  ('danceclubs', ['nightlife']),
#  ('dancerestaurants', ['nightlife']),
#  ('fasil', ['nightlife']),
#  ('karaoke', ['nightlife']),
#  ('pianobars', ['nightlife']),
#  ('poolhalls', ['nightlife']),
#  ('foodbanks', ['nonprofit']),
#  ('homelessshelters', ['nonprofit']),
#  ('retinaspecialists', ['opthamalogists']),
#  ('sunglasses', ['opticians']),
#  ('nailtechnicians', ['othersalons']),
#  ('dog_parks', ['parks']),
#  ('skate_parks', ['parks']),
#  ('audiovisualequipmentrental', ['partyequipmentrentals']),
#  ('bouncehouserentals', ['partyequipmentrentals']),
#  ('karaokerental', ['partyequipmentrentals']),
#  ('petboarding', ['pet_sitting']),
#  ('animalshelters', ['pets']),
#  ('horse_boarding', ['pets']),
#  ('petadoption', ['pets']),
#  ('petservices', ['pets']),
#  ('petstore', ['pets']),
#  ('vet', ['pets']),
#  ('animalholistic', ['petservices']),
#  ('animalphysicaltherapy', ['petservices']),
#  ('aquariumservices', ['petservices']),
#  ('dogwalkers', ['petservices']),
#  ('emergencypethospital', ['petservices']),
#  ('farriers', ['petservices']),
#  ('groomer', ['petservices']),
#  ('pet_sitting', ['petservices']),
#  ('pet_training', ['petservices']),
#  ('petbreeders', ['petservices']),
#  ('petcremation', ['petservices']),
#  ('pethospice', ['petservices']),
#  ('petinsurance', ['petservices']),
#  ('petphotography', ['petservices']),
#  ('pettransport', ['petservices']),
#  ('petwasteremoval', ['petservices']),
#  ('birdshops', ['petstore']),
#  ('localfishstores', ['petstore']),
#  ('reptileshops', ['petstore']),
#  ('boudoirphotography', ['photographers']),
#  ('eventphotography', ['photographers']),
#  ('sessionphotography', ['photographers']),
#  ('addictionmedicine', ['physicians']),
#  ('allergist', ['physicians']),
#  ('anesthesiologists', ['physicians']),
#  ('audiologist', ['physicians']),
#  ('cardiology', ['physicians']),
#  ('cosmeticsurgeons', ['physicians']),
#  ('dermatology', ['physicians']),
#  ('earnosethroat', ['physicians']),
#  ('emergencymedicine', ['physicians']),
#  ('endocrinologists', ['physicians']),
#  ('familydr', ['physicians']),
#  ('fertility', ['physicians']),
#  ('gastroenterologist', ['physicians']),
#  ('geneticists', ['physicians']),
#  ('gerontologist', ['physicians']),
#  ('hepatologists', ['physicians']),
#  ('homeopathic', ['physicians']),
#  ('hospitalists', ['physicians']),
#  ('immunodermatologists', ['physicians']),
#  ('infectiousdisease', ['physicians']),
#  ('internalmed', ['physicians']),
#  ('naturopathic', ['physicians']),
#  ('nephrologists', ['physicians']),
#  ('neurologist', ['physicians']),
#  ('neuropathologists', ['physicians']),
#  ('neurotologists', ['physicians']),
#  ('obgyn', ['physicians']),
#  ('oncologist', ['physicians']),
#  ('opthamalogists', ['physicians']),
#  ('orthopedists', ['physicians']),
#  ('osteopathicphysicians', ['physicians']),
#  ('otologists', ['physicians']),
#  ('painmanagement', ['physicians']),
#  ('pathologists', ['physicians']),
#  ('pediatricians', ['physicians']),
#  ('phlebologists', ['physicians']),
#  ('plasticsurgeons', ['physicians']),
#  ('podiatrists', ['physicians']),
#  ('preventivemedicine', ['physicians']),
#  ('proctologist', ['physicians']),
#  ('psychiatrists', ['physicians']),
#  ('pulmonologist', ['physicians']),
#  ('radiologists', ['physicians']),
#  ('rhematologists', ['physicians']),
#  ('spinesurgeons', ['physicians']),
#  ('sportsmed', ['physicians']),
#  ('surgeons', ['physicians']),
#  ('tattooremoval', ['physicians']),
#  ('toxicologists', ['physicians']),
#  ('tropicalmedicine', ['physicians']),
#  ('underseamedicine', ['physicians']),
#  ('urologists', ['physicians']),
#  ('vascularmedicine', ['physicians']),
#  ('backflowservices', ['plumbing']),
#  ('pierogis', ['polish']),
#  ('alentejo', ['portuguese']),
#  ('algarve', ['portuguese']),
#  ('azores', ['portuguese']),
#  ('beira', ['portuguese']),
#  ('fado_houses', ['portuguese']),
#  ('madeira', ['portuguese']),
#  ('minho', ['portuguese']),
#  ('ribatejo', ['portuguese']),
#  ('tras_os_montes', ['portuguese']),
#  ('accountants', ['professional']),
#  ('advertising', ['professional']),
#  ('architects', ['professional']),
#  ('artconsultants', ['professional']),
#  ('billingservices', ['professional']),
#  ('boatrepair', ['professional']),
#  ('bookkeepers', ['professional']),
#  ('businessconsulting', ['professional']),
#  ('careercounseling', ['professional']),
#  ('commissionedartists', ['professional']),
#  ('customsbrokers', ['professional']),
#  ('digitizingservices', ['professional']),
#  ('duplicationservices', ['professional']),
#  ('editorialservices', ['professional']),
#  ('employmentagencies', ['professional']),
#  ('fengshui', ['professional']),
#  ('graphicdesign', ['professional']),
#  ('indoorlandscaping', ['professional']),
#  ('lawyers', ['professional']),
#  ('legalservices', ['professional']),
#  ('lifecoach', ['professional']),
#  ('marketing', ['professional']),
#  ('matchmakers', ['professional']),
#  ('mediators', ['professional']),
#  ('musicproduction', ['professional']),
#  ('officecleaning', ['professional']),
#  ('patentlaw', ['professional']),
#  ('payroll', ['professional']),
#  ('personalassistants', ['professional']),
#  ('privateinvestigation', ['professional']),
#  ('productdesign', ['professional']),
#  ('publicadjusters', ['professional']),
#  ('publicrelations', ['professional']),
#  ('security', ['professional']),
#  ('shredding', ['professional']),
#  ('signmaking', ['professional']),
#  ('softwaredevelopment', ['professional']),
#  ('talentagencies', ['professional']),
#  ('taxidermy', ['professional']),
#  ('tenantlaw', ['professional']),
#  ('translationservices', ['professional']),
#  ('videofilmproductions', ['professional']),
#  ('web_design', ['professional']),
#  ('wholesalers', ['professional']),
#  ('isps', ['professional', 'homeservices']),
#  ('astrologers', ['psychic_astrology']),
#  ('mystics', ['psychic_astrology']),
#  ('psychicmediums', ['psychic_astrology']),
#  ('psychics', ['psychic_astrology']),
#  ('authorized_postal_representative', ['publicservicesgovt']),
#  ('civiccenter', ['publicservicesgovt']),
#  ('communitycenters', ['publicservicesgovt']),
#  ('courthouses', ['publicservicesgovt']),
#  ('departmentsofmotorvehicles', ['publicservicesgovt']),
#  ('embassy', ['publicservicesgovt']),
#  ('firedepartments', ['publicservicesgovt']),
#  ('jailsandprisons', ['publicservicesgovt']),
#  ('landmarks', ['publicservicesgovt']),
#  ('libraries', ['publicservicesgovt']),
#  ('municipality', ['publicservicesgovt']),
#  ('policedepartments', ['publicservicesgovt']),
#  ('postoffices', ['publicservicesgovt']),
#  ('registry_office', ['publicservicesgovt']),
#  ('taxoffice', ['publicservicesgovt']),
#  ('townhall', ['publicservicesgovt']),
#  ('apartments', ['realestate']),
#  ('artspacerentals', ['realestate']),
#  ('commercialrealestate', ['realestate']),
#  ('condominiums', ['realestate']),
#  ('estateliquidation', ['realestate']),
#  ('homedevelopers', ['realestate']),
#  ('homeownerassociation', ['realestate']),
#  ('homestaging', ['realestate']),
#  ('housingcooperatives', ['realestate']),
#  ('kitchenincubators', ['realestate']),
#  ('mobilehomes', ['realestate']),
#  ('mobileparks', ['realestate']),
#  ('mortgagebrokers', ['realestate']),
#  ('propertymgmt', ['realestate']),
#  ('realestateagents', ['realestate']),
#  ('realestatesvcs', ['realestate']),
#  ('sharedofficespaces', ['realestate']),
#  ('university_housing', ['realestate']),
#  ('apartmentagents', ['realestateagents']),
#  ('estatephotography', ['realestatesvcs']),
#  ('landsurveying', ['realestatesvcs']),
#  ('afrobrazilian', ['religiousorgs']),
#  ('buddhist_temples', ['religiousorgs']),
#  ('churches', ['religiousorgs']),
#  ('hindu_temples', ['religiousorgs']),
#  ('mosques', ['religiousorgs']),
#  ('shrines', ['religiousorgs']),
#  ('sikhtemples', ['religiousorgs']),
#  ('spiritism', ['religiousorgs']),
#  ('synagogues', ['religiousorgs']),
#  ('taoisttemples', ['religiousorgs']),
#  ('afghani', ['restaurants']),
#  ('african', ['restaurants']),
#  ('andalusian', ['restaurants']),
#  ('arabian', ['restaurants']),
#  ('argentine', ['restaurants']),
#  ('armenian', ['restaurants']),
#  ('asianfusion', ['restaurants']),
#  ('asturian', ['restaurants']),
#  ('australian', ['restaurants']),
#  ('austrian', ['restaurants']),
#  ('baguettes', ['restaurants']),
#  ('bangladeshi', ['restaurants']),
#  ('basque', ['restaurants']),
#  ('bavarian', ['restaurants']),
#  ('bbq', ['restaurants']),
#  ('beergarden', ['restaurants']),
#  ('beerhall', ['restaurants']),
#  ('beisl', ['restaurants']),
#  ('belgian', ['restaurants']),
#  ('bistros', ['restaurants']),
#  ('blacksea', ['restaurants']),
#  ('brasseries', ['restaurants']),
#  ('brazilian', ['restaurants']),
#  ('breakfast_brunch', ['restaurants']),
#  ('british', ['restaurants']),
#  ('buffets', ['restaurants']),
#  ('bulgarian', ['restaurants']),
#  ('burgers', ['restaurants']),
#  ('burmese', ['restaurants']),
#  ('cafes', ['restaurants']),
#  ('cafeteria', ['restaurants']),
#  ('cajun', ['restaurants']),
#  ('cambodian', ['restaurants']),
#  ('canteen', ['restaurants']),
#  ('caribbean', ['restaurants']),
#  ('catalan', ['restaurants']),
#  ('chech', ['restaurants']),
#  ('cheesesteaks', ['restaurants']),
#  ('chicken_wings', ['restaurants']),
#  ('chickenshop', ['restaurants']),
#  ('chilean', ['restaurants']),
#  ('chinese', ['restaurants']),
#  ('comfortfood', ['restaurants']),
#  ('corsican', ['restaurants']),
#  ('creperies', ['restaurants']),
#  ('cuban', ['restaurants']),
#  ('currysausage', ['restaurants']),
#  ('cypriot', ['restaurants']),
#  ('czech', ['restaurants']),
#  ('czechslovakian', ['restaurants']),
#  ('danish', ['restaurants']),
#  ('delis', ['restaurants']),
#  ('diners', ['restaurants']),
#  ('dinnertheater', ['restaurants']),
#  ('dumplings', ['restaurants']),
#  ('eastern_european', ['restaurants']),
#  ('eritrean', ['restaurants']),
#  ('ethiopian', ['restaurants']),
#  ('filipino', ['restaurants']),
#  ('fischbroetchen', ['restaurants']),
#  ('fishnchips', ['restaurants']),
#  ('flatbread', ['restaurants']),
#  ('fondue', ['restaurants']),
#  ('food_court', ['restaurants']),
#  ('foodstands', ['restaurants']),
#  ('freiduria', ['restaurants']),
#  ('french', ['restaurants']),
#  ('galician', ['restaurants']),
#  ('gamemeat', ['restaurants']),
#  ('gastropubs', ['restaurants']),
#  ('georgian', ['restaurants']),
#  ('german', ['restaurants']),
#  ('giblets', ['restaurants']),
#  ('gluten_free', ['restaurants']),
#  ('greek', ['restaurants']),
#  ('guamanian', ['restaurants']),
#  ('halal', ['restaurants']),
#  ('hawaiian', ['restaurants']),
#  ('heuriger', ['restaurants']),
#  ('himalayan', ['restaurants']),
#  ('hkcafe', ['restaurants']),
#  ('honduran', ['restaurants']),
#  ('hotdog', ['restaurants']),
#  ('hotdogs', ['restaurants']),
#  ('hotpot', ['restaurants']),
#  ('hungarian', ['restaurants']),
#  ('iberian', ['restaurants']),
#  ('indonesian', ['restaurants']),
#  ('indpak', ['restaurants']),
#  ('international', ['restaurants']),
#  ('irish', ['restaurants']),
#  ('island_pub', ['restaurants']),
#  ('israeli', ['restaurants']),
#  ('italian', ['restaurants']),
#  ('japanese', ['restaurants']),
#  ('jewish', ['restaurants']),
#  ('kebab', ['restaurants']),
#  ('kopitiam', ['restaurants']),
#  ('korean', ['restaurants']),
#  ('kosher', ['restaurants']),
#  ('kurdish', ['restaurants']),
#  ('laos', ['restaurants']),
#  ('laotian', ['restaurants']),
#  ('latin', ['restaurants']),
#  ('lyonnais', ['restaurants']),
#  ('malaysian', ['restaurants']),
#  ('meatballs', ['restaurants']),
#  ('mediterranean', ['restaurants']),
#  ('mexican', ['restaurants']),
#  ('mideastern', ['restaurants']),
#  ('milkbars', ['restaurants']),
#  ('modern_australian', ['restaurants']),
#  ('modern_european', ['restaurants']),
#  ('mongolian', ['restaurants']),
#  ('moroccan', ['restaurants']),
#  ('newamerican', ['restaurants']),
#  ('newcanadian', ['restaurants']),
#  ('newmexican', ['restaurants']),
#  ('newzealand', ['restaurants']),
#  ('nicaraguan', ['restaurants']),
#  ('nightfood', ['restaurants']),
#  ('nikkei', ['restaurants']),
#  ('noodles', ['restaurants']),
#  ('norcinerie', ['restaurants']),
#  ('norwegian', ['restaurants']),
#  ('opensandwiches', ['restaurants']),
#  ('oriental', ['restaurants']),
#  ('pakistani', ['restaurants']),
#  ('panasian', ['restaurants']),
#  ('parma', ['restaurants']),
#  ('persian', ['restaurants']),
#  ('peruvian', ['restaurants']),
#  ('pfcomercial', ['restaurants']),
#  ('pita', ['restaurants']),
#  ('pizza', ['restaurants']),
#  ('polish', ['restaurants']),
#  ('polynesian', ['restaurants']),
#  ('popuprestaurants', ['restaurants']),
#  ('portuguese', ['restaurants']),
#  ('potatoes', ['restaurants']),
#  ('poutineries', ['restaurants']),
#  ('pubfood', ['restaurants']),
#  ('raw_food', ['restaurants']),
#  ('riceshop', ['restaurants']),
#  ('romanian', ['restaurants']),
#  ('rotisserie_chicken', ['restaurants']),
#  ('rumanian', ['restaurants']),
#  ('russian', ['restaurants']),
#  ('salad', ['restaurants']),
#  ('sandwiches', ['restaurants']),
#  ('scandinavian', ['restaurants']),
#  ('schnitzel', ['restaurants']),
#  ('scottish', ['restaurants']),
#  ('seafood', ['restaurants']),
#  ('serbocroatian', ['restaurants']),
#  ('signature_cuisine', ['restaurants']),
#  ('singaporean', ['restaurants']),
#  ('slovakian', ['restaurants']),
#  ('somali', ['restaurants']),
#  ('soulfood', ['restaurants']),
#  ('soup', ['restaurants']),
#  ('southern', ['restaurants']),
#  ('spanish', ['restaurants']),
#  ('srilankan', ['restaurants']),
#  ('steak', ['restaurants']),
#  ('sud_ouest', ['restaurants']),
#  ('supperclubs', ['restaurants']),
#  ('sushi', ['restaurants']),
#  ('swabian', ['restaurants']),
#  ('swedish', ['restaurants']),
#  ('swissfood', ['restaurants']),
#  ('syrian', ['restaurants']),
#  ('tabernas', ['restaurants']),
#  ('taiwanese', ['restaurants']),
#  ('tapas', ['restaurants']),
#  ('tapasmallplates', ['restaurants']),
#  ('tavolacalda', ['restaurants']),
#  ('tex-mex', ['restaurants']),
#  ('thai', ['restaurants']),
#  ('tradamerican', ['restaurants']),
#  ('traditional_swedish', ['restaurants']),
#  ('trattorie', ['restaurants']),
#  ('turkish', ['restaurants']),
#  ('ukrainian', ['restaurants']),
#  ('uzbek', ['restaurants']),
#  ('vegan', ['restaurants']),
#  ('vegetarian', ['restaurants']),
#  ('venison', ['restaurants']),
#  ('vietnamese', ['restaurants']),
#  ('waffles', ['restaurants']),
#  ('wok', ['restaurants']),
#  ('wraps', ['restaurants']),
#  ('yugoslav', ['restaurants']),
#  ('adult', ['shopping']),
#  ('antiques', ['shopping']),
#  ('artsandcrafts', ['shopping']),
#  ('auctionhouses', ['shopping']),
#  ('baby_gear', ['shopping']),
#  ('batterystores', ['shopping']),
#  ('bespoke', ['shopping']),
#  ('brewingsupplies', ['shopping']),
#  ('bridal', ['shopping']),
#  ('cannabisdispensaries', ['shopping']),
#  ('cellphoneaccessories', ['shopping']),
#  ('chinesebazaar', ['shopping']),
#  ('computers', ['shopping']),
#  ('concept_shops', ['shopping']),
#  ('custommerchandise', ['shopping']),
#  ('diamondbuyers', ['shopping']),
#  ('discountstore', ['shopping']),
#  ('drones', ['shopping']),
#  ('drugstores', ['shopping']),
#  ('dutyfreeshops', ['shopping']),
#  ('electronics', ['shopping']),
#  ('farmingequipment', ['shopping']),
#  ('fashion', ['shopping']),
#  ('fireworks', ['shopping']),
#  ('fitnessequipment', ['shopping']),
#  ('fleamarkets', ['shopping']),
#  ('flowers', ['shopping']),
#  ('gemstonesandminerals', ['shopping']),
#  ('goldbuyers', ['shopping']),
#  ('golfshops', ['shopping']),
#  ('guns_and_ammo', ['shopping']),
#  ('headshops', ['shopping']),
#  ('hifi', ['shopping']),
#  ('hobbyshops', ['shopping']),
#  ('homeandgarden', ['shopping']),
#  ('horsequipment', ['shopping']),
#  ('jewelry', ['shopping']),
#  ('knittingsupplies', ['shopping']),
#  ('livestocksupply', ['shopping']),
#  ('luggage', ['shopping']),
#  ('marketstalls', ['shopping']),
#  ('media', ['shopping']),
#  ('medicalsupplies', ['shopping']),
#  ('militarysurplus', ['shopping']),
#  ('mobilephones', ['shopping']),
#  ('motorcyclinggear', ['shopping']),
#  ('musicalinstrumentsandteachers', ['shopping']),
#  ('officeequipment', ['shopping']),
#  ('opticians', ['shopping']),
#  ('outlet_stores', ['shopping']),
#  ('packingsupplies', ['shopping']),
#  ('pawn', ['shopping']),
#  ('personal_shopping', ['shopping']),
#  ('photographystores', ['shopping']),
#  ('poolbilliards', ['shopping']),
#  ('popupshops', ['shopping']),
#  ('props', ['shopping']),
#  ('publicmarkets', ['shopping']),
#  ('religiousitems', ['shopping']),
#  ('safestores', ['shopping']),
#  ('safetyequipment', ['shopping']),
#  ('scandinaviandesign', ['shopping']),
#  ('shoppingcenters', ['shopping']),
#  ('shoppingpassages', ['shopping']),
#  ('souvenirs', ['shopping']),
#  ('spiritual_shop', ['shopping']),
#  ('sportgoods', ['shopping']),
#  ('tabletopgames', ['shopping']),
#  ('teachersupplies', ['shopping']),
#  ('thrift_stores', ['shopping']),
#  ('tickets', ['shopping']),
#  ('tobaccoshops', ['shopping']),
#  ('toys', ['shopping']),
#  ('trophyshops', ['shopping']),
#  ('uniforms', ['shopping']),
#  ('usedbooks', ['shopping']),
#  ('vapeshops', ['shopping']),
#  ('vitaminssupplements', ['shopping']),
#  ('watches', ['shopping']),
#  ('wholesale_stores', ['shopping']),
#  ('wigs', ['shopping']),
#  ('perfume', ['shopping', 'beautysvc']),
#  ('deptstores', ['shopping', 'fashion']),
#  ('estheticians', ['skincare']),
#  ('veteransorganizations', ['social_clubs']),
#  ('arroceria_paella', ['spanish']),
#  ('artschools', ['specialtyschools']),
#  ('bartendingschools', ['specialtyschools']),
#  ('cheerleading', ['specialtyschools']),
#  ('childbirthedu', ['specialtyschools']),
#  ('circusschools', ['specialtyschools']),
#  ('cookingschools', ['specialtyschools']),
#  ('cosmetology_schools', ['specialtyschools']),
#  ('cprclasses', ['specialtyschools']),
#  ('dance_schools', ['specialtyschools']),
#  ('dramaschools', ['specialtyschools']),
#  ('driving_schools', ['specialtyschools']),
#  ('duischools', ['specialtyschools']),
#  ('firearmtraining', ['specialtyschools']),
#  ('firstaidclasses', ['specialtyschools']),
#  ('flightinstruction', ['specialtyschools']),
#  ('foodsafety', ['specialtyschools']),
#  ('language_schools', ['specialtyschools']),
#  ('massage_schools', ['specialtyschools']),
#  ('nursingschools', ['specialtyschools']),
#  ('parentingclasses', ['specialtyschools']),
#  ('photoclasses', ['specialtyschools']),
#  ('poledancingclasses', ['specialtyschools']),
#  ('sambaschools', ['specialtyschools']),
#  ('skischools', ['specialtyschools']),
#  ('speechtraining', ['specialtyschools']),
#  ('surfschools', ['specialtyschools']),
#  ('trafficschools', ['specialtyschools']),
#  ('vocation', ['specialtyschools']),
#  ('bikes', ['sportgoods']),
#  ('diveshops', ['sportgoods']),
#  ('golfequipment', ['sportgoods']),
#  ('hockeyequipment', ['sportgoods']),
#  ('huntingfishingsupplies', ['sportgoods']),
#  ('outdoorgear', ['sportgoods']),
#  ('skateshops', ['sportgoods']),
#  ('skishops', ['sportgoods']),
#  ('dancewear', ['sportswear']),
#  ('spraytanning', ['tanning']),
#  ('tanningbeds', ['tanning']),
#  ('cheesetastingclasses', ['tastingclasses']),
#  ('winetasteclasses', ['tastingclasses']),
#  ('tuina', ['tcm']),
#  ('aerialtours', ['tours']),
#  ('architecturaltours', ['tours']),
#  ('arttours', ['tours']),
#  ('beertours', ['tours']),
#  ('biketours', ['tours']),
#  ('boattours', ['tours']),
#  ('bustours', ['tours']),
#  ('foodtours', ['tours']),
#  ('historicaltours', ['tours']),
#  ('scootertours', ['tours']),
#  ('walkingtours', ['tours']),
#  ('whalewatchingtours', ['tours']),
#  ('winetours', ['tours']),
#  ('airlines', ['transport']),
#  ('airport_shuttles', ['transport']),
#  ('bikesharing', ['transport']),
#  ('buses', ['transport']),
#  ('busstations', ['transport']),
#  ('cablecars', ['transport']),
#  ('dolmusstation', ['transport']),
#  ('ferries', ['transport']),
#  ('limos', ['transport']),
#  ('metrostations', ['transport']),
#  ('pedicabs', ['transport']),
#  ('privatejetcharter', ['transport']),
#  ('publictransport', ['transport']),
#  ('sharedtaxis', ['transport']),
#  ('taxis', ['transport']),
#  ('towncarservice', ['transport']),
#  ('trains', ['transport']),
#  ('watertaxis', ['transport']),
#  ('luggagestorage', ['travelservices']),
#  ('passportvisaservices', ['travelservices']),
#  ('travelagents', ['travelservices']),
#  ('visitorcenters', ['travelservices']),
#  ('cheekufta', ['turkish']),
#  ('gozleme', ['turkish']),
#  ('homemadefood', ['turkish']),
#  ('lahmacun', ['turkish']),
#  ('ottomancuisine', ['turkish']),
#  ('turkishravioli', ['turkish']),
#  ('electricitysuppliers', ['utilities']),
#  ('naturalgassuppliers', ['utilities']),
#  ('watersuppliers', ['utilities']),
#  ('suppliesrestaurant', ['wholesalers']),
#  ('winetastingroom', ['wineries']),
#  ('pettingzoos', ['zoos'])]

# %% [markdown]
# #### Parent aliases we may want:
# 'parent_aliases': active, arts, bars, breweries, festivals, fitness, food, museums, nightlife, restaurants, tours, wineries, zoos

# %%
# Confirm Category Parent Aliases sorted and unique values only
import requests
import json

url = "https://api.yelp.com/v3/categories"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
}

response = requests.get(url, headers=headers)

data = json.loads(response.text)

categories = [category['parent_aliases'] for category in data['categories']]
categories_unique_sorted = sorted(set(sum(categories, [])))

for category in categories_unique_sorted:
    print(category)
# Out:
# active
# adultentertainment
# african
# airports
# arabian
# artclasses
# arts
# artsandcrafts
# auto
# autoglass
# autopartssupplies
# autorepair
# bars
# beautysvc
# belgian
# bicycles
# brazilian
# breakfast_brunch
# breweries
# c_and_mh
# cafes
# cannabis_clinics
# caribbean
# chinese
# crisispregnancycenters
# dentalhygienists
# dentists
# diagnosticservices
# diving
# donburi
# education
# estateplanning
# eventservices
# farms
# fashion
# festivals
# financialservices
# fitness
# flowers
# food
# french
# funeralservices
# gardening
# german
# gourmet
# gyms
# hair
# hairremoval
# health
# homeandgarden
# homeservices
# hotels
# hotelstravel
# insurance
# italian
# itservices
# japanese
# jpsweets
# junkremovalandhauling
# kitchenandbath
# landscaping
# latin
# laundryservices
# lawyers
# legalservices
# localflavor
# localservices
# malaysian
# martialarts
# massmedia
# medcenters
# media
# medicalspa
# mediterranean
# mexican
# mideastern
# movietheaters
# museums
# musicinstrumentservices
# nightlife
# nonprofit
# opthamalogists
# opticians
# othersalons
# parks
# partyequipmentrentals
# pet_sitting
# pets
# petservices
# petstore
# photographers
# physicians
# plumbing
# polish
# portuguese
# professional
# psychic_astrology
# publicservicesgovt
# realestate
# realestateagents
# realestatesvcs
# religiousorgs
# restaurants
# shopping
# skincare
# social_clubs
# spanish
# specialtyschools
# sportgoods
# sportswear
# tanning
# tastingclasses
# tcm
# tours
# transport
# travelservices
# turkish
# utilities
# wholesalers
# wineries
# zoos

# %% [markdown]
# ### Active Data Pulls

# %% [markdown]
# ## Denver

# %%
# Active - Data Pull for Denver Active Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=active&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "bearer VLnY10dNyAE5dLbob1YXoLTY4nygV3DWCCZJuk8mDuVI-zTME9om5QjffXfelKG1LqkLeUMt-N6vsp2vtWde_CLYvP28lkWBPjUsvCtbB38cy762UuInOPWvnEh5ZHYx"
        }
        response = requests.get(url, headers=headers)
        denver_active_data = response.json()
        
        with open('Denver_active_response.json', 'a') as json_file:
            json.dump(denver_active_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_active_data)

# %%
# Arts - Data Pull for Denver Arts Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)        
        denver_art_data = response.json()
        
        with open('Denver_art_response.json', 'a') as json_file:
            json.dump(denver_art_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_active_data)

# %%
# Bars - Data Pull for Denver Bars Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=bars&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)    
        denver_bars_data = response.json()
        
        with open('Denver_bars_response.json', 'a') as json_file:
            json.dump(denver_bars_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_bars_data)

# %%
# Breweries - Data Pull for Denver Breweries Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=breweries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        denver_breweries_data = response.json()
        
        with open('Denver_brewiers_response.json', 'a') as json_file:
            json.dump(denver_brewiers_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_brewiers_data)

# %%
# Festivals - Data Pull for Denver Festivals Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=festivals&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        denver_festivals_data = response.json()
        
        with open('Denver_festivals_response.json', 'a') as json_file:
            json.dump(denver_festivals_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_festivals_data)

# %%
# Fitness - Data Pull for Denver Fitness Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=fitness&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        denver_fitness_data = response.json()
        
        with open('Denver_festivals_response.json', 'a') as json_file:
            json.dump(denver_fitness_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_fitness_data)

# %%
# Food - Data Pull for Denver Food Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=food&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        denver_food_data = response.json()
        
        with open('Denver_food_response.json', 'a') as json_file:
            json.dump(denver_food_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_food_data)

# %%
# Museums - Data Pull for Denver Museums Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=museums&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        denver_museums_data = response.json()
        
        with open('Denver_museums_response.json', 'a') as json_file:
            json.dump(denver_museums_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_museums_data)

# %%
# Nightlife - Data Pull for Denver Nightlife Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=nightlife&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        denver_nightlife_data = response.json()
        
        with open('Denver_nightlife_response.json', 'a') as json_file:
            json.dump(denver_nightlife_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_nightlife_data)

# %%
# Restaurants - Data Pull for Denver Restaurants: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):    
        import requests

        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=restaurants&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        denver_restaurants_data = response.json()
        
        with open('Denver_restaurants_response.json', 'a') as json_file:
            json.dump(denver_restaurants_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_restaurants_data)

# %%
# Tours - Data Pull for Denver Tours Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=tours&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        denver_tours_data = response.json()
        
        with open('Denver_tours_response.json', 'a') as json_file:
            json.dump(denver_tours_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_tours_data)

# %%
# Wineries - Data Pull for Denver Wineries Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=wineries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        denver_wineries_data = response.json()
        
        with open('Denver_wineries_response.json', 'a') as json_file:
            json.dump(denver_wineries_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_wineries_data)
# Out:
# {'businesses': [], 'total': 24, 'region': {'center': {'longitude': -104.97024536132812, 'latitude': 39.73552421220229}}}

# %%
# Zoos - Data Pull for Denver Zoos Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=zoos&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        denver_zoos_data = response.json()
        
        with open('Denver_zoos_response.json', 'a') as json_file:
            json.dump(denver_zoos_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(denver_zoos_data)
# Out:
# {'businesses': [], 'total': 5, 'region': {'center': {'longitude': -104.97024536132812, 'latitude': 39.73552421220229}}}

# %% [markdown]
# #### (End of Denver Pulls)

# %% [markdown]
# ## Miami

# %%
# Active - Data Pull for Miami Active Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=active&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_active_data = response.json()
        
        with open('Miami_active_response.json', 'a') as json_file:
            json.dump(miami_active_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_active_data)
# Out:
# {'businesses': [{'id': 'tNDK642trJ-fIRystFStyw', 'alias': 'ymca-of-south-broward-county-hollywood', 'name': 'YMCA of South Broward County', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/857UZ_ty385LbB3GwdvBZA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/ymca-of-south-broward-county-hollywood?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 9, 'categories': [{'alias': 'gyms', 'title': 'Gyms'}], 'rating': 3.0, 'coordinates': {'latitude': 26.026335, 'longitude': -80.171501}, 'transactions': [], 'location': {'address1': '3161 Taft St', 'address2': '', 'address3': '', 'city': 'Hollywood', 'zip_code': '33021', 'country': 'US', 'state': 'FL', 'display_address': ['3161 Taft St', 'Hollywood, FL 33021']}, 'phone': '+19549899622', 'display_phone': '(954) 989-9622', 'distance': 32584.42395425666}, {'id': 'bHP9qKlfBU7th_pDBqxL7A', 'alias': 'youfit-gyms-miami-14', 'name': 'YouFit Gyms', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_S-Jn4QzSCTIv9lXAYZ0yA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/youfit-gyms-miami-14?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 27, 'categories': [{'alias': 'gyms', 'title': 'Gyms'}, {'alias': 'healthtrainers', 'title': 'Trainers'}], 'rating': 3.0, 'coordinates': {'latitude': 25.73303, 'longitude': -80.3761}, 'transactions': [], 'location': {'address1': '3900 SW 112th Ave', 'address2': '', 'address3': '', 'city': 'Miami', 'zip_code': '33165', 'country': 'US', 'state': 'FL', 'display_address': ['3900 SW 112th Ave', 'Miami, FL 33165']}, 'phone': '+17868797434', 'display_phone': '(786) 879-7434', 'distance': 9084.119993022312}, {'id': 'E-StdbXFFrJHsQHL_1QhQA', 'alias': 'jet-ski-tours-of-miami-miami-beach', 'name': 'Jet ski Tours of Miami', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PlcmqC7Avt7sSK4c8xiBBA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/jet-ski-tours-of-miami-miami-beach?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 60, 'categories': [{'alias': 'jetskis', 'title': 'Jet Skis'}], 'rating': 3.0, 'coordinates': {'latitude': 25.775463, 'longitude': -80.1419}, 'transactions': [], 'location': {'address1': '520 West Ave', 'address2': '', 'address3': '', 'city': 'Miami beach', 'zip_code': '33133', 'country': 'US', 'state': 'FL', 'display_address': ['520 West Ave', 'Miami beach, FL 33133']}, 'phone': '+13055387547', 'display_phone': '(305) 538-7547', 'distance': 14855.403054587678}, {'id': 'PJsTNnil31QyxBGLtbeFYg', 'alias': 'pirates-adventures-miami-2', 'name': 'Pirates Adventures', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m5qbOeaepSMR-BMzr3vM1Q/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/pirates-adventures-miami-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 17, 'categories': [{'alias': 'boatcharters', 'title': 'Boat Charters'}, {'alias': 'boating', 'title': 'Boating'}], 'rating': 3.0, 'coordinates': {'latitude': 25.77909333, 'longitude': -80.18682333}, 'transactions': [], 'location': {'address1': '401 Biscayne Blvd', 'address2': '', 'address3': '', 'city': 'Miami', 'zip_code': '33132', 'country': 'US', 'state': 'FL', 'display_address': ['401 Biscayne Blvd', 'Miami, FL 33132']}, 'phone': '+13053587612', 'display_phone': '(305) 358-7612', 'distance': 10419.849654760641}, {'id': 'HeOthT25QvTNyJSXPgFTlg', 'alias': 'party-miami-boat-miami', 'name': 'Party Miami Boat', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NWLr8V1TXdEv7aXp1FtS8w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/party-miami-boat-miami?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=a ...

# %%
# Arts - Data Pull for Miami Arts Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_arts_data = response.json()
        
        with open('Miami_arts_response.json', 'a') as json_file:
            json.dump(miami_arts_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_arts_data)
# Out:
# {'businesses': [], 'total': 398, 'region': {'center': {'longitude': -80.2880859375, 'latitude': 25.752753731496888}}}

# %%
# Bars - Data Pull for Miami Bars Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=bars&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_bars_data = response.json()
        
        with open('Miami_bars_response.json', 'a') as json_file:
            json.dump(miami_bars_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_bars_data)
# Out:
# {'businesses': [{'id': 'FrN193wV84ld1929V_3srg', 'alias': 'mad-butcher-miami-miami', 'name': 'Mad Butcher - Miami', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Vh_LAhS6UiYKrmbSGZ8gUQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/mad-butcher-miami-miami?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 23, 'categories': [{'alias': 'bars', 'title': 'Bars'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}, {'alias': 'bbq', 'title': 'Barbeque'}], 'rating': 2.5, 'coordinates': {'latitude': 25.79962205251595, 'longitude': -80.19921066708127}, 'transactions': [], 'location': {'address1': '2300 NW 2nd Ave', 'address2': '', 'address3': None, 'city': 'Miami', 'zip_code': '33127', 'country': 'US', 'state': 'FL', 'display_address': ['2300 NW 2nd Ave', 'Miami, FL 33127']}, 'phone': '+17863911191', 'display_phone': '(786) 391-1191', 'distance': 10312.85051426592}, {'id': 'gx5nYVRLPUvAkkDr5AkjqA', 'alias': 'divino-pecado-and-santo-bocado-doral-4', 'name': 'Divino Pecado & Santo Bocado', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Sa5pXZmiUVCHbZdoOymKBA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/divino-pecado-and-santo-bocado-doral-4?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 5, 'categories': [{'alias': 'danceclubs', 'title': 'Dance Clubs'}, {'alias': 'lounges', 'title': 'Lounges'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}], 'rating': 2.5, 'coordinates': {'latitude': 25.79663, 'longitude': -80.36975}, 'transactions': ['delivery'], 'location': {'address1': '10730 NW 25th St', 'address2': None, 'address3': '', 'city': 'Doral', 'zip_code': '33172', 'country': 'US', 'state': 'FL', 'display_address': ['10730 NW 25th St', 'Doral, FL 33172']}, 'phone': '+17864094699', 'display_phone': '(786) 409-4699', 'distance': 9526.543442978538}, {'id': 'NZKSkdDQxwUglws0K5pmfw', 'alias': 'mojitobar-miami', 'name': 'Mojitobar', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/F6xYNsg8WrrHPJAcIe1vUA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/mojitobar-miami?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 185, 'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'tacos', 'title': 'Tacos'}], 'rating': 2.5, 'coordinates': {'latitude': 25.778385906986365, 'longitude': -80.18643291165961}, 'transactions': [], 'price': '$$', 'location': {'address1': '401 Biscayne Blvd', 'address2': None, 'address3': '', 'city': 'Miami', 'zip_code': '33132', 'country': 'US', 'state': 'FL', 'display_address': ['401 Biscayne Blvd', 'Miami, FL 33132']}, 'phone': '+13057056130', 'display_phone': '(305) 705-6130', 'distance': 10570.997900345717}, {'id': '-yiftcvy2at7FglLtQyCkg', 'alias': 'casino-miami-miami', 'name': 'Casino Miami', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f0NbUfTT4rfrOQQ-yUqtfA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/casino-miami-miami?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 69, 'categories': [{'alias': 'casinos', 'title': 'Casinos'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 2.5, 'coordinates': {'latitude': 25.8073357, 'longitude': -80.2568107}, 'transactions': [], 'price': '$$', 'location': {'address1': '3500 NW 37th Ave', 'address2': '', 'address3': '', 'city': 'Miami', 'zip_code': '33142', 'country': 'US', 'state': 'FL', 'display_address': ['3500 NW 37th Ave', 'Miami, FL 33142']}, 'phone': '+13056336400', 'display_phone': '(305) 633-6400', 'distance': 6829.491423556454}, {'id': 'ShDKFv1oWCkHnbQ8wukZHQ', 'alias': 'voodoo-rooftop-lounge-and-hookah-miami-be ...

# %%
# Breweries - Data Pull for Miami Breweries Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_breweries_data = response.json()
        
        with open('Miami_breweries_response.json', 'a') as json_file:
            json.dump(miami_breweries_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_breweries_data)
# Out:
# {'businesses': [], 'total': 365, 'region': {'center': {'longitude': -80.2880859375, 'latitude': 25.752753731496888}}}

# %%
# Festivals - Data Pull for Miami Festivals Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=festivals&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_festivals_data = response.json()
        
        with open('Miami_festivals_response.json', 'a') as json_file:
            json.dump(miami_festivals_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_festivals_data)
# Out:
# {'businesses': [], 'total': 19, 'region': {'center': {'longitude': -80.2880859375, 'latitude': 25.752753731496888}}}

# %%
# Fitness - Data Pull for Miami Fitness Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=fitness&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_fitness_data = response.json()
        
        with open('Miami_fitness_response.json', 'a') as json_file:
            json.dump(miami_bars_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_fitness_data)
# Out:
# {'businesses': [{'id': 'ZtGhKztlKUAWiSF4fs5cfw', 'alias': 'amped-fitness-doral-miami', 'name': 'Amped Fitness - Doral', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ALZTz_AOAPRXQ8VCACcfHg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/amped-fitness-doral-miami?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 25, 'categories': [{'alias': 'healthtrainers', 'title': 'Trainers'}], 'rating': 2.0, 'coordinates': {'latitude': 25.78314, 'longitude': -80.32673}, 'transactions': [], 'location': {'address1': '8181 NW 12th St', 'address2': None, 'address3': '', 'city': 'Miami', 'zip_code': '33126', 'country': 'US', 'state': 'FL', 'display_address': ['8181 NW 12th St', 'Miami, FL 33126']}, 'phone': '+17272913953', 'display_phone': '(727) 291-3953', 'distance': 5143.61156231172}, {'id': 'EqP3qhpsaWKHse90qC5CVQ', 'alias': 'la-fitness-north-miami', 'name': 'LA Fitness', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5i2d4GDk6GSXR-kWktJvZg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/la-fitness-north-miami?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 202, 'categories': [{'alias': 'gyms', 'title': 'Gyms'}, {'alias': 'healthtrainers', 'title': 'Trainers'}, {'alias': 'yoga', 'title': 'Yoga'}], 'rating': 2.0, 'coordinates': {'latitude': 25.890034, 'longitude': -80.161928}, 'transactions': [], 'location': {'address1': '1801 NE 123rd St', 'address2': 'Ste 200', 'address3': None, 'city': 'North Miami', 'zip_code': '33181', 'country': 'US', 'state': 'FL', 'display_address': ['1801 NE 123rd St', 'Ste 200', 'North Miami, FL 33181']}, 'phone': '+17867181789', 'display_phone': '(786) 718-1789', 'distance': 19791.0386446311}, {'id': 'cd3Y-YovQXU8W3yC8R4xEw', 'alias': 'hyatt-stayfit-fort-lauderdale', 'name': 'Hyatt StayFit', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/V6G4sdLjaoMpByLzCwOjDQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hyatt-stayfit-fort-lauderdale?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 1, 'categories': [{'alias': 'gyms', 'title': 'Gyms'}], 'rating': 3.0, 'coordinates': {'latitude': 26.101594, 'longitude': -80.115466}, 'transactions': [], 'location': {'address1': '2301 SE 17th St', 'address2': '', 'address3': 'Manchester Grand Hyatt', 'city': 'Fort Lauderdale', 'zip_code': '33316', 'country': 'US', 'state': 'FL', 'display_address': ['2301 SE 17th St', 'Manchester Grand Hyatt', 'Fort Lauderdale, FL 33316']}, 'phone': '', 'display_phone': '', 'distance': 42457.00516460377}, {'id': '1jrCawe2sHlPX8-jpLD1aA', 'alias': 'la-fitness-pembroke-pines', 'name': 'LA Fitness', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HtBbJtu4i-vp33b0-IyiSg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/la-fitness-pembroke-pines?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 118, 'categories': [{'alias': 'gyms', 'title': 'Gyms'}, {'alias': 'healthtrainers', 'title': 'Trainers'}, {'alias': 'yoga', 'title': 'Yoga'}], 'rating': 2.0, 'coordinates': {'latitude': 26.009866, 'longitude': -80.394657}, 'transactions': [], 'location': {'address1': '18445 Pines Blvd', 'address2': None, 'address3': None, 'city': 'Pembroke Pines', 'zip_code': '33029', 'country': 'US', 'state': 'FL', 'display_address': ['18445 Pines Blvd', 'Pembroke Pines, FL 33029']}, 'phone': '+19544415330', 'display_phone': '(954) 441-5330', 'distance': 30512.80453521405}, {'id': 'GltJR1f1oS3kZXe2_4oDoA', 'alias': 'la-fitness-doral-2', 'name': 'LA Fitness', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZM1sQq_QA9bzFhBMvQnErQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/la-fitness-dora ...

# %%
# Food - Data Pull for Miami Arts Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_food_data = response.json()
        
        with open('Miami_food_response.json', 'a') as json_file:
            json.dump(miami_food_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_food_data)
# Out:
# {'businesses': [], 'total': 316, 'region': {'center': {'longitude': -80.2880859375, 'latitude': 25.752753731496888}}}

# %%
# Museums - Data Pull for Miami Museums Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=museums&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_museums_data = response.json()
        
        with open('Miami_museums_response.json', 'a') as json_file:
            json.dump(miami_museums_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_museums_data)
# Out:
# {'businesses': [], 'total': 10, 'region': {'center': {'longitude': -80.2880859375, 'latitude': 25.752753731496888}}}

# %%
# Nightlife - Data Pull for Miami Nightlife Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=nightlife&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_nightlife_data = response.json()
        
        with open('Miami_nightlife_response.json', 'a') as json_file:
            json.dump(miami_nightlife_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_nightlife_data)
# Out:
# {'businesses': [{'id': 'ksXSO_wA64QYtwQS3K242Q', 'alias': 'candela-bar-brickell-miami', 'name': 'Candela Bar Brickell', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xwQvhDy-eEbrpmxGIPaU9A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/candela-bar-brickell-miami?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 22, 'categories': [{'alias': 'hookah_bars', 'title': 'Hookah Bars'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}], 'rating': 2.5, 'coordinates': {'latitude': 25.764999015539704, 'longitude': -80.1939434721196}, 'transactions': [], 'price': '$$', 'location': {'address1': '900 South Miami Ave', 'address2': 'Ste 180', 'address3': '', 'city': 'Miami', 'zip_code': '33130', 'country': 'US', 'state': 'FL', 'display_address': ['900 South Miami Ave', 'Ste 180', 'Miami, FL 33130']}, 'phone': '+17863605569', 'display_phone': '(786) 360-5569', 'distance': 9525.758630719669}, {'id': '-yiftcvy2at7FglLtQyCkg', 'alias': 'casino-miami-miami', 'name': 'Casino Miami', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f0NbUfTT4rfrOQQ-yUqtfA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/casino-miami-miami?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 69, 'categories': [{'alias': 'casinos', 'title': 'Casinos'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 2.5, 'coordinates': {'latitude': 25.8073357, 'longitude': -80.2568107}, 'transactions': [], 'price': '$$', 'location': {'address1': '3500 NW 37th Ave', 'address2': '', 'address3': '', 'city': 'Miami', 'zip_code': '33142', 'country': 'US', 'state': 'FL', 'display_address': ['3500 NW 37th Ave', 'Miami, FL 33142']}, 'phone': '+13056336400', 'display_phone': '(305) 633-6400', 'distance': 6829.491423556454}, {'id': 'ShDKFv1oWCkHnbQ8wukZHQ', 'alias': 'voodoo-rooftop-lounge-and-hookah-miami-beach-3', 'name': 'Voodoo Rooftop Lounge & Hookah', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_foofWnH2YgyLZ0bfBt-cA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/voodoo-rooftop-lounge-and-hookah-miami-beach-3?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 343, 'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'lounges', 'title': 'Lounges'}, {'alias': 'hookah_bars', 'title': 'Hookah Bars'}], 'rating': 2.5, 'coordinates': {'latitude': 25.77974, 'longitude': -80.13108}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '928 Ocean Dr', 'address2': None, 'address3': '', 'city': 'Miami Beach', 'zip_code': '33139', 'country': 'US', 'state': 'FL', 'display_address': ['928 Ocean Dr', 'Miami Beach, FL 33139']}, 'phone': '+13052066404', 'display_phone': '(305) 206-6404', 'distance': 16004.662616470336}, {'id': 'jlyxtuv2aorMd6VN_3ckyg', 'alias': 'billares-gato-negro-hollywood', 'name': 'Billares Gato Negro', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0vggw_DKyl7lj4jdXI2aFA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/billares-gato-negro-hollywood?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 9, 'categories': [{'alias': 'poolbilliards', 'title': 'Pool & Billiards'}, {'alias': 'sportsbars', 'title': 'Sports Bars'}, {'alias': 'hookah_bars', 'title': 'Hookah Bars'}], 'rating': 2.5, 'coordinates': {'latitude': 26.011604064746, 'longitude': -80.1482295244932}, 'transactions': [], 'location': {'address1': '2027 Hollywood Blvd', 'address2': '', 'address3': None, 'city': 'Hollywood', 'zip_code': '33020', 'country': 'US', 'state': 'FL', 'display_address': ['2027 Hollywood Blvd', 'Hollywood, FL 33020']}, 'phone': '+1754 ...

# %%
# Restaurants - Data Pull for Miami Restaurants: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):    
        import requests

        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=restaurants&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_restaurants_data = response.json()
        
        with open('Miami_restaurants_response.json', 'a') as json_file:
            json.dump(miami_restaurants_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_restaurants_data)
# Out:
# {'businesses': [{'id': '2Fr7io7h27gdZ5PAnLg1qQ', 'alias': 'bandidos-taqueria-no-title', 'name': 'Bandidos Taqueria', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/chl6VAJrsSVKZ_X5fWoJgg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/bandidos-taqueria-no-title?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 29, 'categories': [{'alias': 'mexican', 'title': 'Mexican'}], 'rating': 4.0, 'coordinates': {'latitude': 25.79619, 'longitude': -80.32376}, 'transactions': ['delivery', 'pickup'], 'location': {'address1': '7800 NW 25th St', 'address2': 'Ste 15', 'address3': '', 'city': 'Miami', 'zip_code': '33126', 'country': 'US', 'state': 'FL', 'display_address': ['7800 NW 25th St', 'Ste 15', 'Miami, FL 33126']}, 'phone': '+13055308899', 'display_phone': '(305) 530-8899', 'distance': 6014.422422005317}, {'id': 'ZAFRJu1c2T9WGDpxQMoxgQ', 'alias': 'pizza-bianco-sunny-isles-beach', 'name': 'Pizza Bianco', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lkolDBfp9DCACwCEpD2tBg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/pizza-bianco-sunny-isles-beach?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 87, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'salad', 'title': 'Salad'}], 'rating': 4.0, 'coordinates': {'latitude': 25.954474, 'longitude': -80.1197403}, 'transactions': ['delivery', 'pickup'], 'price': '$', 'location': {'address1': '19201 Collins Ave', 'address2': '', 'address3': '', 'city': 'Sunny Isles Beach', 'zip_code': '33160', 'country': 'US', 'state': 'FL', 'display_address': ['19201 Collins Ave', 'Sunny Isles Beach, FL 33160']}, 'phone': '+13059377738', 'display_phone': '(305) 937-7738', 'distance': 28051.540962351224}, {'id': 'HgAd3Vr0GA3NR0EZqZzS8Q', 'alias': 'diplomat-prime-hollywood-2', 'name': 'Diplomat Prime', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x8MLUIAQfzHEy1OepFvLDw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/diplomat-prime-hollywood-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 266, 'categories': [{'alias': 'steak', 'title': 'Steakhouses'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 25.9917153, 'longitude': -80.1180293}, 'transactions': ['delivery'], 'price': '$$$$', 'location': {'address1': '3555 S Ocean Dr', 'address2': '', 'address3': '', 'city': 'Hollywood', 'zip_code': '33019', 'country': 'US', 'state': 'FL', 'display_address': ['3555 S Ocean Dr', 'Hollywood, FL 33019']}, 'phone': '+19546028331', 'display_phone': '(954) 602-8331', 'distance': 31551.741581610448}, {'id': 'liSzk3Qf4wkCaFO-v97Tlg', 'alias': 'atlantikos-bal-harbour', 'name': 'Atlantikos', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k3HolckTZlE5ziATgU9zTw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/atlantikos-bal-harbour?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 92, 'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}, {'alias': 'greek', 'title': 'Greek'}], 'rating': 4.0, 'coordinates': {'latitude': 25.8888332, 'longitude': -80.12287}, 'transactions': ['delivery'], 'price': '$$$$', 'location': {'address1': '9703 Collins Ave', 'address2': '', 'address3': None, 'city': 'Bal Harbour', 'zip_code': '33154', 'country': 'US', 'state': 'FL', 'display_address': ['9703 Collins Ave', 'Bal Harbour, FL 33154']}, 'phone': '+13059933333', 'display_phone': '(305) 993-3333', 'distance': 22414.927571793232}, {'id': 'QI-U9OPlchriBOuaUQSIDA', 'alias': 'spaghetto-davie-3', 'name': 'Spaghetto Kitchen', 'image_url': ' ...

# %%
# Tours - Data Pull for Miami Tours Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=tours&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_tours_data = response.json()
        
        with open('Miami_tours_response.json', 'a') as json_file:
            json.dump(miami_tours_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_tours_data)
# Out:
# {'businesses': [], 'total': 122, 'region': {'center': {'longitude': -80.2880859375, 'latitude': 25.752753731496888}}}

# %%
# Wineries - Data Pull for Miami Wineries Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=wineries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_wineries_data = response.json()
        
        with open('Miami_wineries_response.json', 'a') as json_file:
            json.dump(miami_wineries_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_wineries_data)
# Out:
# {'businesses': [], 'total': 4, 'region': {'center': {'longitude': -80.2880859375, 'latitude': 25.752753731496888}}}

# %%
# Zoos - Data Pull for Miami Zoos Category: Radius 40000, Open, By Rating
location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=zoos&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        miami_zoos_data = response.json()
        
        with open('Miami_zoos_response.json', 'a') as json_file:
            json.dump(miami_zoos_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(miami_zoos_data)
# Out:
# {'businesses': [], 'total': 1, 'region': {'center': {'longitude': -80.2880859375, 'latitude': 25.752753731496888}}}

# %% [markdown]
# #### (End of Miami Pulls)

# %% [markdown]
# ## New York

# %%
# Active - Data Pull for New York Active Category: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=active&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        newyork_fitness_data = response.json()
        
        with open('NewYork_active_response.json', 'a') as json_file:
            json.dump(newyork_active_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_active_data)

# %%
# Bars - Data Pull for New York Bars Category: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=bars&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_bars_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)
        
        newyork_bars_data = response.json()
        
        with open('NewYork_bars_response.json', 'a') as json_file:
            json.dump(newyork_bars_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_bars_data)

# %%
# Breweries - Data Pull for New York Breweries Category: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=breweries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        newyork_breweries_data = response.json()
        
        with open('NewYork_breweries_response.json', 'a') as json_file:
            json.dump(newyork_breweries_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_breweries_data)

# %%
# Festivals - Data Pull for New York Festivals Category: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=festivals&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_festivals_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)
        
        newyork_festivals_data = response.json()
        
        with open('NewYork_festivals_response.json', 'a') as json_file:
            json.dump(newyork_festivals_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_festivals_data)

# %%
# Fitness - Data Pull for New York Fitness Category: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=fitness&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_fitness_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)
        
        newyork_fitness_data = response.json()
        
        with open('NewYork_fitness_response.json', 'a') as json_file:
            json.dump(newyork_bars_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_fitness_data)

# %%
# Food - Data Pull for New York Food Category: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=food&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        newyork_food_data = response.json()
        
        with open('NewYork_food_response.json', 'a') as json_file:
            json.dump(newyork_food_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_food_data)

# %%
# Museums - Data Pull for New York Museums Category: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=museums&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        newyork_museums_data = response.json()
        
        with open('NewYork_museums_response.json', 'a') as json_file:
            json.dump(newyork_museums_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_museums_data)

# %%
# Nightlife - Data Pull for New York Nightlife Category: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=nightlife&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        newyork_nightlife_data = response.json()
        
        with open('NewYork_nightlife_response.json', 'a') as json_file:
            json.dump(newyork_nightlife_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_nightlife_data)

# %%
# Restaurants - Data Pull for New York Restaurants: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):    
        import requests

        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=restaurants&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("restaurant_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

        
        newyork_restaurants_data = response.json()
        
        with open('NewYork_restaurants_response.json', 'a') as json_file:
            json.dump(newyork_restaurants_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_restaurants_data)

# %%
# Tours - Data Pull for New York Tours Category: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=tours&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        newyork_tours_data = response.json()
        
        with open('NewYork_tours_response.json', 'a') as json_file:
            json.dump(newyork_tours_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_tours_data)

# %%
# Wineries - Data Pull for New York Wineries Category: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=wineries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        newyork_wineries_data = response.json()
        
        with open('NewYork_wineries_response.json', 'a') as json_file:
            json.dump(newyork_wineries_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_wineries_data)

# %%
# Zoos - Data Pull for New York Zoos Category: Radius 40000, Open, By Rating
location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=zoos&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        newyork_zoos_data = response.json()
        
        with open('NewYork_zoos_response.json', 'a') as json_file:
            json.dump(newyork_zoos_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)
        
print(newyork_zoos_data)

# %% [markdown]
# #### (End of New York Pulls)
