# %% [markdown]
# # Smart Travel App
# ## Group 4, Project 4
# ### Team: Dominique Villarreal, Enrique Garcia, Jose Santos
# ### Project Due Date: June 12, 2023

# %% [markdown]
# ## Setup Environment

# %%
import requests
import pprint as pp
import json

# %% [markdown]
# ## Exploring the Yelp API

# %%
# Confirm Category Alias & Parent Aliases

url = "https://api.yelp.com/v3/categories"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
}

response = requests.get(url, headers=headers)

data = json.loads(response.text)

categories = [(category['alias'], category['parent_aliases']) for category in data['categories']]
categories_sorted = sorted(categories, key=lambda x: (x[1], x[0]))

pp.pprint(categories_sorted)
# Out:
# [('active', []),
#  ('arts', []),
#  ('auto', []),
#  ('beautysvc', []),
#  ('bicycles', []),
#  ('education', []),
#  ('eventservices', []),
#  ('financialservices', []),
#  ('food', []),
#  ('health', []),
#  ('homeservices', []),
#  ('hotelstravel', []),
#  ('localflavor', []),
#  ('localservices', []),
#  ('massmedia', []),
#  ('nightlife', []),
#  ('pets', []),
#  ('professional', []),
#  ('publicservicesgovt', []),
#  ('religiousorgs', []),
#  ('restaurants', []),
#  ('shopping', []),
#  ('airsoft', ['active']),
#  ('amateursportsteams', ['active']),
#  ('amusementparks', ['active']),
#  ('aquariums', ['active']),
#  ('archery', ['active']),
#  ('atvrentals', ['active']),
#  ('axethrowing', ['active']),
#  ('badminton', ['active']),
#  ('baseballfields', ['active']),
#  ('basketballcourts', ['active']),
#  ('bathing_area', ['active']),
#  ('battingcages', ['active']),
#  ('beachequipmentrental', ['active']),
#  ('beaches', ['active']),
#  ('beachvolleyball', ['active']),
#  ('bicyclepaths', ['active']),
#  ('bikeparking', ['active']),
#  ('bikerentals', ['active']),
#  ('boating', ['active']),
#  ('bobsledding', ['active']),
#  ('bocceball', ['active']),
#  ('bowling', ['active']),
#  ('bubblesoccer', ['active']),
#  ('bungeejumping', ['active']),
#  ('canyoneering', ['active']),
#  ('carousels', ['active']),
#  ('challengecourses', ['active']),
#  ('climbing', ['active']),
#  ('cyclingclasses', ['active']),
#  ('dartarenas', ['active']),
#  ('daycamps', ['active']),
#  ('discgolf', ['active']),
#  ('diving', ['active']),
#  ('escapegames', ['active']),
#  ('experiences', ['active']),
#  ('fencing', ['active']),
#  ('fishing', ['active']),
#  ('fitness', ['active']),
#  ('flyboarding', ['active']),
#  ('football', ['active']),
#  ('gliding', ['active']),
#  ('gokarts', ['active']),
#  ('golf', ['active']),
#  ('gun_ranges', ['active']),
#  ('gymnastics', ['active']),
#  ('handball', ['active']),
#  ('hanggliding', ['active']),
#  ('hiking', ['active']),
#  ('horsebackriding', ['active']),
#  ('horseracing', ['active']),
#  ('hot_air_balloons', ['active']),
#  ('indoor_playcenter', ['active']),
#  ('jetskis', ['active']),
#  ('kids_activities', ['active']),
#  ('kiteboarding', ['active']),
#  ('lakes', ['active']),
#  ('lasertag', ['active']),
#  ('lawn_bowling', ['active']),
#  ('leisure_centers', ['active']),
#  ('mini_golf', ['active']),
#  ('mountainbiking', ['active']),
#  ('nudist', ['active']),
#  ('paddleboarding', ['active']),
#  ('paintball', ['active']),
#  ('paragliding', ['active']),
#  ('parasailing', ['active']),
#  ('parks', ['active']),
#  ('pickleball', ['active']),
#  ('playgrounds', ['active']),
#  ('publicplazas', ['active']),
#  ('races', ['active']),
#  ('racingexperience', ['active']),
#  ('rafting', ['active']),
#  ('recreation', ['active']),
#  ('rock_climbing', ['active']),
#  ('sailing', ['active']),
#  ('scavengerhunts', ['active']),
#  ('scooterrentals', ['active']),
#  ('seniorcenters', ['active']),
#  ('skatingrinks', ['active']),
#  ('skiing', ['active']),
#  ('skydiving', ['active']),
#  ('sledding', ['active']),
#  ('snorkeling', ['active']),
#  ('spinclasses', ['active']),
#  ('sport_equipment_hire', ['active']),
#  ('sports_clubs', ['active']),
#  ('squash', ['active']),
#  ('summer_camps', ['active']),
#  ('surfing', ['active']),
#  ('surflifesaving', ['active']),
#  ('swimmingpools', ['active']),
#  ('tennis', ['active']),
#  ('trampoline', ['active']),
#  ('tubing', ['active']),
#  ('volleyball', ['active']),
#  ('waterparks', ['active']),
#  ('wildlifehunting', ['active']),
#  ('zipline', ['active']),
#  ('zoos', ['active']),
#  ('zorbing', ['active']),
#  ('stripclubs', ['adultentertainment']),
#  ('stripteasedancers', ['adultentertainment']),
#  ('senegalese', ['african']),
#  ('southafrican', ['african']),
#  ('airportterminals', ['airports']),
#  ('arabpizza', ['arabian']),
#  ('glassblowing', ['artclasses']),
#  ('arcades', ['arts']),
#  ('bettingcenters', ['arts']),
#  ('bingo', ['arts']),
#  ('cabaret', ['arts']),
#  ('casinos', ['arts']),
#  ('castles', ['arts']),
#  ('choirs', ['arts']),
#  ('countryclubs', ['arts']),
#  ('culturalcenter', ['arts']),
#  ('eatertainment', ['arts']),
#  ('farms', ['arts']),
#  ('festivals', ['arts']),
#  ('gardens', ['arts']),
#  ('hauntedhouses', ['arts']),
#  ('lancenters', ['arts']),
#  ('mahjong', ['arts']),
#  ('makerspaces', ['arts']),
#  ('marchingbands', ['arts']),
#  ('movietheaters', ['arts']),
#  ('museums', ['arts']),
#  ('observatories', ['arts']),
#  ('opera', ['arts']),
#  ('pachinko', ['arts']),
#  ('paintandsip', ['arts']),
#  ('planetarium', ['arts']),
#  ('psychic_astrology', ['arts']),
#  ('racetracks', ['arts']),
#  ('rodeo', ['arts']),
#  ('social_clubs', ['arts']),
#  ('sportsbetting', ['arts']),
#  ('sportsteams', ['arts']),
#  ('stadiumsarenas', ['arts']),
#  ('streetart', ['arts']),
#  ('studiotaping', ['arts']),
#  ('tablaoflamenco', ['arts']),
#  ('theater', ['arts']),
#  ('ticketsales', ['arts']),
#  ('virtualrealitycenters', ['arts']),
#  ('wineries', ['arts', 'food']),
#  ('jazzandblues', ['arts', 'nightlife']),
#  ('musicvenues', ['arts', 'nightlife']),
#  ('galleries', ['arts', 'shopping']),
#  ('artsupplies', ['artsandcrafts']),
#  ('ateliers', ['artsandcrafts']),
#  ('cookingclasses', ['artsandcrafts']),
#  ('costumes', ['artsandcrafts']),
#  ('embroideryandcrochet', ['artsandcrafts']),
#  ('fabricstores', ['artsandcrafts']),
#  ('framing', ['artsandcrafts']),
#  ('paintyourownpottery', ['artsandcrafts']),
#  ('aircraftdealers', ['auto']),
#  ('aircraftrepairs', ['auto']),
#  ('auto_detailing', ['auto']),
#  ('autocustomization', ['auto']),
#  ('autodamageassessment', ['auto']),
#  ('autoelectric', ['auto']),
#  ('autoglass', ['auto']),
#  ('autoloanproviders', ['auto']),
#  ('autopartssupplies', ['auto']),
#  ('autorepair', ['auto']),
#  ('autosecurity', ['auto']),
#  ('autoupholstery', ['auto']),
#  ('aviationservices', ['auto']),
#  ('boatdealers', ['auto']),
#  ('boatpartsandsupplies', ['auto']),
#  ('bodyshops', ['auto']),
#  ('car_dealers', ['auto']),
#  ('carauctions', ['auto']),
#  ('carbrokers', ['auto']),
#  ('carbuyers', ['auto']),
#  ('carshares', ['auto']),
#  ('carwash', ['auto']),
#  ('evchargingstations', ['auto']),
#  ('fueldocks', ['auto']),
#  ('gasstations', ['auto']),
#  ('golfcartdealers', ['auto']),
#  ('hybridcarrepair', ['auto']),
#  ('interlocksystems', ['auto']),
#  ('marinas', ['auto']),
#  ('mobiledentrepair', ['auto']),
#  ('mobilityequipment', ['auto']),
#  ('motodealers', ['auto']),
#  ('motorcycledealers', ['auto']),
#  ('motorcyclerepair', ['auto']),
#  ('motorepairs', ['auto']),
#  ('oilchange', ['auto']),
#  ('parking', ['auto']),
#  ('registrationservices', ['auto']),
#  ('roadsideassist', ['auto']),
#  ('rv_dealers', ['auto']),
#  ('rvrepair', ['auto']),
#  ('service_stations', ['auto']),
#  ('servicestations', ['auto']),
#  ('smog_check_stations', ['auto']),
#  ('stereo_installation', ['auto']),
#  ('tires', ['auto']),
#  ('towing', ['auto']),
#  ('trailerdealers', ['auto']),
#  ('trailerrental', ['auto']),
#  ('trailerrepair', ['auto']),
#  ('transmissionrepair', ['auto']),
#  ('truck_rental', ['auto']),
#  ('truckdealers', ['auto']),
#  ('truckrepair', ['auto']),
#  ('usedcardealers', ['auto']),
#  ('vehicleshipping', ['auto']),
#  ('vehiclewraps', ['auto']),
#  ('wheelrimrepair', ['auto']),
#  ('windshieldinstallrepair', ['auto']),
#  ('carwindowtinting', ['autoglass']),
#  ('motorcyclepartsandsupplies', ['autopartssupplies']),
#  ('diyautoshop', ['autorepair']),
#  ('absinthebars', ['bars']),
#  ('airportlounges', ['bars']),
#  ('beachbars', ['bars']),
#  ('beerbar', ['bars']),
#  ('champagne_bars', ['bars']),
#  ('cigarbars', ['bars']),
#  ('cocktailbars', ['bars']),
#  ('divebars', ['bars']),
#  ('drivethrubars', ['bars']),
#  ('gaybars', ['bars']),
#  ('hookah_bars', ['bars']),
#  ('hotel_bar', ['bars']),
#  ('irish_pubs', ['bars']),
#  ('lounges', ['bars']),
#  ('pubs', ['bars']),
#  ('pulquerias', ['bars']),
#  ('sakebars', ['bars']),
#  ('speakeasies', ['bars']),
#  ('sportsbars', ['bars']),
#  ('tabac', ['bars']),
#  ('tikibars', ['bars']),
#  ('vermouthbars', ['bars']),
#  ('whiskeybars', ['bars']),
#  ('wine_bars', ['bars']),
#  ('acnetreatment', ['beautysvc']),
#  ('barbers', ['beautysvc']),
#  ('eroticmassage', ['beautysvc']),
#  ('eyebrowservices', ['beautysvc']),
#  ('eyelashservice', ['beautysvc']),
#  ('footcare', ['beautysvc']),
#  ('hair', ['beautysvc']),
#  ('hairloss', ['beautysvc']),
#  ('hairremoval', ['beautysvc']),
#  ('hotsprings', ['beautysvc']),
#  ('makeupartists', ['beautysvc']),
#  ('massage', ['beautysvc']),
#  ('othersalons', ['beautysvc']),
#  ('permanentmakeup', ['beautysvc']),
#  ('piercing', ['beautysvc']),
#  ('rolfing', ['beautysvc']),
#  ('skincare', ['beautysvc']),
#  ('spas', ['beautysvc']),
#  ('tanning', ['beautysvc']),
#  ('tattoo', ['beautysvc']),
#  ('teethwhitening', ['beautysvc']),
#  ('hair_extensions', ['beautysvc', 'hair']),
#  ('cosmetics', ['beautysvc', 'shopping']),
#  ('flemish', ['belgian']),
#  ('bikeassociations', ['bicycles']),
#  ('bikerepair', ['bicycles']),
#  ('bikeshop', ['bicycles']),
#  ('specialbikes', ['bicycles']),
#  ('brazilianempanadas', ['brazilian']),
#  ('centralbrazilian', ['brazilian']),
#  ('northeasternbrazilian', ['brazilian']),
#  ('northernbrazilian', ['brazilian']),
#  ('rodizios', ['brazilian']),
#  ('pancakes', ['breakfast_brunch']),
#  ('brewpubs', ['breweries']),
#  ('psychoanalysts', ['c_and_mh']),
#  ('psychologists', ['c_and_mh']),
#  ('psychotherapists', ['c_and_mh']),
#  ('sextherapists', ['c_and_mh']),
#  ('sophrologists', ['c_and_mh']),
#  ('sportspsychologists', ['c_and_mh']),
#  ('themedcafes', ['cafes']),
#  ('cannabistours', ['cannabis_clinics']),
#  ('dominican', ['caribbean']),
#  ('haitian', ['caribbean']),
#  ('puertorican', ['caribbean']),
#  ('trinidadian', ['caribbean']),
#  ('cantonese', ['chinese']),
#  ('congee', ['chinese']),
#  ('dimsum', ['chinese']),
#  ('fuzhou', ['chinese']),
#  ('hainan', ['chinese']),
#  ('hakka', ['chinese']),
#  ('henghwa', ['chinese']),
#  ('hokkien', ['chinese']),
#  ('hunan', ['chinese']),
#  ('pekinese', ['chinese']),
#  ('shanghainese', ['chinese']),
#  ('szechuan', ['chinese']),
#  ('teochew', ['chinese']),
#  ('faithbasedcpc', ['crisispregnancycenters']),
#  ('dentalhygeiniststorefront', ['dentalhygienists']),
#  ('dentalhygienistsmobile', ['dentalhygienists']),
#  ('cosmeticdentists', ['dentists']),
#  ('endodontists', ['dentists']),
#  ('generaldentistry', ['dentists']),
#  ('oralsurgeons', ['dentists']),
#  ('orthodontists', ['dentists']),
#  ('pediatric_dentists', ['dentists']),
#  ('periodontists', ['dentists']),
#  ('diagnosticimaging', ['diagnosticservices']),
#  ('laboratorytesting', ['diagnosticservices']),
#  ('freediving', ['diving']),
#  ('scuba', ['diving']),
#  ('gyudon', ['donburi']),
#  ('oyakodon', ['donburi']),
#  ('adultedu', ['education']),
#  ('artclasses', ['education']),
#  ('collegecounseling', ['education']),
#  ('collegeuniv', ['education']),
#  ('educationservices', ['education']),
#  ('elementaryschools', ['education']),
#  ('highschools', ['education']),
#  ('montessori', ['education']),
#  ('preschools', ['education']),
#  ('privateschools', ['education']),
#  ('privatetutors', ['education']),
#  ('religiousschools', ['education']),
#  ('specialed', ['education']),
#  ('specialtyschools', ['education']),
#  ('tastingclasses', ['education']),
#  ('testprep', ['education']),
#  ('tutoring', ['education']),
#  ('waldorfschools', ['education']),
#  ('willstrustsprobates', ['estateplanning']),
#  ('balloonservices', ['eventservices']),
#  ('bartenders', ['eventservices']),
#  ('boatcharters', ['eventservices']),
#  ('caricatures', ['eventservices']),
#  ('catering', ['eventservices']),
#  ('clowns', ['eventservices']),
#  ('djs', ['eventservices']),
#  ('eventplanning', ['eventservices']),
#  ('facepainting', ['eventservices']),
#  ('floraldesigners', ['eventservices']),
#  ('gametruckrental', ['eventservices']),
#  ('golfcartrentals', ['eventservices']),
#  ('hennaartists', ['eventservices']),
#  ('magicians', ['eventservices']),
#  ('mohels', ['eventservices']),
#  ('musicians', ['eventservices']),
#  ('officiants', ['eventservices']),
#  ('partybikerentals', ['eventservices']),
#  ('partybusrentals', ['eventservices']),
#  ('partycharacters', ['eventservices']),
#  ('partyequipmentrentals', ['eventservices']),
#  ('partysupplies', ['eventservices']),
#  ('personalchefs', ['eventservices']),
#  ('photoboothrentals', ['eventservices']),
#  ('photographers', ['eventservices']),
#  ('silentdisco', ['eventservices']),
#  ('sommelierservices', ['eventservices']),
#  ('teambuilding', ['eventservices']),
#  ('triviahosts', ['eventservices']),
#  ('valetservices', ['eventservices']),
#  ('venues', ['eventservices']),
#  ('videographers', ['eventservices']),
#  ('wedding_planning', ['eventservices']),
#  ('weddingchappels', ['eventservices']),
#  ('stationery', ['eventservices', 'artsandcrafts', 'flowers']),
#  ('hotels', ['eventservices', 'hotelstravel']),
#  ('attractionfarms', ['farms']),
#  ('pickyourown', ['farms']),
#  ('ranches', ['farms']),
#  ('accessories', ['fashion']),
#  ('ceremonialclothing', ['fashion']),
#  ('childcloth', ['fashion']),
#  ('clothingrental', ['fashion']),
#  ('formalwear', ['fashion']),
#  ('furclothing', ['fashion']),
#  ('hats', ['fashion']),
#  ('kimonos', ['fashion']),
#  ('leather', ['fashion']),
#  ('lingerie', ['fashion']),
#  ('maternity', ['fashion']),
#  ('menscloth', ['fashion']),
#  ('plus_size_fashion', ['fashion']),
#  ('shoes', ['fashion']),
#  ('sleepwear', ['fashion']),
#  ('stockings', ['fashion']),
#  ('surfshop', ['fashion']),
#  ('swimwear', ['fashion']),
#  ('tradclothing', ['fashion']),
#  ('vintage', ['fashion']),
#  ('womenscloth', ['fashion']),
#  ('sportswear', ['fashion', 'sportgoods']),
#  ('funfair', ['festivals']),
#  ('generalfestivals', ['festivals']),
#  ('tradefairs', ['festivals']),
#  ('xmasmarkets', ['festivals']),
#  ('banks', ['financialservices']),
#  ('businessfinancing', ['financialservices']),
#  ('currencyexchange', ['financialservices']),
#  ('debtrelief', ['financialservices']),
#  ('financialadvising', ['financialservices']),
#  ('installmentloans', ['financialservices']),
#  ('insurance', ['financialservices']),
#  ('investing', ['financialservices']),
#  ('mortgagelenders', ['financialservices']),
#  ('paydayloans', ['financialservices']),
#  ('taxservices', ['financialservices']),
#  ('titleloans', ['financialservices']),
#  ('aerialfitness', ['fitness']),
#  ('barreclasses', ['fitness']),
#  ('bootcamps', ['fitness']),
#  ('boxing', ['fitness']),
#  ('cardioclasses', ['fitness']),
#  ('dancestudio', ['fitness']),
#  ('emstraining', ['fitness']),
#  ('golflessons', ['fitness']),
#  ('gyms', ['fitness']),
#  ('healthtrainers', ['fitness']),
#  ('martialarts', ['fitness']),
#  ('meditationcenters', ['fitness']),
#  ('pilates', ['fitness']),
#  ('qigong', ['fitness']),
#  ('selfdefenseclasses', ['fitness']),
#  ('taichi', ['fitness']),
#  ('yoga', ['fitness']),
#  ('swimminglessons', ['fitness', 'specialtyschools']),
#  ('florists', ['flowers']),
#  ('flowersonly', ['flowers']),
#  ('giftshops', ['flowers']),
#  ('acaibowls', ['food']),
#  ('backshop', ['food']),
#  ('bagels', ['food']),
#  ('bakeries', ['food']),
#  ('beer_and_wine', ['food']),
#  ('bento', ['food']),
#  ('beverage_stores', ['food']),
#  ('breweries', ['food']),
#  ('bubbletea', ['food']),
#  ('butcher', ['food']),
#  ('cakeshop', ['food']),
#  ('chimneycakes', ['food']),
#  ('churros', ['food']),
#  ('cideries', ['food']),
#  ('coffee', ['food']),
#  ('coffeeroasteries', ['food']),
#  ('coffeeteasupplies', ['food']),
#  ('convenience', ['food']),
#  ('csa', ['food']),
#  ('cupcakes', ['food']),
#  ('customcakes', ['food']),
#  ('delicatessen', ['food']),
#  ('desserts', ['food']),
#  ('distilleries', ['food']),
#  ('diyfood', ['food']),
#  ('donairs', ['food']),
#  ('donuts', ['food']),
#  ('empanadas', ['food']),
#  ('ethicgrocery', ['food']),
#  ('ethnicgrocery', ['food']),
#  ('farmersmarket', ['food']),
#  ('fishmonger', ['food']),
#  ('fooddeliveryservices', ['food']),
#  ('foodtrucks', ['food']),
#  ('friterie', ['food']),
#  ('gelato', ['food']),
#  ('gluhwein', ['food']),
#  ('gourmet', ['food']),
#  ('grocery', ['food']),
#  ('hawkercentre', ['food']),
#  ('honey', ['food']),
#  ('icecream', ['food']),
#  ('importedfood', ['food']),
#  ('internetcafe', ['food']),
#  ('intlgrocery', ['food']),
#  ('jpsweets', ['food']),
#  ('juicebars', ['food']),
#  ('kombucha', ['food']),
#  ('meaderies', ['food']),
#  ('milkshakebars', ['food']),
#  ('nasilemak', ['food']),
#  ('organic_stores', ['food']),
#  ('panzerotti', ['food']),
#  ('piadina', ['food']),
#  ('poke', ['food']),
#  ('pretzels', ['food']),
#  ('salumerie', ['food']),
#  ('shavedice', ['food']),
#  ('shavedsnow', ['food']),
#  ('smokehouse', ['food']),
#  ('streetvendors', ['food']),
#  ('sugarshacks', ['food']),
#  ('tea', ['food']),
#  ('torshi', ['food']),
#  ('tortillas', ['food']),
#  ('waterstores', ['food']),
#  ('zapiekanka', ['food']),
#  ('eltern_cafes', ['food', 'restaurants']),
#  ('kiosk', ['food', 'shopping']),
#  ('alsatian', ['french']),
#  ('auvergnat', ['french']),
#  ('berrichon', ['french']),
#  ('bourguignon', ['french']),
#  ('mauritius', ['french']),
#  ('nicois', ['french']),
#  ('provencal', ['french']),
#  ('reunion', ['french']),
#  ('cremationservices', ['funeralservices']),
#  ('mortuaryservices', ['funeralservices']),
#  ('hydroponics', ['gardening']),
#  ('baden', ['german']),
#  ('easterngerman', ['german']),
#  ('franconian', ['german']),
#  ('hessian', ['german']),
#  ('northerngerman', ['german']),
#  ('palatine', ['german']),
#  ('rhinelandian', ['german']),
#  ('candy', ['gourmet']),
#  ('cheese', ['gourmet']),
#  ('chocolate', ['gourmet']),
#  ('dagashi', ['gourmet']),
#  ('driedfruit', ['gourmet']),
#  ('ethnicmarkets', ['gourmet']),
#  ('frozenfood', ['gourmet']),
#  ('healthmarkets', ['gourmet']),
#  ('herbsandspices', ['gourmet']),
#  ('macarons', ['gourmet']),
#  ('markets', ['gourmet']),
#  ('meats', ['gourmet']),
#  ('oliveoil', ['gourmet']),
#  ('pastashops', ['gourmet']),
#  ('popcorn', ['gourmet']),
#  ('seafoodmarkets', ['gourmet']),
#  ('tofu', ['gourmet']),
#  ('circuittraininggyms', ['gyms']),
#  ('intervaltraininggyms', ['gyms']),
#  ('blowoutservices', ['hair']),
#  ('hairstylists', ['hair']),
#  ('kidshairsalons', ['hair']),
#  ('menshair', ['hair']),
#  ('laser_hair_removal', ['hairremoval']),
#  ('sugaring', ['hairremoval']),
#  ('threadingservices', ['hairremoval']),
#  ('waxing', ['hairremoval']),
#  ('acupuncture', ['health']),
#  ('alternativemedicine', ['health']),
#  ('animalassistedtherapy', ['health']),
#  ('assistedliving', ['health']),
#  ('ayurveda', ['health']),
#  ('behavioranalysts', ['health']),
#  ('blooddonation', ['health']),
#  ('bodycontouring', ['health']),
#  ('c_and_mh', ['health']),
#  ('cannabis_clinics', ['health']),
#  ('cannabiscollective', ['health']),
#  ('cannabisreferrals', ['health']),
#  ('chiropractors', ['health']),
#  ('colonics', ['health']),
#  ('conciergemedicine', ['health']),
#  ('crisispregnancycenters', ['health']),
#  ('cryotherapy', ['health']),
#  ('dentalhygienists', ['health']),
#  ('dentists', ['health']),
#  ('diagnosticservices', ['health']),
#  ('dialysisclinics', ['health']),
#  ('dietitians', ['health']),
#  ('doulas', ['health']),
#  ('emergencyrooms', ['health']),
#  ('floatspa', ['health']),
#  ('habilitativeservices', ['health']),
#  ('halfwayhouses', ['health']),
#  ('halotherapy', ['health']),
#  ('healthcoach', ['health']),
#  ('healthinsurance', ['health']),
#  ('hearing_aids', ['health']),
#  ('hearingaidproviders', ['health']),
#  ('herbalshops', ['health']),
#  ('homehealthcare', ['health']),
#  ('hospice', ['health']),
#  ('hospitals', ['health']),
#  ('hydrotherapy', ['health']),
#  ('hypnosis', ['health']),
#  ('ivhydration', ['health']),
#  ('lactationservices', ['health']),
#  ('laserlasikeyes', ['health']),
#  ('liceservices', ['health']),
#  ('massage_therapy', ['health']),
#  ('medcenters', ['health']),
#  ('medicalfoot', ['health']),
#  ('medicaltransportation', ['health']),
#  ('memorycare', ['health']),
#  ('midwives', ['health']),
#  ('nursepractitioner', ['health']),
#  ('nutritionists', ['health']),
#  ('occupationaltherapy', ['health']),
#  ('optometrists', ['health']),
#  ('organdonorservices', ['health']),
#  ('orthotics', ['health']),
#  ('oxygenbars', ['health']),
#  ('personalcare', ['health']),
#  ('pharmacy', ['health']),
#  ('physicaltherapy', ['health']),
#  ('physicians', ['health']),
#  ('placentaencapsulation', ['health']),
#  ('postpartumcare', ['health']),
#  ('prenatal', ['health']),
#  ('prosthetics', ['health']),
#  ('prosthodontists', ['health']),
#  ('psychotechnicaltests', ['health']),
#  ('reflexology', ['health']),
#  ('rehabilitation_center', ['health']),
#  ('reiki', ['health']),
#  ('reproductivehealthservices', ['health']),
#  ('retirement_homes', ['health']),
#  ('saunas', ['health']),
#  ('skillednursing', ['health']),
#  ('sleepspecialists', ['health']),
#  ('speech_therapists', ['health']),
#  ('spermclinic', ['health']),
#  ('tcm', ['health']),
#  ('ultrasoundimagingcenters', ['health']),
#  ('urgent_care', ['health']),
#  ('weightlosscenters', ['health']),
#  ('medicalspa', ['health', 'beautysvc']),
#  ('appliances', ['homeandgarden']),
#  ('candlestores', ['homeandgarden']),
#  ('christmastrees', ['homeandgarden']),
#  ('furniture', ['homeandgarden']),
#  ('gardening', ['homeandgarden']),
#  ('grillingequipment', ['homeandgarden']),
#  ('hardware', ['homeandgarden']),
#  ('holidaydecorations', ['homeandgarden']),
#  ('homedecor', ['homeandgarden']),
#  ('hottubandpool', ['homeandgarden']),
#  ('kitchenandbath', ['homeandgarden']),
#  ('lightingstores', ['homeandgarden']),
#  ('linens', ['homeandgarden']),
#  ('materialeelettrico', ['homeandgarden']),
#  ('mattresses', ['homeandgarden']),
#  ('outdoorfurniture', ['homeandgarden']),
#  ('paintstores', ['homeandgarden']),
#  ('playsets', ['homeandgarden']),
#  ('pumpkinpatches', ['homeandgarden']),
#  ('rugs', ['homeandgarden']),
#  ('shedsandoutdoorstorage', ['homeandgarden']),
#  ('tableware', ['homeandgarden']),
#  ('artificialturf', ['homeservices']),
#  ('blinds', ['homeservices']),
#  ('buildingsupplies', ['homeservices']),
#  ('cabinetry', ['homeservices']),
#  ('carpenters', ['homeservices']),
#  ('carpeting', ['homeservices']),
#  ('carpetinstallation', ['homeservices']),
#  ('childproofing', ['homeservices']),
#  ('chimneysweeps', ['homeservices']),
#  ('contractors', ['homeservices']),
#  ('countertopinstall', ['homeservices']),
#  ('damagerestoration', ['homeservices']),
#  ('decksrailing', ['homeservices']),
#  ('demolitionservices', ['homeservices']),
#  ('doorsales', ['homeservices']),
#  ('drywall', ['homeservices']),
#  ('electricians', ['homeservices']),
#  ('excavationservices', ['homeservices']),
#  ('fencesgates', ['homeservices']),
#  ('fireplace', ['homeservices']),
#  ('fireprotection', ['homeservices']),
#  ('firewood', ['homeservices']),
#  ('flooring', ['homeservices']),
#  ('foundationrepair', ['homeservices']),
#  ('furnitureassembly', ['homeservices']),
#  ('garage_door_services', ['homeservices']),
#  ('gardeners', ['homeservices']),
#  ('glassandmirrors', ['homeservices']),
#  ('groutservices', ['homeservices']),
#  ('gutterservices', ['homeservices']),
#  ('handyman', ['homeservices']),
#  ('home_inspectors', ['homeservices']),
#  ('home_organization', ['homeservices']),
#  ('homeautomation', ['homeservices']),
#  ('homecleaning', ['homeservices']),
#  ('homeenergyauditors', ['homeservices']),
#  ('homenetworkinstall', ['homeservices']),
#  ('hometheatreinstallation', ['homeservices']),
#  ('homewindowtinting', ['homeservices']),
#  ('housesitters', ['homeservices']),
#  ('hvac', ['homeservices']),
#  ('insulationinstallation', ['homeservices']),
#  ('interiordesign', ['homeservices']),
#  ('irrigation', ['homeservices']),
#  ('landscapearchitects', ['homeservices']),
#  ('landscaping', ['homeservices']),
#  ('lighting', ['homeservices']),
#  ('locksmiths', ['homeservices']),
#  ('masonry_concrete', ['homeservices']),
#  ('mobile_home_repair', ['homeservices']),
#  ('movers', ['homeservices']),
#  ('packingservices', ['homeservices']),
#  ('painters', ['homeservices']),
#  ('patiocoverings', ['homeservices']),
#  ('plumbing', ['homeservices']),
#  ('poolcleaners', ['homeservices']),
#  ('poolservice', ['homeservices']),
#  ('pressurewashers', ['homeservices']),
#  ('realestate', ['homeservices']),
#  ('refinishing', ['homeservices']),
#  ('roofing', ['homeservices']),
#  ('roofinspectors', ['homeservices']),
#  ('saunainstallation', ['homeservices']),
#  ('seasonaldecorservices', ['homeservices']),
#  ('securitysystems', ['homeservices']),
#  ('shutters', ['homeservices']),
#  ('solarinstallation', ['homeservices']),
#  ('solarpanelcleaning', ['homeservices']),
#  ('structuralengineers', ['homeservices']),
#  ('stucco', ['homeservices']),
#  ('televisionserviceproviders', ['homeservices']),
#  ('tiling', ['homeservices']),
#  ('treeservices', ['homeservices']),
#  ('utilities', ['homeservices']),
#  ('vinylsiding', ['homeservices']),
#  ('wallpapering', ['homeservices']),
#  ('waterheaterinstallrepair', ['homeservices']),
#  ('waterproofing', ['homeservices']),
#  ('waterpurification', ['homeservices']),
#  ('windowsinstallation', ['homeservices']),
#  ('windowwashing', ['homeservices']),
#  ('agriturismi', ['hotels']),
#  ('mountainhuts', ['hotels']),
#  ('pensions', ['hotels']),
#  ('residences', ['hotels']),
#  ('reststops', ['hotels']),
#  ('ryokan', ['hotels']),
#  ('airports', ['hotelstravel']),
#  ('bedbreakfast', ['hotelstravel']),
#  ('campgrounds', ['hotelstravel']),
#  ('carrental', ['hotelstravel']),
#  ('guesthouses', ['hotelstravel']),
#  ('healthretreats', ['hotelstravel']),
#  ('hostels', ['hotelstravel']),
#  ('motorcycle_rental', ['hotelstravel']),
#  ('resorts', ['hotelstravel']),
#  ('rvparks', ['hotelstravel']),
#  ('rvrental', ['hotelstravel']),
#  ('skiresorts', ['hotelstravel']),
#  ('tours', ['hotelstravel']),
#  ('trainstations', ['hotelstravel']),
#  ('transport', ['hotelstravel']),
#  ('travelservices', ['hotelstravel']),
#  ('vacation_rentals', ['hotelstravel']),
#  ('vacationrentalagents', ['hotelstravel']),
#  ('autoinsurance', ['insurance']),
#  ('homeinsurance', ['insurance']),
#  ('lifeinsurance', ['insurance']),
#  ('abruzzese', ['italian']),
#  ('altoatesine', ['italian']),
#  ('apulian', ['italian']),
#  ('calabrian', ['italian']),
#  ('cucinacampana', ['italian']),
#  ('emilian', ['italian']),
#  ('friulan', ['italian']),
#  ('ligurian', ['italian']),
#  ('lumbard', ['italian']),
#  ('napoletana', ['italian']),
#  ('piemonte', ['italian']),
#  ('roman', ['italian']),
#  ('sardinian', ['italian']),
#  ('sicilian', ['italian']),
#  ('tuscan', ['italian']),
#  ('venetian', ['italian']),
#  ('datarecovery', ['itservices']),
#  ('mobilephonerepair', ['itservices']),
#  ('telecommunications', ['itservices']),
#  ('blowfish', ['japanese']),
#  ('conveyorsushi', ['japanese']),
#  ('donburi', ['japanese']),
#  ('handrolls', ['japanese']),
#  ('horumon', ['japanese']),
#  ('izakaya', ['japanese']),
#  ('japacurry', ['japanese']),
#  ('kaiseki', ['japanese']),
#  ('kushikatsu', ['japanese']),
#  ('oden', ['japanese']),
#  ('okinawan', ['japanese']),
#  ('okonomiyaki', ['japanese']),
#  ('onigiri', ['japanese']),
#  ('ramen', ['japanese']),
#  ('robatayaki', ['japanese']),
#  ('soba', ['japanese']),
#  ('sukiyaki', ['japanese']),
#  ('takoyaki', ['japanese']),
#  ('tempura', ['japanese']),
#  ('teppanyaki', ['japanese']),
#  ('tonkatsu', ['japanese']),
#  ('udon', ['japanese']),
#  ('unagi', ['japanese']),
#  ('westernjapanese', ['japanese']),
#  ('yakiniku', ['japanese']),
#  ('yakitori', ['japanese']),
#  ('taiyaki', ['jpsweets']),
#  ('dumpsterrental', ['junkremovalandhauling']),
#  ('kitchensupplies', ['kitchenandbath']),
#  ('lawnservices', ['landscaping']),
#  ('colombian', ['latin']),
#  ('salvadoran', ['latin']),
#  ('venezuelan', ['latin']),
#  ('dryclean', ['laundryservices']),
#  ('laundromat', ['laundryservices']),
#  ('bankruptcy', ['lawyers']),
#  ('businesslawyers', ['lawyers']),
#  ('consumerlaw', ['lawyers']),
#  ('contractlaw', ['lawyers']),
#  ('criminaldefense', ['lawyers']),
#  ('disabilitylaw', ['lawyers']),
#  ('divorce', ['lawyers']),
#  ('duilawyers', ['lawyers']),
#  ('elderlaw', ['lawyers']),
#  ('employmentlawyers', ['lawyers']),
#  ('entertainmentlaw', ['lawyers']),
#  ('estateplanning', ['lawyers']),
#  ('general_litigation', ['lawyers']),
#  ('immigrationlawyers', ['lawyers']),
#  ('iplaw', ['lawyers']),
#  ('medicallaw', ['lawyers']),
#  ('personal_injury', ['lawyers']),
#  ('realestatelawyers', ['lawyers']),
#  ('socialsecuritylaw', ['lawyers']),
#  ('taxlaw', ['lawyers']),
#  ('trafficticketinglaw', ['lawyers']),
#  ('workerscomplaw', ['lawyers']),
#  ('courtreporters', ['legalservices']),
#  ('processservers', ['legalservices']),
#  ('parklets', ['localflavor']),
#  ('publicart', ['localflavor']),
#  ('unofficialyelpevents', ['localflavor']),
#  ('yelpevents', ['localflavor']),
#  ('3dprinting', ['localservices']),
#  ('adoptionservices', ['localservices']),
#  ('airductcleaning', ['localservices']),
#  ('appraisalservices', ['localservices']),
#  ('artinstallation', ['localservices']),
#  ('artrestoration', ['localservices']),
#  ('awnings', ['localservices']),
#  ('bailbondsmen', ['localservices']),
#  ('bike_repair_maintenance', ['localservices']),
#  ('biohazardcleanup', ['localservices']),
#  ('bookbinding', ['localservices']),
#  ('busrental', ['localservices']),
#  ('calligraphy', ['localservices']),
#  ('carpet_cleaning', ['localservices']),
#  ('carpetdyeing', ['localservices']),
#  ('childcare', ['localservices']),
#  ('clockrepair', ['localservices']),
#  ('communitybookbox', ['localservices']),
#  ('communitygardens', ['localservices']),
#  ('copyshops', ['localservices']),
#  ('couriers', ['localservices']),
#  ('craneservices', ['localservices']),
#  ('donationcenter', ['localservices']),
#  ('drycleaninglaundry', ['localservices']),
#  ('eldercareplanning', ['localservices']),
#  ('electronicsrepair', ['localservices']),
#  ('elevatorservices', ['localservices']),
#  ('engraving', ['localservices']),
#  ('enviroabatement', ['localservices']),
#  ('environmentaltesting', ['localservices']),
#  ('farmequipmentrepair', ['localservices']),
#  ('fingerprinting', ['localservices']),
#  ('forestry', ['localservices']),
#  ('funeralservices', ['localservices']),
#  ('furniturerepair', ['localservices']),
#  ('generatorinstallrepair', ['localservices']),
#  ('gestorias', ['localservices']),
#  ('grillservices', ['localservices']),
#  ('gunsmith', ['localservices']),
#  ('hazardouswastedisposal', ['localservices']),
#  ('homeappliancerepair', ['localservices']),
#  ('hydrojetting', ['localservices']),
#  ('icedelivery', ['localservices']),
#  ('internetbooth', ['localservices']),
#  ('itservices', ['localservices']),
#  ('jewelryrepair', ['localservices']),
#  ('junkremovalandhauling', ['localservices']),
#  ('junkyards', ['localservices']),
#  ('knifesharpening', ['localservices']),
#  ('laundryservices', ['localservices']),
#  ('machinerental', ['localservices']),
#  ('machineshops', ['localservices']),
#  ('mailboxcenters', ['localservices']),
#  ('metaldetectorservices', ['localservices']),
#  ('metalfabricators', ['localservices']),
#  ('mistingsystemservices', ['localservices']),
#  ('musicinstrumentservices', ['localservices']),
#  ('nannys', ['localservices']),
#  ('nonprofit', ['localservices']),
#  ('notaries', ['localservices']),
#  ('outdoorpowerequipmentservices', ['localservices']),
#  ('pest_control', ['localservices']),
#  ('portabletoiletservices', ['localservices']),
#  ('powdercoating', ['localservices']),
#  ('propane', ['localservices']),
#  ('record_labels', ['localservices']),
#  ('recording_studios', ['localservices']),
#  ('recyclingcenter', ['localservices']),
#  ('rentfurniture', ['localservices']),
#  ('reupholstery', ['localservices']),
#  ('sandblasting', ['localservices']),
#  ('screen_printing_tshirt_printing', ['localservices']),
#  ('screenprinting', ['localservices']),
#  ('selfstorage', ['localservices']),
#  ('septicservices', ['localservices']),
#  ('sewingalterations', ['localservices']),
#  ('shipping_centers', ['localservices']),
#  ('shoerepair', ['localservices']),
#  ('shoeshine', ['localservices']),
#  ('smokingareas', ['localservices']),
#  ('snowremoval', ['localservices']),
#  ('snuggleservices', ['localservices']),
#  ('stonemasons', ['localservices']),
#  ('tvmounting', ['localservices']),
#  ('watch_repair', ['localservices']),
#  ('waterdelivery', ['localservices']),
#  ('welldrilling', ['localservices']),
#  ('wildlifecontrol', ['localservices']),
#  ('youth_club', ['localservices']),
#  ('mamak', ['malaysian']),
#  ('nyonya', ['malaysian']),
#  ('brazilianjiujitsu', ['martialarts']),
#  ('chinesemartialarts', ['martialarts']),
#  ('karate', ['martialarts']),
#  ('kickboxing', ['martialarts']),
#  ('muaythai', ['martialarts']),
#  ('taekwondo', ['martialarts']),
#  ('printmedia', ['massmedia']),
#  ('radiostations', ['massmedia']),
#  ('televisionstations', ['massmedia']),
#  ('bulkbilling', ['medcenters']),
#  ('osteopaths', ['medcenters']),
#  ('walkinclinics', ['medcenters']),
#  ('bookstores', ['media']),
#  ('comicbooks', ['media']),
#  ('mags', ['media']),
#  ('musicvideo', ['media']),
#  ('videoandgames', ['media']),
#  ('videogamestores', ['media']),
#  ('vinyl_records', ['media']),
#  ('aestheticians', ['medicalspa']),
#  ('falafel', ['mediterranean']),
#  ('easternmexican', ['mexican']),
#  ('jaliscan', ['mexican']),
#  ('northernmexican', ['mexican']),
#  ('oaxacan', ['mexican']),
#  ('pueblan', ['mexican']),
#  ('tacos', ['mexican']),
#  ('tamales', ['mexican']),
#  ('yucatan', ['mexican']),
#  ('egyptian', ['mideastern']),
#  ('lebanese', ['mideastern']),
#  ('driveintheater', ['movietheaters']),
#  ('outdoormovies', ['movietheaters']),
#  ('artmuseums', ['museums']),
#  ('childrensmuseums', ['museums']),
#  ('guitarstores', ['musicinstrumentservices']),
#  ('pianoservices', ['musicinstrumentservices']),
#  ('pianostores', ['musicinstrumentservices']),
#  ('vocalcoach', ['musicinstrumentservices']),
#  ('adultentertainment', ['nightlife']),
#  ('barcrawl', ['nightlife']),
#  ('bars', ['nightlife']),
#  ('beergardens', ['nightlife']),
#  ('clubcrawl', ['nightlife']),
#  ('coffeeshops', ['nightlife']),
#  ('comedyclubs', ['nightlife']),
#  ('countrydancehalls', ['nightlife']),
#  ('danceclubs', ['nightlife']),
#  ('dancerestaurants', ['nightlife']),
#  ('fasil', ['nightlife']),
#  ('karaoke', ['nightlife']),
#  ('pianobars', ['nightlife']),
#  ('poolhalls', ['nightlife']),
#  ('foodbanks', ['nonprofit']),
#  ('homelessshelters', ['nonprofit']),
#  ('retinaspecialists', ['opthamalogists']),
#  ('sunglasses', ['opticians']),
#  ('nailtechnicians', ['othersalons']),
#  ('dog_parks', ['parks']),
#  ('skate_parks', ['parks']),
#  ('audiovisualequipmentrental', ['partyequipmentrentals']),
#  ('bouncehouserentals', ['partyequipmentrentals']),
#  ('karaokerental', ['partyequipmentrentals']),
#  ('petboarding', ['pet_sitting']),
#  ('animalshelters', ['pets']),
#  ('horse_boarding', ['pets']),
#  ('petadoption', ['pets']),
#  ('petservices', ['pets']),
#  ('petstore', ['pets']),
#  ('vet', ['pets']),
#  ('animalholistic', ['petservices']),
#  ('animalphysicaltherapy', ['petservices']),
#  ('aquariumservices', ['petservices']),
#  ('dogwalkers', ['petservices']),
#  ('emergencypethospital', ['petservices']),
#  ('farriers', ['petservices']),
#  ('groomer', ['petservices']),
#  ('pet_sitting', ['petservices']),
#  ('pet_training', ['petservices']),
#  ('petbreeders', ['petservices']),
#  ('petcremation', ['petservices']),
#  ('pethospice', ['petservices']),
#  ('petinsurance', ['petservices']),
#  ('petphotography', ['petservices']),
#  ('pettransport', ['petservices']),
#  ('petwasteremoval', ['petservices']),
#  ('birdshops', ['petstore']),
#  ('localfishstores', ['petstore']),
#  ('reptileshops', ['petstore']),
#  ('boudoirphotography', ['photographers']),
#  ('eventphotography', ['photographers']),
#  ('sessionphotography', ['photographers']),
#  ('addictionmedicine', ['physicians']),
#  ('allergist', ['physicians']),
#  ('anesthesiologists', ['physicians']),
#  ('audiologist', ['physicians']),
#  ('cardiology', ['physicians']),
#  ('cosmeticsurgeons', ['physicians']),
#  ('dermatology', ['physicians']),
#  ('earnosethroat', ['physicians']),
#  ('emergencymedicine', ['physicians']),
#  ('endocrinologists', ['physicians']),
#  ('familydr', ['physicians']),
#  ('fertility', ['physicians']),
#  ('gastroenterologist', ['physicians']),
#  ('geneticists', ['physicians']),
#  ('gerontologist', ['physicians']),
#  ('hepatologists', ['physicians']),
#  ('homeopathic', ['physicians']),
#  ('hospitalists', ['physicians']),
#  ('immunodermatologists', ['physicians']),
#  ('infectiousdisease', ['physicians']),
#  ('internalmed', ['physicians']),
#  ('naturopathic', ['physicians']),
#  ('nephrologists', ['physicians']),
#  ('neurologist', ['physicians']),
#  ('neuropathologists', ['physicians']),
#  ('neurotologists', ['physicians']),
#  ('obgyn', ['physicians']),
#  ('oncologist', ['physicians']),
#  ('opthamalogists', ['physicians']),
#  ('orthopedists', ['physicians']),
#  ('osteopathicphysicians', ['physicians']),
#  ('otologists', ['physicians']),
#  ('painmanagement', ['physicians']),
#  ('pathologists', ['physicians']),
#  ('pediatricians', ['physicians']),
#  ('phlebologists', ['physicians']),
#  ('plasticsurgeons', ['physicians']),
#  ('podiatrists', ['physicians']),
#  ('preventivemedicine', ['physicians']),
#  ('proctologist', ['physicians']),
#  ('psychiatrists', ['physicians']),
#  ('pulmonologist', ['physicians']),
#  ('radiologists', ['physicians']),
#  ('rhematologists', ['physicians']),
#  ('spinesurgeons', ['physicians']),
#  ('sportsmed', ['physicians']),
#  ('surgeons', ['physicians']),
#  ('tattooremoval', ['physicians']),
#  ('toxicologists', ['physicians']),
#  ('tropicalmedicine', ['physicians']),
#  ('underseamedicine', ['physicians']),
#  ('urologists', ['physicians']),
#  ('vascularmedicine', ['physicians']),
#  ('backflowservices', ['plumbing']),
#  ('pierogis', ['polish']),
#  ('alentejo', ['portuguese']),
#  ('algarve', ['portuguese']),
#  ('azores', ['portuguese']),
#  ('beira', ['portuguese']),
#  ('fado_houses', ['portuguese']),
#  ('madeira', ['portuguese']),
#  ('minho', ['portuguese']),
#  ('ribatejo', ['portuguese']),
#  ('tras_os_montes', ['portuguese']),
#  ('accountants', ['professional']),
#  ('advertising', ['professional']),
#  ('architects', ['professional']),
#  ('artconsultants', ['professional']),
#  ('billingservices', ['professional']),
#  ('boatrepair', ['professional']),
#  ('bookkeepers', ['professional']),
#  ('businessconsulting', ['professional']),
#  ('careercounseling', ['professional']),
#  ('commissionedartists', ['professional']),
#  ('customsbrokers', ['professional']),
#  ('digitizingservices', ['professional']),
#  ('duplicationservices', ['professional']),
#  ('editorialservices', ['professional']),
#  ('employmentagencies', ['professional']),
#  ('fengshui', ['professional']),
#  ('graphicdesign', ['professional']),
#  ('indoorlandscaping', ['professional']),
#  ('lawyers', ['professional']),
#  ('legalservices', ['professional']),
#  ('lifecoach', ['professional']),
#  ('marketing', ['professional']),
#  ('matchmakers', ['professional']),
#  ('mediators', ['professional']),
#  ('musicproduction', ['professional']),
#  ('officecleaning', ['professional']),
#  ('patentlaw', ['professional']),
#  ('payroll', ['professional']),
#  ('personalassistants', ['professional']),
#  ('privateinvestigation', ['professional']),
#  ('productdesign', ['professional']),
#  ('publicadjusters', ['professional']),
#  ('publicrelations', ['professional']),
#  ('security', ['professional']),
#  ('shredding', ['professional']),
#  ('signmaking', ['professional']),
#  ('softwaredevelopment', ['professional']),
#  ('talentagencies', ['professional']),
#  ('taxidermy', ['professional']),
#  ('tenantlaw', ['professional']),
#  ('translationservices', ['professional']),
#  ('videofilmproductions', ['professional']),
#  ('web_design', ['professional']),
#  ('wholesalers', ['professional']),
#  ('isps', ['professional', 'homeservices']),
#  ('astrologers', ['psychic_astrology']),
#  ('mystics', ['psychic_astrology']),
#  ('psychicmediums', ['psychic_astrology']),
#  ('psychics', ['psychic_astrology']),
#  ('authorized_postal_representative', ['publicservicesgovt']),
#  ('civiccenter', ['publicservicesgovt']),
#  ('communitycenters', ['publicservicesgovt']),
#  ('courthouses', ['publicservicesgovt']),
#  ('departmentsofmotorvehicles', ['publicservicesgovt']),
#  ('embassy', ['publicservicesgovt']),
#  ('firedepartments', ['publicservicesgovt']),
#  ('jailsandprisons', ['publicservicesgovt']),
#  ('landmarks', ['publicservicesgovt']),
#  ('libraries', ['publicservicesgovt']),
#  ('municipality', ['publicservicesgovt']),
#  ('policedepartments', ['publicservicesgovt']),
#  ('postoffices', ['publicservicesgovt']),
#  ('registry_office', ['publicservicesgovt']),
#  ('taxoffice', ['publicservicesgovt']),
#  ('townhall', ['publicservicesgovt']),
#  ('apartments', ['realestate']),
#  ('artspacerentals', ['realestate']),
#  ('commercialrealestate', ['realestate']),
#  ('condominiums', ['realestate']),
#  ('estateliquidation', ['realestate']),
#  ('homedevelopers', ['realestate']),
#  ('homeownerassociation', ['realestate']),
#  ('homestaging', ['realestate']),
#  ('housingcooperatives', ['realestate']),
#  ('kitchenincubators', ['realestate']),
#  ('mobilehomes', ['realestate']),
#  ('mobileparks', ['realestate']),
#  ('mortgagebrokers', ['realestate']),
#  ('propertymgmt', ['realestate']),
#  ('realestateagents', ['realestate']),
#  ('realestatesvcs', ['realestate']),
#  ('sharedofficespaces', ['realestate']),
#  ('university_housing', ['realestate']),
#  ('apartmentagents', ['realestateagents']),
#  ('estatephotography', ['realestatesvcs']),
#  ('landsurveying', ['realestatesvcs']),
#  ('afrobrazilian', ['religiousorgs']),
#  ('buddhist_temples', ['religiousorgs']),
#  ('churches', ['religiousorgs']),
#  ('hindu_temples', ['religiousorgs']),
#  ('mosques', ['religiousorgs']),
#  ('shrines', ['religiousorgs']),
#  ('sikhtemples', ['religiousorgs']),
#  ('spiritism', ['religiousorgs']),
#  ('synagogues', ['religiousorgs']),
#  ('taoisttemples', ['religiousorgs']),
#  ('afghani', ['restaurants']),
#  ('african', ['restaurants']),
#  ('andalusian', ['restaurants']),
#  ('arabian', ['restaurants']),
#  ('argentine', ['restaurants']),
#  ('armenian', ['restaurants']),
#  ('asianfusion', ['restaurants']),
#  ('asturian', ['restaurants']),
#  ('australian', ['restaurants']),
#  ('austrian', ['restaurants']),
#  ('baguettes', ['restaurants']),
#  ('bangladeshi', ['restaurants']),
#  ('basque', ['restaurants']),
#  ('bavarian', ['restaurants']),
#  ('bbq', ['restaurants']),
#  ('beergarden', ['restaurants']),
#  ('beerhall', ['restaurants']),
#  ('beisl', ['restaurants']),
#  ('belgian', ['restaurants']),
#  ('bistros', ['restaurants']),
#  ('blacksea', ['restaurants']),
#  ('brasseries', ['restaurants']),
#  ('brazilian', ['restaurants']),
#  ('breakfast_brunch', ['restaurants']),
#  ('british', ['restaurants']),
#  ('buffets', ['restaurants']),
#  ('bulgarian', ['restaurants']),
#  ('burgers', ['restaurants']),
#  ('burmese', ['restaurants']),
#  ('cafes', ['restaurants']),
#  ('cafeteria', ['restaurants']),
#  ('cajun', ['restaurants']),
#  ('cambodian', ['restaurants']),
#  ('canteen', ['restaurants']),
#  ('caribbean', ['restaurants']),
#  ('catalan', ['restaurants']),
#  ('chech', ['restaurants']),
#  ('cheesesteaks', ['restaurants']),
#  ('chicken_wings', ['restaurants']),
#  ('chickenshop', ['restaurants']),
#  ('chilean', ['restaurants']),
#  ('chinese', ['restaurants']),
#  ('comfortfood', ['restaurants']),
#  ('corsican', ['restaurants']),
#  ('creperies', ['restaurants']),
#  ('cuban', ['restaurants']),
#  ('currysausage', ['restaurants']),
#  ('cypriot', ['restaurants']),
#  ('czech', ['restaurants']),
#  ('czechslovakian', ['restaurants']),
#  ('danish', ['restaurants']),
#  ('delis', ['restaurants']),
#  ('diners', ['restaurants']),
#  ('dinnertheater', ['restaurants']),
#  ('dumplings', ['restaurants']),
#  ('eastern_european', ['restaurants']),
#  ('eritrean', ['restaurants']),
#  ('ethiopian', ['restaurants']),
#  ('filipino', ['restaurants']),
#  ('fischbroetchen', ['restaurants']),
#  ('fishnchips', ['restaurants']),
#  ('flatbread', ['restaurants']),
#  ('fondue', ['restaurants']),
#  ('food_court', ['restaurants']),
#  ('foodstands', ['restaurants']),
#  ('freiduria', ['restaurants']),
#  ('french', ['restaurants']),
#  ('galician', ['restaurants']),
#  ('gamemeat', ['restaurants']),
#  ('gastropubs', ['restaurants']),
#  ('georgian', ['restaurants']),
#  ('german', ['restaurants']),
#  ('giblets', ['restaurants']),
#  ('gluten_free', ['restaurants']),
#  ('greek', ['restaurants']),
#  ('guamanian', ['restaurants']),
#  ('halal', ['restaurants']),
#  ('hawaiian', ['restaurants']),
#  ('heuriger', ['restaurants']),
#  ('himalayan', ['restaurants']),
#  ('hkcafe', ['restaurants']),
#  ('honduran', ['restaurants']),
#  ('hotdog', ['restaurants']),
#  ('hotdogs', ['restaurants']),
#  ('hotpot', ['restaurants']),
#  ('hungarian', ['restaurants']),
#  ('iberian', ['restaurants']),
#  ('indonesian', ['restaurants']),
#  ('indpak', ['restaurants']),
#  ('international', ['restaurants']),
#  ('irish', ['restaurants']),
#  ('island_pub', ['restaurants']),
#  ('israeli', ['restaurants']),
#  ('italian', ['restaurants']),
#  ('japanese', ['restaurants']),
#  ('jewish', ['restaurants']),
#  ('kebab', ['restaurants']),
#  ('kopitiam', ['restaurants']),
#  ('korean', ['restaurants']),
#  ('kosher', ['restaurants']),
#  ('kurdish', ['restaurants']),
#  ('laos', ['restaurants']),
#  ('laotian', ['restaurants']),
#  ('latin', ['restaurants']),
#  ('lyonnais', ['restaurants']),
#  ('malaysian', ['restaurants']),
#  ('meatballs', ['restaurants']),
#  ('mediterranean', ['restaurants']),
#  ('mexican', ['restaurants']),
#  ('mideastern', ['restaurants']),
#  ('milkbars', ['restaurants']),
#  ('modern_australian', ['restaurants']),
#  ('modern_european', ['restaurants']),
#  ('mongolian', ['restaurants']),
#  ('moroccan', ['restaurants']),
#  ('newamerican', ['restaurants']),
#  ('newcanadian', ['restaurants']),
#  ('newmexican', ['restaurants']),
#  ('newzealand', ['restaurants']),
#  ('nicaraguan', ['restaurants']),
#  ('nightfood', ['restaurants']),
#  ('nikkei', ['restaurants']),
#  ('noodles', ['restaurants']),
#  ('norcinerie', ['restaurants']),
#  ('norwegian', ['restaurants']),
#  ('opensandwiches', ['restaurants']),
#  ('oriental', ['restaurants']),
#  ('pakistani', ['restaurants']),
#  ('panasian', ['restaurants']),
#  ('parma', ['restaurants']),
#  ('persian', ['restaurants']),
#  ('peruvian', ['restaurants']),
#  ('pfcomercial', ['restaurants']),
#  ('pita', ['restaurants']),
#  ('pizza', ['restaurants']),
#  ('polish', ['restaurants']),
#  ('polynesian', ['restaurants']),
#  ('popuprestaurants', ['restaurants']),
#  ('portuguese', ['restaurants']),
#  ('potatoes', ['restaurants']),
#  ('poutineries', ['restaurants']),
#  ('pubfood', ['restaurants']),
#  ('raw_food', ['restaurants']),
#  ('riceshop', ['restaurants']),
#  ('romanian', ['restaurants']),
#  ('rotisserie_chicken', ['restaurants']),
#  ('rumanian', ['restaurants']),
#  ('russian', ['restaurants']),
#  ('salad', ['restaurants']),
#  ('sandwiches', ['restaurants']),
#  ('scandinavian', ['restaurants']),
#  ('schnitzel', ['restaurants']),
#  ('scottish', ['restaurants']),
#  ('seafood', ['restaurants']),
#  ('serbocroatian', ['restaurants']),
#  ('signature_cuisine', ['restaurants']),
#  ('singaporean', ['restaurants']),
#  ('slovakian', ['restaurants']),
#  ('somali', ['restaurants']),
#  ('soulfood', ['restaurants']),
#  ('soup', ['restaurants']),
#  ('southern', ['restaurants']),
#  ('spanish', ['restaurants']),
#  ('srilankan', ['restaurants']),
#  ('steak', ['restaurants']),
#  ('sud_ouest', ['restaurants']),
#  ('supperclubs', ['restaurants']),
#  ('sushi', ['restaurants']),
#  ('swabian', ['restaurants']),
#  ('swedish', ['restaurants']),
#  ('swissfood', ['restaurants']),
#  ('syrian', ['restaurants']),
#  ('tabernas', ['restaurants']),
#  ('taiwanese', ['restaurants']),
#  ('tapas', ['restaurants']),
#  ('tapasmallplates', ['restaurants']),
#  ('tavolacalda', ['restaurants']),
#  ('tex-mex', ['restaurants']),
#  ('thai', ['restaurants']),
#  ('tradamerican', ['restaurants']),
#  ('traditional_swedish', ['restaurants']),
#  ('trattorie', ['restaurants']),
#  ('turkish', ['restaurants']),
#  ('ukrainian', ['restaurants']),
#  ('uzbek', ['restaurants']),
#  ('vegan', ['restaurants']),
#  ('vegetarian', ['restaurants']),
#  ('venison', ['restaurants']),
#  ('vietnamese', ['restaurants']),
#  ('waffles', ['restaurants']),
#  ('wok', ['restaurants']),
#  ('wraps', ['restaurants']),
#  ('yugoslav', ['restaurants']),
#  ('adult', ['shopping']),
#  ('antiques', ['shopping']),
#  ('artsandcrafts', ['shopping']),
#  ('auctionhouses', ['shopping']),
#  ('baby_gear', ['shopping']),
#  ('batterystores', ['shopping']),
#  ('bespoke', ['shopping']),
#  ('brewingsupplies', ['shopping']),
#  ('bridal', ['shopping']),
#  ('cannabisdispensaries', ['shopping']),
#  ('cellphoneaccessories', ['shopping']),
#  ('chinesebazaar', ['shopping']),
#  ('computers', ['shopping']),
#  ('concept_shops', ['shopping']),
#  ('custommerchandise', ['shopping']),
#  ('diamondbuyers', ['shopping']),
#  ('discountstore', ['shopping']),
#  ('drones', ['shopping']),
#  ('drugstores', ['shopping']),
#  ('dutyfreeshops', ['shopping']),
#  ('electronics', ['shopping']),
#  ('farmingequipment', ['shopping']),
#  ('fashion', ['shopping']),
#  ('fireworks', ['shopping']),
#  ('fitnessequipment', ['shopping']),
#  ('fleamarkets', ['shopping']),
#  ('flowers', ['shopping']),
#  ('gemstonesandminerals', ['shopping']),
#  ('goldbuyers', ['shopping']),
#  ('golfshops', ['shopping']),
#  ('guns_and_ammo', ['shopping']),
#  ('headshops', ['shopping']),
#  ('hifi', ['shopping']),
#  ('hobbyshops', ['shopping']),
#  ('homeandgarden', ['shopping']),
#  ('horsequipment', ['shopping']),
#  ('jewelry', ['shopping']),
#  ('knittingsupplies', ['shopping']),
#  ('livestocksupply', ['shopping']),
#  ('luggage', ['shopping']),
#  ('marketstalls', ['shopping']),
#  ('media', ['shopping']),
#  ('medicalsupplies', ['shopping']),
#  ('militarysurplus', ['shopping']),
#  ('mobilephones', ['shopping']),
#  ('motorcyclinggear', ['shopping']),
#  ('musicalinstrumentsandteachers', ['shopping']),
#  ('officeequipment', ['shopping']),
#  ('opticians', ['shopping']),
#  ('outlet_stores', ['shopping']),
#  ('packingsupplies', ['shopping']),
#  ('pawn', ['shopping']),
#  ('personal_shopping', ['shopping']),
#  ('photographystores', ['shopping']),
#  ('poolbilliards', ['shopping']),
#  ('popupshops', ['shopping']),
#  ('props', ['shopping']),
#  ('publicmarkets', ['shopping']),
#  ('religiousitems', ['shopping']),
#  ('safestores', ['shopping']),
#  ('safetyequipment', ['shopping']),
#  ('scandinaviandesign', ['shopping']),
#  ('shoppingcenters', ['shopping']),
#  ('shoppingpassages', ['shopping']),
#  ('souvenirs', ['shopping']),
#  ('spiritual_shop', ['shopping']),
#  ('sportgoods', ['shopping']),
#  ('tabletopgames', ['shopping']),
#  ('teachersupplies', ['shopping']),
#  ('thrift_stores', ['shopping']),
#  ('tickets', ['shopping']),
#  ('tobaccoshops', ['shopping']),
#  ('toys', ['shopping']),
#  ('trophyshops', ['shopping']),
#  ('uniforms', ['shopping']),
#  ('usedbooks', ['shopping']),
#  ('vapeshops', ['shopping']),
#  ('vitaminssupplements', ['shopping']),
#  ('watches', ['shopping']),
#  ('wholesale_stores', ['shopping']),
#  ('wigs', ['shopping']),
#  ('perfume', ['shopping', 'beautysvc']),
#  ('deptstores', ['shopping', 'fashion']),
#  ('estheticians', ['skincare']),
#  ('veteransorganizations', ['social_clubs']),
#  ('arroceria_paella', ['spanish']),
#  ('artschools', ['specialtyschools']),
#  ('bartendingschools', ['specialtyschools']),
#  ('cheerleading', ['specialtyschools']),
#  ('childbirthedu', ['specialtyschools']),
#  ('circusschools', ['specialtyschools']),
#  ('cookingschools', ['specialtyschools']),
#  ('cosmetology_schools', ['specialtyschools']),
#  ('cprclasses', ['specialtyschools']),
#  ('dance_schools', ['specialtyschools']),
#  ('dramaschools', ['specialtyschools']),
#  ('driving_schools', ['specialtyschools']),
#  ('duischools', ['specialtyschools']),
#  ('firearmtraining', ['specialtyschools']),
#  ('firstaidclasses', ['specialtyschools']),
#  ('flightinstruction', ['specialtyschools']),
#  ('foodsafety', ['specialtyschools']),
#  ('language_schools', ['specialtyschools']),
#  ('massage_schools', ['specialtyschools']),
#  ('nursingschools', ['specialtyschools']),
#  ('parentingclasses', ['specialtyschools']),
#  ('photoclasses', ['specialtyschools']),
#  ('poledancingclasses', ['specialtyschools']),
#  ('sambaschools', ['specialtyschools']),
#  ('skischools', ['specialtyschools']),
#  ('speechtraining', ['specialtyschools']),
#  ('surfschools', ['specialtyschools']),
#  ('trafficschools', ['specialtyschools']),
#  ('vocation', ['specialtyschools']),
#  ('bikes', ['sportgoods']),
#  ('diveshops', ['sportgoods']),
#  ('golfequipment', ['sportgoods']),
#  ('hockeyequipment', ['sportgoods']),
#  ('huntingfishingsupplies', ['sportgoods']),
#  ('outdoorgear', ['sportgoods']),
#  ('skateshops', ['sportgoods']),
#  ('skishops', ['sportgoods']),
#  ('dancewear', ['sportswear']),
#  ('spraytanning', ['tanning']),
#  ('tanningbeds', ['tanning']),
#  ('cheesetastingclasses', ['tastingclasses']),
#  ('winetasteclasses', ['tastingclasses']),
#  ('tuina', ['tcm']),
#  ('aerialtours', ['tours']),
#  ('architecturaltours', ['tours']),
#  ('arttours', ['tours']),
#  ('beertours', ['tours']),
#  ('biketours', ['tours']),
#  ('boattours', ['tours']),
#  ('bustours', ['tours']),
#  ('foodtours', ['tours']),
#  ('historicaltours', ['tours']),
#  ('scootertours', ['tours']),
#  ('walkingtours', ['tours']),
#  ('whalewatchingtours', ['tours']),
#  ('winetours', ['tours']),
#  ('airlines', ['transport']),
#  ('airport_shuttles', ['transport']),
#  ('bikesharing', ['transport']),
#  ('buses', ['transport']),
#  ('busstations', ['transport']),
#  ('cablecars', ['transport']),
#  ('dolmusstation', ['transport']),
#  ('ferries', ['transport']),
#  ('limos', ['transport']),
#  ('metrostations', ['transport']),
#  ('pedicabs', ['transport']),
#  ('privatejetcharter', ['transport']),
#  ('publictransport', ['transport']),
#  ('sharedtaxis', ['transport']),
#  ('taxis', ['transport']),
#  ('towncarservice', ['transport']),
#  ('trains', ['transport']),
#  ('watertaxis', ['transport']),
#  ('luggagestorage', ['travelservices']),
#  ('passportvisaservices', ['travelservices']),
#  ('travelagents', ['travelservices']),
#  ('visitorcenters', ['travelservices']),
#  ('cheekufta', ['turkish']),
#  ('gozleme', ['turkish']),
#  ('homemadefood', ['turkish']),
#  ('lahmacun', ['turkish']),
#  ('ottomancuisine', ['turkish']),
#  ('turkishravioli', ['turkish']),
#  ('electricitysuppliers', ['utilities']),
#  ('naturalgassuppliers', ['utilities']),
#  ('watersuppliers', ['utilities']),
#  ('suppliesrestaurant', ['wholesalers']),
#  ('winetastingroom', ['wineries']),
#  ('pettingzoos', ['zoos'])]

# %% [markdown]
# #### Parent aliases we may want:
# 'parent_aliases': active, arts, bars, breweries, festivals, fitness, food, museums, nightlife, restaurants, tours, wineries, zoos

# %%
# Confirm Category Parent Aliases sorted and unique values only
import requests
import json

url = "https://api.yelp.com/v3/categories"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
}

response = requests.get(url, headers=headers)

data = json.loads(response.text)

categories = [category['parent_aliases'] for category in data['categories']]
categories_unique_sorted = sorted(set(sum(categories, [])))

for category in categories_unique_sorted:
    print(category)
# Out:
# active
# adultentertainment
# african
# airports
# arabian
# artclasses
# arts
# artsandcrafts
# auto
# autoglass
# autopartssupplies
# autorepair
# bars
# beautysvc
# belgian
# bicycles
# brazilian
# breakfast_brunch
# breweries
# c_and_mh
# cafes
# cannabis_clinics
# caribbean
# chinese
# crisispregnancycenters
# dentalhygienists
# dentists
# diagnosticservices
# diving
# donburi
# education
# estateplanning
# eventservices
# farms
# fashion
# festivals
# financialservices
# fitness
# flowers
# food
# french
# funeralservices
# gardening
# german
# gourmet
# gyms
# hair
# hairremoval
# health
# homeandgarden
# homeservices
# hotels
# hotelstravel
# insurance
# italian
# itservices
# japanese
# jpsweets
# junkremovalandhauling
# kitchenandbath
# landscaping
# latin
# laundryservices
# lawyers
# legalservices
# localflavor
# localservices
# malaysian
# martialarts
# massmedia
# medcenters
# media
# medicalspa
# mediterranean
# mexican
# mideastern
# movietheaters
# museums
# musicinstrumentservices
# nightlife
# nonprofit
# opthamalogists
# opticians
# othersalons
# parks
# partyequipmentrentals
# pet_sitting
# pets
# petservices
# petstore
# photographers
# physicians
# plumbing
# polish
# portuguese
# professional
# psychic_astrology
# publicservicesgovt
# realestate
# realestateagents
# realestatesvcs
# religiousorgs
# restaurants
# shopping
# skincare
# social_clubs
# spanish
# specialtyschools
# sportgoods
# sportswear
# tanning
# tastingclasses
# tcm
# tours
# transport
# travelservices
# turkish
# utilities
# wholesalers
# wineries
# zoos

# %% [markdown]
# ### Active Data Pulls

# %% [markdown]
# ## Denver

# %%
# Active
# Data Pull for Denver Active Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=active&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_active_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Arts
# Data Pull for Denver Arts Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_arts_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Bars
# Data Pull for Denver Bars Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=bars&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_bars_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Breweries
# Data Pull for Denver Breweries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=breweries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_breweries_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Festivals
# Data Pull for Denver Festivals Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=festivals&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_festivals_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Fitness
# Data Pull for Denver Fitness Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=fitness&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_fitness_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Food
# Data Pull for Denver Food Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=food&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_food_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Museums
# Data Pull for Denver Museums Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=museums&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_museums_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Nightlife
# Data Pull for Denver Nightlife Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=nightlife&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_nightlife_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Restaurants
# Data Pull for Denver Restaurants: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):    
        import requests

        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=restaurants&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_restaurant_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Tours
# Data Pull for Denver Tours Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=tours&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_tours_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Wineries
# Data Pull for Denver Wineries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=wineries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_wineries_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Zoos
# Data Pull for Denver Zoos Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=zoos&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_zoos_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %% [markdown]
# #### (End of Denver Pulls)

# %% [markdown]
# ## Miami

# %%
# Active
# Data Pull for Miami Active Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=active&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_active_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Arts
# Data Pull for Miami Arts Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_arts_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Bars
# Data Pull for Miami Bars Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=bars&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_bars_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Breweries
# Data Pull for Miami Breweries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_arts_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Festivals
# Data Pull for Miami Festivals Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=festivals&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_festivals_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Fitness
# Data Pull for Miami Fitness Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=fitness&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_fitness_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Food
# Data Pull for Miami Arts Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_arts_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Museums
# Data Pull for Miami Museums Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=museums&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_museums_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Nightlife
# Data Pull for Miami Nightlife Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=nightlife&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_nightlife_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Restaurants
# Data Pull for Miami Restaurants: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):    
        import requests

        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=restaurants&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_restaurant_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Tours
# Data Pull for Miami Tours Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=tours&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_tours_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Wineries
# Data Pull for Miami Wineries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=wineries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_wineries_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Zoos
# Data Pull for Miami Zoos Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=zoos&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_zoos_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %% [markdown]
# #### (End of Miami Pulls)

# %% [markdown]
# ## New York

# %%
# Active
# Data Pull for New York Active Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=active&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_active_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Bars
# Data Pull for New York Bars Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=bars&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_bars_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Breweries
# Data Pull for New York Breweries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=breweries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_breweries_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Festivals
# Data Pull for New York Festivals Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=festivals&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_festivals_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Fitness
# Data Pull for New York Fitness Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=fitness&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_fitness_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Food
# Data Pull for New York Food Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=food&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_food_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Museums
# Data Pull for New York Museums Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=museums&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_museums_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Nightlife
# Data Pull for New York Nightlife Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=nightlife&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_nightlife_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Restaurants
# Data Pull for New York Restaurants: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):    
        import requests

        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=restaurants&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("restaurant_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Tours
# Data Pull for New York Tours Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=tours&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_tours_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Wineries
# Data Pull for New York Wineries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=wineries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_wineries_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Zoos
# Data Pull for New York Zoos Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=zoos&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_zoos_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %% [markdown]
# #### (End of New York Pulls)

# %%
import json
import pprint as pp
#import psycopg2

file_path = '/Users/josesantos/LearnPython/BCGit/G4_Project4/Denver_arts_response_fixedcopy.txt'

# Open the text file containing the JSON data
with open(file_path, 'r') as file:
    json_data = file.read()

# Parse the JSON data
data = json.loads(json_data)
#pp.pprint(data)
data
# Out:
# {'businesses': [{'id': 'L1QXBchHoza6rEjqx-87RA',
#    'alias': 'medium-kimberly-denver',
#    'name': 'Medium Kimberly ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/S0_FgdTl0f_qzWXgHMVtmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/medium-kimberly-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 5,
#    'categories': [{'alias': 'psychicmediums', 'title': 'Psychic Mediums'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.73367, 'longitude': -104.99736},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80204',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['Denver, CO 80204']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4819.97350529954},
#   {'id': 'KwFEBgDC_cvVvAHJ_CKD7A',
#    'alias': 'lea-marlene-actors-studio-and-the-namastage-theatre-denver',
#    'name': 'Lea Marlene Actors Studio & The Namastage Theatre',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gO3-HsptJbrSUJd2WKYmDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lea-marlene-actors-studio-and-the-namastage-theatre-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 5,
#    'categories': [{'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'dramaschools', 'title': 'Drama Schools'},
#     {'alias': 'videofilmproductions', 'title': 'Video/Film Production'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.747921, 'longitude': -104.9784441},
#    'transactions': [],
#    'location': {'address1': '119 Park Ave W',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80205',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['119 Park Ave W', 'Denver, CO 80205']},
#    'phone': '+17206382612',
#    'display_phone': '(720) 638-2612',
#    'distance': 1546.4651959262935},
#   {'id': 'WhAD9eZndK3xbFpIPqeFYQ',
#    'alias': 'the-dance-art-media-studios-littleton',
#    'name': 'The Dance Art Media Studios',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IKQ664XV3GkkbQFgB4UJWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-dance-art-media-studios-littleton?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 5,
#    'categories': [{'alias': 'dancestudio', 'title': 'Dance Studios'},
#     {'alias': 'theater', 'title': 'Performing Arts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.6081044, 'longitude': -105.0976659},
#    'transactions': [],
#    'location': {'address1': '8996 West Bowles Ave',
#     'address2': 'Unit K2',
#     'address3': None,
#     'city': 'Littleton',
#     'zip_code': '80123',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['8996 West Bowles Ave',
#      'Unit K2',
#      'Littleton, CO 80123']},
#    'phone': '+13039796419',
#    'display_phone': '(303) 979-6419',
#    'distance': 17879.54284033615},
#   {'id': 'HHv2fah0WapIL8Kche3AHQ',
#    'alias': 'wonderbound-denver-2',
#    'name': 'Wonderbound',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AoLS0b6fYQqQvFwlA39CHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wonderbound-denver-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 6,
#    'categories': [{'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'dancestudio', 'title': 'Dance Studios'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.773672666, 'longitude': -104.95555183},
#    'transactions': [],
#    'location': {'address1': '2535 E 40th Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Denver',
#     'zip_code': '80205',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['2535 E 40th Ave', 'Denver, CO 80205']},
#    'phone': '+13032924700',
#    'display_phone': '(303) 292-4700',
#    'distance': 4456.443205259131},
#   {'id': 'bTx_XCtBCxFDgGPBsQS3Jg',
#    'alias': 'blizzard-mountain-pinball-conifer',
#    'name': 'Blizzard Mountain Pinball',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6p_Y8tmPbAL3rMPBrui8wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blizzard-mountain-pinball-conifer?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 14,
#    'categories': [{'alias': 'arcades', 'title': 'Arcades'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.54317, 'longitude': -105.2945},
#    'transactions': [],
#    'location': {'address1': '25797 Conifer Rd',
#     'address2': 'Ste C-206',
#     'address3': '',
#     'city': 'Conifer',
#     'zip_code': '80433',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['25797 Conifer Rd', 'Ste C-206', 'Conifer, CO 80433']},
#    'phone': '+17207672549',
#    'display_phone': '(720) 767-2549',
#    'distance': 35012.815045627016},
#   {'id': 'xlr3wTVEGSamDPmQt-9WeQ',
#    'alias': 'theatre-of-dreams-castle-rock-2',
#    'name': 'Theatre of Dreams',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/E4NyX3pasgNNDPb7KqCiyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/theatre-of-dreams-castle-rock-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 9,
#    'categories': [{'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'eventplanning', 'title': 'Party & Event Planning'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.3773193, 'longitude': -104.8660126},
#    'transactions': [],
#    'location': {'address1': '735 Park St',
#     'address2': '',
#     'address3': '',
#     'city': 'Castle Rock',
#     'zip_code': '80109',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['735 Park St', 'Castle Rock, CO 80109']},
#    'phone': '+13036606799',
#    'display_phone': '(303) 660-6799',
#    'distance': 40842.20708779979},
#   {'id': '2IGjH4ry4n_EuSLMl1QwpQ',
#    'alias': 'corkscrews-wine-storage-denver',
#    'name': 'Corkscrews Wine Storage',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/huKSVlgfc_GbSW3bUlUe6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/corkscrews-wine-storage-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 6,
#    'categories': [{'alias': 'selfstorage', 'title': 'Self Storage'},
#     {'alias': 'winetastingroom', 'title': 'Wine Tasting Room'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.7352467, 'longitude': -105.011678},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1845 W 12th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80204',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['1845 W 12th Ave', 'Denver, CO 80204']},
#    'phone': '+17209162270',
#    'display_phone': '(720) 916-2270',
#    'distance': 3543.0123395965747},
#   {'id': 'zhAp2QCm0v_35CuskE4ggA',
#    'alias': 'professor-phelyx-denver',
#    'name': 'Professor Phelyx',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/22lUw25anwmHV5vrgulswQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/professor-phelyx-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 5,
#    'categories': [{'alias': 'magicians', 'title': 'Magicians'},
#     {'alias': 'theater', 'title': 'Performing Arts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.7510795593262,
#     'longitude': -104.988929748535},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80201',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['Denver, CO 80201']},
#    'phone': '+13039812787',
#    'display_phone': '(303) 981-2787',
#    'distance': 2333.1788413504746},
#   {'id': '_4uDNmjoVhiLqPDVtBsVMw',
#    'alias': 'walker-fine-art-denver',
#    'name': 'Walker Fine Art',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Inb0hEZ5KpHKEH1hX2tJNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/walker-fine-art-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 16,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.7334785461426,
#     'longitude': -104.992027282715},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '300 W 11th Ave',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80204',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['300 W 11th Ave', 'Ste A', 'Denver, CO 80204']},
#    'phone': '+13033558955',
#    'display_phone': '(303) 355-8955',
#    'distance': 1862.7259259783498},
#   {'id': 'A5Agg5CwZWeto_F5p5gwRg',
#    'alias': 'molly-brown-summer-house-denver',
#    'name': 'Molly Brown Summer House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9GG96ROlLY8gxJtk_NBoEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/molly-brown-summer-house-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 6,
#    'categories': [{'alias': 'museums', 'title': 'Museums'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.6681480407715,
#     'longitude': -105.081100463867},
#    'transactions': [],
#    'location': {'address1': '2690 S Wadsworth Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80227',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['2690 S Wadsworth Blvd', 'Denver, CO 80227']},
#    'phone': '+17202538349',
#    'display_phone': '(720) 253-8349',
#    'distance': 12087.762825993468},
#   {'id': '2y7rHpUStsNnl5YGNJstrg',
#    'alias': 'kristie-latimore-tattoos-and-fine-art-lakewood',
#    'name': 'Kristie Latimore Tattoos and Fine Art',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cWlbaOnYlvSKbrvQVXRNnQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kristie-latimore-tattoos-and-fine-art-lakewood?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 8,
#    'categories': [{'alias': 'arts', 'title': 'Arts & Entertainment'},
#     {'alias': 'tattoo', 'title': 'Tattoo'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.740031, 'longitude': -105.093997},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '8642 West Colfax Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Lakewood',
#     'zip_code': '80215',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['8642 West Colfax Ave', 'Lakewood, CO 80215']},
#    'phone': '+17202095265',
#    'display_phone': '(720) 209-5265',
#    'distance': 10593.413920522959},
#   {'id': 'gZyRXn9QKVx8eq1OAKP0Kg',
#    'alias': 'all-its-own-lakewood',
#    'name': 'All Its Own',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/90AiiMczuk_6UbDhPCTJxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/all-its-own-lakewood?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 5,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'homedecor', 'title': 'Home Decor'},
#     {'alias': 'giftshops', 'title': 'Gift Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.7399897, 'longitude': -105.0793512},
#    'transactions': [],
#    'location': {'address1': '7310 W Colfax Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Lakewood',
#     'zip_code': '80214',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['7310 W Colfax Ave', 'Lakewood, CO 80214']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 9342.452258024754},
#   {'id': 'VzvaNixpHf6CsvOWQxJOHw',
#    'alias': 'cosmic-tea-greenwood-village',
#    'name': 'Cosmic Tea',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JdY4IMI-s0UfnPuWBJtKaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cosmic-tea-greenwood-village?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 14,
#    'categories': [{'alias': 'psychics', 'title': 'Psychics'},
#     {'alias': 'spiritual_shop', 'title': 'Spiritual Shop'},
#     {'alias': 'reiki', 'title': 'Reiki'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.61015, 'longitude': -104.886821},
#    'transactions': [],
#    'location': {'address1': '8775 E Orchard Rd',
#     'address2': 'Ste 821',
#     'address3': '',
#     'city': 'Greenwood Village',
#     'zip_code': '80111',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['8775 E Orchard Rd',
#      'Ste 821',
#      'Greenwood Village, CO 80111']},
#    'phone': '+17205027732',
#    'display_phone': '(720) 502-7732',
#    'distance': 15662.269376248732},
#   {'id': '3As3OBcT2fiX5SkLtPWCgA',
#    'alias': 'bella-luna-gifts-and-gallery-denver',
#    'name': 'Bella Luna Gifts & Gallery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/z0491mQhwVrrCwGR7Ov1FQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bella-luna-gifts-and-gallery-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 5,
#    'categories': [{'alias': 'antiques', 'title': 'Antiques'},
#     {'alias': 'giftshops', 'title': 'Gift Shops'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.74787, 'longitude': -104.97372},
#    'transactions': [],
#    'location': {'address1': '2045 Downing St',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80205',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['2045 Downing St', 'Denver, CO 80205']},
#    'phone': '+13035079118',
#    'display_phone': '(303) 507-9118',
#    'distance': 1404.1341598528643},
#   {'id': 'qwli4jLWn6VRNurYaZ7yaw',
#    'alias': 'peak-acting-studios-centennial',
#    'name': 'PEAK Acting Studios',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9ZbuJfyXQE-UhdkoDLbFiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peak-acting-studios-centennial?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 5,
#    'categories': [{'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'specialtyschools', 'title': 'Specialty Schools'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.5920989, 'longitude': -104.8880452},
#    'transactions': [],
#    'location': {'address1': '6841 S Yosemite St',
#     'address2': 'Ste 1-B',
#     'address3': '',
#     'city': 'Centennial',
#     'zip_code': '80112',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['6841 S Yosemite St',
#      'Ste 1-B',
#      'Centennial, CO 80112']},
#    'phone': '+17202950504',
#    'display_phone': '(720) 295-0504',
#    'distance': 17431.326821874398},
#   {'id': 'ejkZSRMkLBkVXZIy8yvvew',
#    'alias': 'soul-to-soul-intuitive-healing-lafayette',
#    'name': 'Soul to Soul Intuitive Healing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PCcFeVazB9Jx52qAyqzgAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soul-to-soul-intuitive-healing-lafayette?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 13,
#    'categories': [{'alias': 'psychic_astrology',
#      'title': 'Supernatural Readings'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.98814, 'longitude': -105.09758},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': None,
#     'address3': '',
#     'city': 'Lafayette',
#     'zip_code': '80026',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['Lafayette, CO 80026']},
#    'phone': '+13035891531',
#    'display_phone': '(303) 589-1531',
#    'distance': 30453.698069896054},
#   {'id': 'IMv5xMx_dW0dGba1MEzyxQ',
#    'alias': 'framed-image-denver-2',
#    'name': 'Framed Image',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NDScqGdr4gNq_6SjglCSrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/framed-image-denver-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 7,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'framing', 'title': 'Framing'},
#     {'alias': 'artrestoration', 'title': 'Art Restoration'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.65267, 'longitude': -104.92819},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '5066 E Hampden Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80222',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['5066 E Hampden Ave', 'Denver, CO 80222']},
#    'phone': '+13036920727',
#    'display_phone': '(303) 692-0727',
#    'distance': 9895.482520427333},
#   {'id': 'Spgt-QNJ9z-iPuO0x1jDHA',
#    'alias': 'my-paint-your-place-parker',
#    'name': 'My Paint Your Place',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/asC_zeJyJmxxNxqj7a7NCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-paint-your-place-parker?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 6,
#    'categories': [{'alias': 'paintandsip', 'title': 'Paint & Sip'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.5218437, 'longitude': -104.6901344},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'Parker',
#     'zip_code': '80138',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['Parker, CO 80138']},
#    'phone': '+13039069231',
#    'display_phone': '(303) 906-9231',
#    'distance': 33764.2093012323},
#   {'id': '2zbjs8H7J1B-Ci3c7dUV9w',
#    'alias': 'board-and-brush-westminster-westminster',
#    'name': 'Board & Brush Westminster',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/edtFlQfASa0tt1LDRy2Q7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/board-and-brush-westminster-westminster?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 8,
#    'categories': [{'alias': 'homedecor', 'title': 'Home Decor'},
#     {'alias': 'paintandsip', 'title': 'Paint & Sip'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.85542333, 'longitude': -105.05987167},
#    'transactions': [],
#    'location': {'address1': '5674 W 88th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Westminster',
#     'zip_code': '80031',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['5674 W 88th Ave', 'Westminster, CO 80031']},
#    'phone': '+17206295567',
#    'display_phone': '(720) 629-5567',
#    'distance': 15354.302427975794},
#   {'id': 'Jbw5f5tvTyvdTyNlTEXAqQ',
#    'alias': 'wine-dispensary-denver',
#    'name': 'Wine Dispensary',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XnHlvEj7q3kY5od2dUf7YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wine-dispensary-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 9,
#    'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#     {'alias': 'winetastingroom', 'title': 'Wine Tasting Room'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.754641, 'longitude': -105.004926},
#    'transactions': [],
#    'location': {'address1': '1590 Little Raven St',
#     'address2': 'Ste 175',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80202',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['1590 Little Raven St',
#      'Ste 175',
#      'Denver, CO 80202']},
#    'phone': '+13038328007',
#    'display_phone': '(303) 832-8007',
#    'distance': 3648.3385720399274},
#   {'id': 'JZFf25jETHTThTwP4C8N4Q',
#    'alias': 'intuitive-tarot-with-maxim-estes-park',
#    'name': 'Intuitive Tarot With Maxim',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yloaX-T6bISxHXOQjQlGgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/intuitive-tarot-with-maxim-estes-park?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 8,
#    'categories': [{'alias': 'psychic_astrology',
#      'title': 'Supernatural Readings'},
#     {'alias': 'spiritual_shop', 'title': 'Spiritual Shop'},
#     {'alias': 'lifecoach', 'title': 'Life Coach'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.3738403320312,
#     'longitude': -105.51602935791},
#    'transactions': [],
#    'location': {'address1': None,
#     'address2': None,
#     'address3': '',
#     'city': 'Estes Park',
#     'zip_code': '80517',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['Estes Park, CO 80517']},
#    'phone': '+13109931684',
#    'display_phone': '(310) 993-1684',
#    'distance': 85402.11870531141},
#   {'id': 'TuAGGr6y4opJrxV3Yd-wpw',
#    'alias': 'earth-feather-healings-longmont',
#    'name': 'Earth Feather Healings',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dZXu3ivOXxrOgyN9k2k9Pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/earth-feather-healings-longmont?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 13,
#    'categories': [{'alias': 'reiki', 'title': 'Reiki'},
#     {'alias': 'psychic_astrology', 'title': 'Supernatural Readings'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.1666627496544,
#     'longitude': -105.102164782584},
#    'transactions': [],
#    'location': {'address1': '440 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Longmont',
#     'zip_code': '80501',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['440 Main St', 'Longmont, CO 80501']},
#    'phone': '+17204906171',
#    'display_phone': '(720) 490-6171',
#    'distance': 49241.50560495546},
#   {'id': '0jQx2wOlmiXvDB4Zl-k7dA',
#    'alias': 'soothe-your-soul-healing-arts-studio-denver',
#    'name': 'Soothe Your Soul Healing Arts Studio',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/j_HJgNKVa3oE0qmf3nvUZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soothe-your-soul-healing-arts-studio-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 6,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'psychic_astrology', 'title': 'Supernatural Readings'},
#     {'alias': 'reiki', 'title': 'Reiki'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.7512012, 'longitude': -105.0346191},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '23RD Ave And Lowell Blvd',
#     'address2': '',
#     'address3': 'Highlands, Northwest',
#     'city': 'Denver',
#     'zip_code': '80211',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['23RD Ave And Lowell Blvd',
#      'Highlands, Northwest',
#      'Denver, CO 80211']},
#    'phone': '+13038421210',
#    'display_phone': '(303) 842-1210',
#    'distance': 5773.376109122586},
#   {'id': 'wyGf_dH7AEvEuwZV_Zlk8g',
#    'alias': 'guitar-instruction-by-brian-littleton-2',
#    'name': 'Guitar Instruction By Brian',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/t9A7Wktu4OTM00ftM63QVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/guitar-instruction-by-brian-littleton-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 10,
#    'categories': [{'alias': 'musicalinstrumentsandteachers',
#      'title': 'Musical Instruments & Teachers'},
#     {'alias': 'theater', 'title': 'Performing Arts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.5724113, 'longitude': -104.9868426},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '7950 S Lincoln St',
#     'address2': 'Ste 111-B',
#     'address3': '',
#     'city': 'Littleton',
#     'zip_code': '80122',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['7950 S Lincoln St',
#      'Ste 111-B',
#      'Littleton, CO 80122']},
#    'phone': '+13038032181',
#    'display_phone': '(303) 803-2181',
#    'distance': 18192.88004127548},
#   {'id': 'v08hXM4NX4sYBIXOqy4Svg',
#    'alias': 'crafty-chassis-denver',
#    'name': 'Crafty Chassis',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7s24EFGDu8KJg-vbzzyPxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crafty-chassis-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 7,
#    'categories': [{'alias': 'artclasses', 'title': 'Art Classes'},
#     {'alias': 'teambuilding', 'title': 'Team Building Activities'},
#     {'alias': 'arts', 'title': 'Arts & Entertainment'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.71643, 'longitude': -104.99434},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': None,
#     'city': 'Denver',
#     'zip_code': '80223',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['Denver, CO 80223']},
#    'phone': '+13033788536',
#    'display_phone': '(303) 378-8536',
#    'distance': 4779.166265994421},
#   {'id': 'GVoADhmcVwZ84G_QF-WoJg',
#    'alias': 'mirada-fine-art-gallery-denver-2',
#    'name': 'Mirada Fine Art Gallery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xEhUq7EiA5EgNV-wxC5b3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mirada-fine-art-gallery-denver-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 8,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.748850083471574,
#     'longitude': -104.9991599097848},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1331 15th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80202',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['1331 15th St', 'Denver, CO 80202']},
#    'phone': '+13036979006',
#    'display_phone': '(303) 697-9006',
#    'distance': 2882.274808944794},
#   {'id': 'eGG-VZO_otjm-kIFm5qnWA',
#    'alias': 'alchemy-of-light-arvada-3',
#    'name': 'Alchemy of Light',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2ZBikS9o85nvG92Tq5q2tQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alchemy-of-light-arvada-3?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 13,
#    'categories': [{'alias': 'psychic_astrology',
#      'title': 'Supernatural Readings'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#     {'alias': 'reiki', 'title': 'Reiki'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.796043, 'longitude': -105.056364},
#    'transactions': [],
#    'location': {'address1': '5511 W 56th Ave',
#     'address2': 'Ste 130',
#     'address3': '',
#     'city': 'Arvada',
#     'zip_code': '80002',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['5511 W 56th Ave', 'Ste 130', 'Arvada, CO 80002']},
#    'phone': '+17207498325',
#    'display_phone': '(720) 749-8325',
#    'distance': 9973.18254046506},
#   {'id': 'FghMQgSixTzHd3WBHIy4MQ',
#    'alias': 'cynthia-rose-medium-denver',
#    'name': 'Cynthia Rose Medium',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qSgvq5rstIAmrRJMxvCLgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cynthia-rose-medium-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 8,
#    'categories': [{'alias': 'psychicmediums', 'title': 'Psychic Mediums'},
#     {'alias': 'astrologers', 'title': 'Astrologers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.6682515, 'longitude': -105.096661},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': None,
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80227',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['Denver, CO 80227']},
#    'phone': '+13035252007',
#    'display_phone': '(303) 525-2007',
#    'distance': 13149.88799519925},
#   {'id': '0OODLolnxC8318Qg8s370A',
#    'alias': 'tibet-gallery-boulder-2',
#    'name': 'Tibet Gallery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iiVpmZQ2pyYdthhhqmOsnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tibet-gallery-boulder-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 6,
#    'categories': [{'alias': 'rugs', 'title': 'Rugs'},
#     {'alias': 'jewelry', 'title': 'Jewelry'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.01622, 'longitude': -105.28383},
#    'transactions': [],
#    'location': {'address1': '1909 9th St',
#     'address2': 'Ste 120',
#     'address3': None,
#     'city': 'Boulder',
#     'zip_code': '80302',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['1909 9th St', 'Ste 120', 'Boulder, CO 80302']},
#    'phone': '+13034020140',
#    'display_phone': '(303) 402-0140',
#    'distance': 41122.8399518271},
#   {'id': 'nlDiLEpboBKnpcjulYRnvQ',
#    'alias': 'custom-singing-telegrams-denver',
#    'name': 'Custom Singing Telegrams',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NYqyrv4cYyOW1V3CrZMHxQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/custom-singing-telegrams-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 27,
#    'categories': [{'alias': 'theater', 'title': 'Performing Arts'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.676419, 'longitude': -104.92155},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80206',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['Denver, CO 80206']},
#    'phone': '+13039318466',
#    'display_phone': '(303) 931-8466',
#    'distance': 7781.172169595504},
#   {'id': 'ugiyyxL6P9R_K98pX7l9IQ',
#    'alias': 'tm-ballroom-dance-studio-lakewood',
#    'name': 'TM Ballroom Dance Studio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NLcqD88Oqjbs9CPnQBdwCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tm-ballroom-dance-studio-lakewood?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 19,
#    'categories': [{'alias': 'dancestudio', 'title': 'Dance Studios'},
#     {'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'dance_schools', 'title': 'Dance Schools'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.7033815, 'longitude': -105.1363626},
#    'transactions': [],
#    'location': {'address1': '12354 W Alameda Pkwy',
#     'address2': 'Ste 170',
#     'address3': '',
#     'city': 'Lakewood',
#     'zip_code': '80228',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['12354 W Alameda Pkwy',
#      'Ste 170',
#      'Lakewood, CO 80228']},
#    'phone': '+13039973486',
#    'display_phone': '(303) 997-3486',
#    'distance': 14650.509185023682},
#   {'id': 'Qe5M1v2lr-8jwE0Q0_8T_A',
#    'alias': 'kate-spry-spry-supernatural-highlands-ranch-2',
#    'name': 'Kate Spry - Spry Supernatural',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OGLEh1pVfI_P0MiMk0j8Vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kate-spry-spry-supernatural-highlands-ranch-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 6,
#    'categories': [{'alias': 'lifecoach', 'title': 'Life Coach'},
#     {'alias': 'psychicmediums', 'title': 'Psychic Mediums'},
#     {'alias': 'psychics', 'title': 'Psychics'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.544898, 'longitude': -104.990783},
#    'transactions': [],
#    'location': {'address1': '34 Burgundy Ct',
#     'address2': '',
#     'address3': '',
#     'city': 'Highlands Ranch',
#     'zip_code': '80126',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['34 Burgundy Ct', 'Highlands Ranch, CO 80126']},
#    'phone': '+17202537339',
#    'display_phone': '(720) 253-7339',
#    'distance': 21270.242641969275},
#   {'id': '6e3SRKMd4EgusCLUDyIV0Q',
#    'alias': 'potters-touch-westminster',
#    'name': "Potter's Touch",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Z7NiAfLN4eVNToISXpKl_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/potters-touch-westminster?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 8,
#    'categories': [{'alias': 'paintandsip', 'title': 'Paint & Sip'},
#     {'alias': 'artsupplies', 'title': 'Art Supplies'},
#     {'alias': 'paintyourownpottery', 'title': 'Paint-Your-Own Pottery'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.900552, 'longitude': -105.052229},
#    'transactions': [],
#    'location': {'address1': '5191 W 112th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Westminster',
#     'zip_code': '80031',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['5191 W 112th Ave', 'Westminster, CO 80031']},
#    'phone': '+17209494569',
#    'display_phone': '(720) 949-4569',
#    'distance': 19640.26299710269},
#   {'id': 'hcD2uQsMzIumY46zV2h-PA',
#    'alias': 'alliancevr-aurora-2',
#    'name': 'AllianceVR',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LhXiMB3I0Cq_myPHPrXBHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alliancevr-aurora-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 5,
#    'categories': [{'alias': 'arcades', 'title': 'Arcades'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.66464, 'longitude': -104.86162},
#    'transactions': [],
#    'location': {'address1': '2851 S Parker Rd',
#     'address2': 'Ste 240',
#     'address3': '',
#     'city': 'Aurora',
#     'zip_code': '80014',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['2851 S Parker Rd', 'Ste 240', 'Aurora, CO 80014']},
#    'phone': '+13035511595',
#    'display_phone': '(303) 551-1595',
#    'distance': 12219.720630812371},
#   {'id': 'gyWOAVC8sbBFRe_9bPenIg',
#    'alias': '5280-custom-framing-denver-3',
#    'name': '5280 Custom Framing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AQL90J3XMnPGmV3TZH_eTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/5280-custom-framing-denver-3?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 29,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'framing', 'title': 'Framing'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.7498687, 'longitude': -105.0010963},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1528 15th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80202',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['1528 15th St', 'Denver, CO 80202']},
#    'phone': '+13036237263',
#    'display_phone': '(303) 623-7263',
#    'distance': 3082.519538916245},
#   {'id': 'SkSfSSM3srBgpboUvNnPBQ',
#    'alias': 'best-tours-of-denver-denver',
#    'name': 'Best Tours of Denver',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5iRBtGRvJfeEPDBi9cmynA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/best-tours-of-denver-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 24,
#    'categories': [{'alias': 'historicaltours', 'title': 'Historical Tours'},
#     {'alias': 'walkingtours', 'title': 'Walking Tours'},
#     {'alias': 'hauntedhouses', 'title': 'Haunted Houses'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.7312126159668,
#     'longitude': -104.98225402832},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': None,
#     'city': 'Denver',
#     'zip_code': '80203',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['Denver, CO 80203']},
#    'phone': '+17203659464',
#    'display_phone': '(720) 365-9464',
#    'distance': 1167.8232974182863},
#   {'id': 'QcehndoyQgVN94PzteqsMw',
#    'alias': 'time-capsule-framing-shawnee',
#    'name': 'Time Capsule Framing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IqdxgUSD-5XOF4q7WfBWLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/time-capsule-framing-shawnee?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 39,
#    'categories': [{'alias': 'framing', 'title': 'Framing'},
#     {'alias': 'copyshops', 'title': 'Printing Services'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.4219066, 'longitude': -105.5556062},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '56048 Hwy 285',
#     'address2': None,
#     'address3': '',
#     'city': 'Shawnee',
#     'zip_code': '80475',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['56048 Hwy 285', 'Shawnee, CO 80475']},
#    'phone': '+17203835477',
#    'display_phone': '(720) 383-5477',
#    'distance': 61096.99332958442},
#   {'id': 'LNWXt1gX8txOlsC56t0QVA',
#    'alias': 'painting-with-a-twist-denver-5',
#    'name': 'Painting with a Twist',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pBUclXWakd9v2Gw6mab0DQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/painting-with-a-twist-denver-5?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 56,
#    'categories': [{'alias': 'paintandsip', 'title': 'Paint & Sip'},
#     {'alias': 'artclasses', 'title': 'Art Classes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.70906, 'longitude': -105.07573},
#    'transactions': [],
#    'location': {'address1': '7134 W Alaska Dr',
#     'address2': None,
#     'address3': None,
#     'city': 'Denver',
#     'zip_code': '80226',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['7134 W Alaska Dr', 'Denver, CO 80226']},
#    'phone': '+17205083645',
#    'display_phone': '(720) 508-3645',
#    'distance': 9487.27340314609},
#   {'id': 'ju1vuf9UCq9hUgw2woJ0-g',
#    'alias': 'shara-ogin-intuitive-coaching-sausalito-3',
#    'name': 'Shara Ogin, Intuitive Coaching',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/x_ZJj_OC-Ajp8W5QLaBbzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shara-ogin-intuitive-coaching-sausalito-3?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 37,
#    'categories': [{'alias': 'psychic_astrology',
#      'title': 'Supernatural Readings'},
#     {'alias': 'naturopathic', 'title': 'Naturopathic/Holistic'},
#     {'alias': 'lifecoach', 'title': 'Life Coach'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 37.85368, 'longitude': -122.4861},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Sausalito',
#     'zip_code': '94965',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['Sausalito, CA 94965']},
#    'phone': '+14159996401',
#    'display_phone': '(415) 999-6401',
#    'distance': 1529643.387370944},
#   {'id': 'uI67WLL3ZtwGDo2Y4mn8PA',
#    'alias': 'painting-soiree-at-landt-creative-space-lakewood-2',
#    'name': 'Painting Soiree at Landt Creative Space',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DJTQfcgfSp8rX82LRlrJWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/painting-soiree-at-landt-creative-space-lakewood-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 17,
#    'categories': [{'alias': 'artclasses', 'title': 'Art Classes'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.740984, 'longitude': -105.075921},
#    'transactions': [],
#    'location': {'address1': '1528 Teller St',
#     'address2': None,
#     'address3': '',
#     'city': 'Lakewood',
#     'zip_code': '80214',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['1528 Teller St', 'Lakewood, CO 80214']},
#    'phone': '+17202797911',
#    'display_phone': '(720) 279-7911',
#    'distance': 9056.250385699326},
#   {'id': 'l3bQhPDW7m6SmmN4UP1fbw',
#    'alias': 'old-map-gallery-denver-2',
#    'name': 'Old Map Gallery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R4j4JPXPqjI8OBJ_0BIRdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/old-map-gallery-denver-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 13,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'hobbyshops', 'title': 'Hobby Shops'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.7512204157917,
#     'longitude': -105.001662662508},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1550 Wynkoop St',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80202',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['1550 Wynkoop St', 'Denver, CO 80202']},
#    'phone': '+13032967725',
#    'display_phone': '(303) 296-7725',
#    'distance': 3170.729632672239},
#   {'id': 'C6Cbgzarz4dnyDgzQ3649w',
#    'alias': 'the-tabletop-tap-englewood',
#    'name': 'The Tabletop Tap',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VzKxoShrMXUf9Lm3bGA_Cg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tabletop-tap-englewood?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 37,
#    'categories': [{'alias': 'arcades', 'title': 'Arcades'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.6551081, 'longitude': -104.9874951},
#    'transactions': [],
#    'location': {'address1': '3394 S Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Englewood',
#     'zip_code': '80113',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['3394 S Broadway', 'Englewood, CO 80113']},
#    'phone': '+17202870155',
#    'display_phone': '(720) 287-0155',
#    'distance': 9053.20322460079},
#   {'id': '0tap6sLDI0tf4hVWharKhQ',
#    'alias': 'element-home-denver-3',
#    'name': 'ELEMENT Home',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YH3rwv6_ApJ_RUFJFvvIkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/element-home-denver-3?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 34,
#    'categories': [{'alias': 'furniture', 'title': 'Furniture Stores'},
#     {'alias': 'homedecor', 'title': 'Home Decor'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.7476609, 'longitude': -104.9990796},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '3030 E 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80206',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['3030 E 2nd Ave', 'Denver, CO 80206']},
#    'phone': '+13038253770',
#    'display_phone': '(303) 825-3770',
#    'distance': 2810.5733536785906},
#   {'id': 'FoQFcVgveKy1z_lSIZDVpw',
#    'alias': 'the-learned-lemur-denver',
#    'name': 'The Learned Lemur',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FiU9gmt28w-JHTbJfVc3FA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-learned-lemur-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 10,
#    'categories': [{'alias': 'antiques', 'title': 'Antiques'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.73976332454026, 'longitude': -104.9603102},
#    'transactions': [],
#    'location': {'address1': '2220 E Colfax Av',
#     'address2': None,
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80206',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['2220 E Colfax Av', 'Denver, CO 80206']},
#    'phone': '+17206007585',
#    'display_phone': '(720) 600-7585',
#    'distance': 971.5315832189382},
#   {'id': 'DuZEE-IuBCdKKZ2sOspOtA',
#    'alias': 'painting-with-a-twist-denver-4',
#    'name': 'Painting with a Twist',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6-ZtI9SJKM5OLgUHA9YqbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/painting-with-a-twist-denver-4?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 9,
#    'categories': [{'alias': 'artclasses', 'title': 'Art Classes'},
#     {'alias': 'paintandsip', 'title': 'Paint & Sip'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 39.754068, 'longitude': -104.994311},
#    'transactions': [],
#    'location': {'address1': '1962 Blake St',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80202',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['1962 Blake St', 'Denver, CO 80202']},
#    'phone': '+17205985755',
#    'display_phone': '(720) 598-5755',
#    'distance': 2915.4977096751104},
#   {'id': 'E6IQ92NA-MUVmbsoZMum2g',
#    'alias': 'eron-johnson-antiques-denver-2',
#    'name': 'Eron Johnson Antiques',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wiUrF8_5ur44FSTnQOispg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eron-johnson-antiques-denver-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 9,
#    'categories': [{'alias': 'antiques', 'title': 'Antiques'},
#     {'alias': 'furniture', 'title': 'Furniture Stores'},
# ...
#    'review_count': 1,
#    'categories': [{'alias': 'theater', 'title': 'Performing Arts'},
#     {'alias': 'sports_clubs', 'title': 'Sports Clubs'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.7417139, 'longitude': -104.9937192},
#    'transactions': [],
#    'location': {'address1': '1325 Glenarm Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80204',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['1325 Glenarm Pl', 'Denver, CO 80204']},
#    'phone': '+13035341211',
#    'display_phone': '(303) 534-1211',
#    'distance': 2121.8643522312077},
#   {'id': '99det7tz-oCS9jKH5qThew',
#    'alias': 'dateline-denver',
#    'name': 'Dateline',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/am8iAyzl_OvGc_BXJ6L_5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dateline-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 1,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.76235, 'longitude': -104.98018},
#    'transactions': [],
#    'location': {'address1': '3004 Larimer St',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80205',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['3004 Larimer St', 'Denver, CO 80205']},
#    'phone': '+13035052127',
#    'display_phone': '(303) 505-2127',
#    'distance': 3086.1111686579916},
#   {'id': 'SIgpZ0w3EfInJO5tDKSs9w',
#    'alias': 'the-fun-singles-denver',
#    'name': 'The Fun Singles',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FIalYDZjlTULw1Tef7vfkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fun-singles-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 3,
#    'categories': [{'alias': 'social_clubs', 'title': 'Social Clubs'},
#     {'alias': 'matchmakers', 'title': 'Matchmakers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.74526, 'longitude': -104.99504},
#    'transactions': [],
#    'location': {'address1': '830 15th St',
#     'address2': 'Ste A',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80202',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['830 15th St', 'Ste A', 'Denver, CO 80202']},
#    'phone': '+17205931844',
#    'display_phone': '(720) 593-1844',
#    'distance': 2386.510660440608},
#   {'id': '5ArcC3IO51yAXKhzZlOHNQ',
#    'alias': 'mary-torrey-westminster',
#    'name': 'Mary Torrey',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mary-torrey-westminster?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 4,
#    'categories': [{'alias': 'psychicmediums', 'title': 'Psychic Mediums'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 39.8438826, 'longitude': -105.052816},
#    'transactions': [],
#    'location': {'address1': '8120 Sheridan Blvd',
#     'address2': 'Bldg C , Ste C - 315',
#     'address3': '',
#     'city': 'Westminster',
#     'zip_code': '80003',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['8120 Sheridan Blvd',
#      'Bldg C , Ste C - 315',
#      'Westminster, CO 80003']},
#    'phone': '+13034848904',
#    'display_phone': '(303) 484-8904',
#    'distance': 13962.400821979041},
#   {'id': 'CAtfUYHaTLmmDe0SXQRJYQ',
#    'alias': 'evergreen-fine-arts-festival-evergreen',
#    'name': 'Evergreen Fine Arts Festival',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lihmKzWW99yO28SCzp78XQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/evergreen-fine-arts-festival-evergreen?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 2,
#    'categories': [{'alias': 'festivals', 'title': 'Festivals'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.6344988549706,
#     'longitude': -105.327662920139},
#    'transactions': [],
#    'location': {'address1': '4208 STimbervale Dr',
#     'address2': '',
#     'address3': None,
#     'city': 'Evergreen',
#     'zip_code': '80439',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['4208 STimbervale Dr', 'Evergreen, CO 80439']},
#    'phone': '+13033493464',
#    'display_phone': '(303) 349-3464',
#    'distance': 32582.56495640384},
#   {'id': 'BTW1ISL2jU_6TBL82fRkVg',
#    'alias': 'native-american-trading-company-denver',
#    'name': 'Native American Trading Company',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AJnLdjHBPrju5YJCrJifvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/native-american-trading-company-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 11,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'appraisalservices', 'title': 'Appraisal Services'},
#     {'alias': 'artrestoration', 'title': 'Art Restoration'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 39.73697, 'longitude': -104.99063},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '213 W 13th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80204',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['213 W 13th Ave', 'Denver, CO 80204']},
#    'phone': '+13035340771',
#    'display_phone': '(303) 534-0771',
#    'distance': 1753.087527545117},
#   {'id': 'n6RWI9NDK3MU34TLZfEgMQ',
#    'alias': 'altitude-tickets-denver',
#    'name': 'Altitude Tickets',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eIREH_GqL85qU7tTgTBlIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/altitude-tickets-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 75,
#    'categories': [{'alias': 'ticketsales', 'title': 'Ticket Sales'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.7473978996277,
#     'longitude': -105.007973983884},
#    'transactions': [],
#    'location': {'address1': '1000 Chopper Cr',
#     'address2': None,
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80204',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['1000 Chopper Cr', 'Denver, CO 80204']},
#    'phone': '+18664616556',
#    'display_phone': '(866) 461-6556',
#    'distance': 3515.5441008673984},
#   {'id': 'CYQCobce92V4NG4lTzInFg',
#    'alias': 'extinction-haunted-house-denver',
#    'name': 'Extinction Haunted House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BbdjXhjTdDOlZ_3R19Eebw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/extinction-haunted-house-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 1,
#    'categories': [{'alias': 'hauntedhouses', 'title': 'Haunted Houses'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 39.7740563288863,
#     'longitude': -104.92378282547},
#    'transactions': [],
#    'location': {'address1': '4100 Grape St',
#     'address2': None,
#     'address3': None,
#     'city': 'Denver',
#     'zip_code': '80210',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['4100 Grape St', 'Denver, CO 80210']},
#    'phone': '+13033772329',
#    'display_phone': '(303) 377-2329',
#    'distance': 5842.365896486975},
#   {'id': 'y_tC-keWCedqkuRy1ZzoQA',
#    'alias': 'linda-paul-studio-lafayette',
#    'name': 'Linda Paul Studio',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ft15LnBDZbhdwgliRqkxGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/linda-paul-studio-lafayette?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 1,
#    'categories': [{'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'homedecor', 'title': 'Home Decor'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 39.9960635, 'longitude': -105.0908147},
#    'transactions': [],
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'Lafayette',
#     'zip_code': '80026',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['Lafayette, CO 80026']},
#    'phone': '+13038182663',
#    'display_phone': '(303) 818-2663',
#    'distance': 30743.871959475986},
#   {'id': 'Zl4qitevlBYMkqTKEYz9rw',
#    'alias': 'goalmaster28-productions-thornton',
#    'name': 'Goalmaster28 Productions',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1Ry4ceu4XbMeTFiO7fEbpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/goalmaster28-productions-thornton?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 3,
#    'categories': [{'alias': 'movietheaters', 'title': 'Cinema'},
#     {'alias': 'televisionstations', 'title': 'Television Stations'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 39.8568090875139,
#     'longitude': -104.994531543245},
#    'transactions': [],
#    'location': {'address1': '8801 Fox Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Thornton',
#     'zip_code': '80260',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['8801 Fox Dr', 'Thornton, CO 80260']},
#    'phone': '+13039008078',
#    'display_phone': '(303) 900-8078',
#    'distance': 13644.923356826648},
#   {'id': 'o-2KB8WOJjDt18Apr02gkw',
#    'alias': 'denver-psychic-reader-denver',
#    'name': 'Denver Psychic Reader',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UaGaEB4Vgw6oBLXNvn1DbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/denver-psychic-reader-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 2,
#    'categories': [{'alias': 'psychics', 'title': 'Psychics'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 39.65328, 'longitude': -104.92899},
#    'transactions': [],
#    'location': {'address1': '3492 S Elm St',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80222',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['3492 S Elm St', 'Denver, CO 80222']},
#    'phone': '+13037893395',
#    'display_phone': '(303) 789-3395',
#    'distance': 9799.383585767853},
#   {'id': '4ZcfFLIp9gVeR7aKRlvAtA',
#    'alias': 'best-psychic-experiences-denver',
#    'name': 'Best Psychic Experiences',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/48GlV-gyIa6aWRO2Gmx9YA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/best-psychic-experiences-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 2,
#    'categories': [{'alias': 'psychics', 'title': 'Psychics'},
#     {'alias': 'spiritual_shop', 'title': 'Spiritual Shop'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.76917, 'longitude': -105.02732},
#    'transactions': [],
#    'location': {'address1': '3770 Grove St',
#     'address2': '',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80211',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['3770 Grove St', 'Denver, CO 80211']},
#    'phone': '+13034805299',
#    'display_phone': '(303) 480-5299',
#    'distance': 6150.797087943288},
#   {'id': 'MfQAHfw_ePPG90q_JjO2zQ',
#    'alias': 'charley-takaya-psychic-denver',
#    'name': 'Charley Takaya Psychic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/A5-_v56DM7qKRU8wmk9bYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/charley-takaya-psychic-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 1,
#    'categories': [{'alias': 'psychics', 'title': 'Psychics'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.740029, 'longitude': -104.983422},
#    'transactions': [],
#    'location': {'address1': '1470 S Grant St',
#     'address2': 'Ste 230',
#     'address3': '',
#     'city': 'Denver',
#     'zip_code': '80203',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['1470 S Grant St', 'Ste 230', 'Denver, CO 80203']},
#    'phone': '+13039008683',
#    'display_phone': '(303) 900-8683',
#    'distance': 1233.0177494400561},
#   {'id': '4wzFrZxvGPE1mq44FcVl6g',
#    'alias': 'vca-southeast-area-animal-hospital-denver-3',
#    'name': 'Vca Southeast Area Animal Hospital',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vca-southeast-area-animal-hospital-denver-3?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 1,
#    'categories': [{'alias': 'vet', 'title': 'Veterinarians'},
#     {'alias': 'veteransorganizations', 'title': 'Veterans Organizations'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.675067, 'longitude': -104.87364},
#    'transactions': [],
#    'location': {'address1': '9801 E Iliff Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Denver',
#     'zip_code': '80231',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['9801 E Iliff Ave', 'Denver, CO 80231']},
#    'phone': '+13037514954',
#    'display_phone': '(303) 751-4954',
#    'distance': 10649.63805336004},
#   {'id': 'Z75iDHOSSk6uGCfDDjiEjQ',
#    'alias': 'american-pride-skill-games-denver',
#    'name': 'American Pride Skill Games',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/txuUrwDnMShXkr4IzjhQXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/american-pride-skill-games-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 1,
#    'categories': [{'alias': 'arcades', 'title': 'Arcades'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.6597900390625,
#     'longitude': -104.860450744629},
#    'transactions': [],
#    'location': {'address1': '10890 E Dartmouth Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Denver',
#     'zip_code': '80014',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['10890 E Dartmouth Ave', 'Denver, CO 80014']},
#    'phone': '+13034782625',
#    'display_phone': '(303) 478-2625',
#    'distance': 12612.444944923584},
#   {'id': 'SXLQPwzIuZ2xoeNF0xocjA',
#    'alias': 'pirisen-music-lessons-centennial-centennial-2',
#    'name': 'Pirisen Music Lessons - Centennial',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2cwsRZbFxcTyNEkU7pDfMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pirisen-music-lessons-centennial-centennial-2?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w',
#    'review_count': 1,
#    'categories': [{'alias': 'musicalinstrumentsandteachers',
#      'title': 'Musical Instruments & Teachers'},
#     {'alias': 'artschools', 'title': 'Art Schools'},
#     {'alias': 'theater', 'title': 'Performing Arts'}],
#    'rating': 1.0,
#    'coordinates': {'latitude': 39.572832, 'longitude': -104.9223331},
#    'transactions': [],
#    'location': {'address1': '8030 S Holly St',
#     'address2': None,
#     'address3': None,
#     'city': 'Centennial',
#     'zip_code': '80122',
#     'country': 'US',
#     'state': 'CO',
#     'display_address': ['8030 S Holly St', 'Centennial, CO 80122']},
#    'phone': '+17204934340',
#    'display_phone': '(720) 493-4340',
#    'distance': 18549.70882733222}]}

# %%
import pandas as pd
df = pd.DataFrame(data['businesses'])
df.head(1000)
# Out:
#                          id  \
# 0    L1QXBchHoza6rEjqx-87RA
# 1    KwFEBgDC_cvVvAHJ_CKD7A
# 2    WhAD9eZndK3xbFpIPqeFYQ
# 3    HHv2fah0WapIL8Kche3AHQ
# 4    bTx_XCtBCxFDgGPBsQS3Jg
# ..                      ...
# 545  4ZcfFLIp9gVeR7aKRlvAtA
# 546  MfQAHfw_ePPG90q_JjO2zQ
# 547  4wzFrZxvGPE1mq44FcVl6g
# 548  Z75iDHOSSk6uGCfDDjiEjQ
# 549  SXLQPwzIuZ2xoeNF0xocjA
#
#                                                  alias  \
# 0                               medium-kimberly-denver
# 1    lea-marlene-actors-studio-and-the-namastage-th...
# 2                the-dance-art-media-studios-littleton
# 3                                 wonderbound-denver-2
# 4                    blizzard-mountain-pinball-conifer
# ..                                                 ...
# 545                    best-psychic-experiences-denver
# 546                      charley-takaya-psychic-denver
# 547        vca-southeast-area-animal-hospital-denver-3
# 548                  american-pride-skill-games-denver
# 549      pirisen-music-lessons-centennial-centennial-2
#
#                                                   name  \
# 0                                     Medium Kimberly
# 1    Lea Marlene Actors Studio & The Namastage Theatre
# 2                          The Dance Art Media Studios
# 3                                          Wonderbound
# 4                            Blizzard Mountain Pinball
# ..                                                 ...
# 545                           Best Psychic Experiences
# 546                             Charley Takaya Psychic
# 547                 Vca Southeast Area Animal Hospital
# 548                         American Pride Skill Games
# 549                 Pirisen Music Lessons - Centennial
#
#                                              image_url  is_closed  \
# 0    https://s3-media1.fl.yelpcdn.com/bphoto/S0_Fgd...      False
# 1    https://s3-media2.fl.yelpcdn.com/bphoto/gO3-Hs...      False
# 2    https://s3-media4.fl.yelpcdn.com/bphoto/IKQ664...      False
# 3    https://s3-media1.fl.yelpcdn.com/bphoto/AoLS0b...      False
# 4    https://s3-media2.fl.yelpcdn.com/bphoto/6p_Y8t...      False
# ..                                                 ...        ...
# 545  https://s3-media1.fl.yelpcdn.com/bphoto/48GlV-...      False
# 546  https://s3-media4.fl.yelpcdn.com/bphoto/A5-_v5...      False
# 547                                                         False
# 548  https://s3-media2.fl.yelpcdn.com/bphoto/txuUrw...      False
# 549  https://s3-media3.fl.yelpcdn.com/bphoto/2cwsRZ...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/medium-kimberly-denve...             5
# 1    https://www.yelp.com/biz/lea-marlene-actors-st...             5
# 2    https://www.yelp.com/biz/the-dance-art-media-s...             5
# 3    https://www.yelp.com/biz/wonderbound-denver-2?...             6
# 4    https://www.yelp.com/biz/blizzard-mountain-pin...            14
# ..                                                 ...           ...
# 545  https://www.yelp.com/biz/best-psychic-experien...             2
# 546  https://www.yelp.com/biz/charley-takaya-psychi...             1
# 547  https://www.yelp.com/biz/vca-southeast-area-an...             1
# 548  https://www.yelp.com/biz/american-pride-skill-...             1
# 549  https://www.yelp.com/biz/pirisen-music-lessons...             1
#
#                                             categories  rating  \
# 0    [{'alias': 'psychicmediums', 'title': 'Psychic...     5.0
# 1    [{'alias': 'theater', 'title': 'Performing Art...     5.0
# 2    [{'alias': 'dancestudio', 'title': 'Dance Stud...     5.0
# 3    [{'alias': 'theater', 'title': 'Performing Art...     5.0
# 4           [{'alias': 'arcades', 'title': 'Arcades'}]     5.0
# ..                                                 ...     ...
# 545  [{'alias': 'psychics', 'title': 'Psychics'}, {...     1.0
# 546       [{'alias': 'psychics', 'title': 'Psychics'}]     1.0
# 547  [{'alias': 'vet', 'title': 'Veterinarians'}, {...     1.0
# 548         [{'alias': 'arcades', 'title': 'Arcades'}]     1.0
# 549  [{'alias': 'musicalinstrumentsandteachers', 't...     1.0
#
#                                            coordinates transactions  \
# 0      {'latitude': 39.73367, 'longitude': -104.99736}           []
# 1    {'latitude': 39.747921, 'longitude': -104.9784...           []
# 2    {'latitude': 39.6081044, 'longitude': -105.097...           []
# 3    {'latitude': 39.773672666, 'longitude': -104.9...           []
# 4       {'latitude': 39.54317, 'longitude': -105.2945}           []
# ..                                                 ...          ...
# 545    {'latitude': 39.76917, 'longitude': -105.02732}           []
# 546  {'latitude': 39.740029, 'longitude': -104.983422}           []
# 547   {'latitude': 39.675067, 'longitude': -104.87364}           []
# 548  {'latitude': 39.6597900390625, 'longitude': -1...           []
# 549  {'latitude': 39.572832, 'longitude': -104.9223...           []
#
#                                               location         phone  \
# 0    {'address1': '', 'address2': '', 'address3': '...
# 1    {'address1': '119 Park Ave W', 'address2': '',...  +17206382612
# 2    {'address1': '8996 West Bowles Ave', 'address2...  +13039796419
# 3    {'address1': '2535 E 40th Ave', 'address2': No...  +13032924700
# 4    {'address1': '25797 Conifer Rd', 'address2': '...  +17207672549
# ..                                                 ...           ...
# 545  {'address1': '3770 Grove St', 'address2': '', ...  +13034805299
# 546  {'address1': '1470 S Grant St', 'address2': 'S...  +13039008683
# 547  {'address1': '9801 E Iliff Ave', 'address2': '...  +13037514954
# 548  {'address1': '10890 E Dartmouth Ave', 'address...  +13034782625
# 549  {'address1': '8030 S Holly St', 'address2': No...  +17204934340
#
#       display_phone      distance price
# 0                     4819.973505   NaN
# 1    (720) 638-2612   1546.465196   NaN
# 2    (303) 979-6419  17879.542840   NaN
# 3    (303) 292-4700   4456.443205   NaN
# 4    (720) 767-2549  35012.815046   NaN
# ..              ...           ...   ...
# 545  (303) 480-5299   6150.797088   NaN
# 546  (303) 900-8683   1233.017749   NaN
# 547  (303) 751-4954  10649.638053   NaN
# 548  (303) 478-2625  12612.444945   NaN
# 549  (720) 493-4340  18549.708827   NaN
#
# [550 rows x 16 columns]
