# %% [markdown]
# # Smart Travel App
# ## Group 4, Project 4
# ### Team: Dominique Villarreal, Enrique Garcia, Jose Santos
# ### Project Due Date: June 12, 2023

# %% [markdown]
# ## Setup Environment

# %%
import json
import pandas as pd
import pprint as pp
import requests
import time

# %% [markdown]
# ## Exploring the Yelp API

# %%
# Confirm Category Alias & Parent Aliases

url = "https://api.yelp.com/v3/categories"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
}

response = requests.get(url, headers=headers)

data = json.loads(response.text)

categories = [(category['alias'], category['parent_aliases']) for category in data['categories']]
categories_sorted = sorted(categories, key=lambda x: (x[1], x[0]))

pp.pprint(categories_sorted)
# Out:
# [('active', []),
#  ('arts', []),
#  ('auto', []),
#  ('beautysvc', []),
#  ('bicycles', []),
#  ('education', []),
#  ('eventservices', []),
#  ('financialservices', []),
#  ('food', []),
#  ('health', []),
#  ('homeservices', []),
#  ('hotelstravel', []),
#  ('localflavor', []),
#  ('localservices', []),
#  ('massmedia', []),
#  ('nightlife', []),
#  ('pets', []),
#  ('professional', []),
#  ('publicservicesgovt', []),
#  ('religiousorgs', []),
#  ('restaurants', []),
#  ('shopping', []),
#  ('airsoft', ['active']),
#  ('amateursportsteams', ['active']),
#  ('amusementparks', ['active']),
#  ('aquariums', ['active']),
#  ('archery', ['active']),
#  ('atvrentals', ['active']),
#  ('axethrowing', ['active']),
#  ('badminton', ['active']),
#  ('baseballfields', ['active']),
#  ('basketballcourts', ['active']),
#  ('bathing_area', ['active']),
#  ('battingcages', ['active']),
#  ('beachequipmentrental', ['active']),
#  ('beaches', ['active']),
#  ('beachvolleyball', ['active']),
# ...

# %% [markdown]
# #### Parent aliases we may want:
# 'parent_aliases': active, arts, bars, breweries, festivals, fitness, food, museums, nightlife, restaurants, tours, wineries, zoos

# %%
# Confirm Category Parent Aliases sorted and unique values only
import requests
import json

url = "https://api.yelp.com/v3/categories"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
}

response = requests.get(url, headers=headers)

data = json.loads(response.text)

categories = [category['parent_aliases'] for category in data['categories']]
categories_unique_sorted = sorted(set(sum(categories, [])))

for category in categories_unique_sorted:
    print(category)
# Out:
# active
# adultentertainment
# african
# airports
# arabian
# artclasses
# arts
# artsandcrafts
# auto
# autoglass
# autopartssupplies
# autorepair
# bars
# beautysvc
# belgian
# bicycles
# brazilian
# breakfast_brunch
# breweries
# c_and_mh
# cafes
# cannabis_clinics
# caribbean
# chinese
# crisispregnancycenters
# dentalhygienists
# dentists
# diagnosticservices
# diving
# donburi
# education
# estateplanning
# eventservices
# farms
# fashion
# festivals
# financialservices
# fitness
# flowers
# food
# french
# funeralservices
# gardening
# german
# gourmet
# gyms
# hair
# hairremoval
# health
# homeandgarden
# homeservices
# hotels
# hotelstravel
# insurance
# italian
# itservices
# japanese
# jpsweets
# junkremovalandhauling
# kitchenandbath
# landscaping
# latin
# laundryservices
# lawyers
# legalservices
# localflavor
# localservices
# malaysian
# martialarts
# massmedia
# medcenters
# media
# medicalspa
# mediterranean
# mexican
# mideastern
# movietheaters
# museums
# ...

# %% [markdown]
# ### Active Data Pulls

# %% [markdown]
# ## Denver

# %%
# Active
# Data Pull for Denver Active Category: Radius 40000, Open, By Rating
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,50,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=active&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer VLnY10dNyAE5dLbob1YXoLTY4nygV3DWCCZJuk8mDuVI-zTME9om5QjffXfelKG1LqkLeUMt-N6vsp2vtWde_CLYvP28lkWBPjUsvCtbB38cy762UuInOPWvnEh5ZHYx"
        }
        response = requests.get(url, headers=headers)
        data = response.json()
                      
        
        #with open("Denver_active_response2.json", "a") as file:
        with open('output.json', 'a') as json_file:
            json.dump(data, json_file)
            #file.write(response.json)
        time.sleep(2.4)

# %%
location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=active&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "bearer VLnY10dNyAE5dLbob1YXoLTY4nygV3DWCCZJuk8mDuVI-zTME9om5QjffXfelKG1LqkLeUMt-N6vsp2vtWde_CLYvP28lkWBPjUsvCtbB38cy762UuInOPWvnEh5ZHYx"
        }
        response = requests.get(url, headers=headers)
        D_data = response.json()
        
        with open('Denver_active_response.json', 'a') as json_file:
            json.dump(D_data, json_file)
            json_file.write('\n')
        time.sleep(2.4)

        
print(D_data)
# Out:
# {'businesses': [{'id': '65NBhEPcUWrKsfe5zDh2pg', 'alias': 'colorado-scuba-center-lakewood-2', 'name': 'Colorado Scuba Center', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_BW78E3J7KHUbdLviFaB9Q/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/colorado-scuba-center-lakewood-2?adjust_creative=CSd6XTHR0DfUmDUFsIPk6g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CSd6XTHR0DfUmDUFsIPk6g', 'review_count': 5, 'categories': [{'alias': 'diving', 'title': 'Diving'}], 'rating': 3.0, 'coordinates': {'latitude': 39.69073995344795, 'longitude': -105.08067791380171}, 'transactions': [], 'location': {'address1': '1432 S Wadsworth Blvd', 'address2': None, 'address3': '', 'city': 'Lakewood', 'zip_code': '80232', 'country': 'US', 'state': 'CO', 'display_address': ['1432 S Wadsworth Blvd', 'Lakewood, CO 80232']}, 'phone': '+13039860007', 'display_phone': '(303) 986-0007', 'distance': 10678.30853276201}, {'id': 'RqR5iWHKl8aX_RlXOqeSPw', 'alias': '24-hour-fitne
# ...

# %%
import pandas as pd
df6 = pd.DataFrame(D_data["businesses"])
df6.head(1000)
# Out:
#                         id                                              alias  \
# 0   65NBhEPcUWrKsfe5zDh2pg                   colorado-scuba-center-lakewood-2
# 1   RqR5iWHKl8aX_RlXOqeSPw         24-hour-fitness-centennial-highlands-ranch
# 2   pEdGdOSqUy7W4PPcCUlr_A     vasa-fitness-aurora-colfax-and-chambers-aurora
# 3   gicmF_wHK1meojq1lj6uBg     colorado-athletic-club-dtc-greenwood-village-2
# 4   XhqJVQlLyfbp3jac5zyciQ    charter-sports-ski-and-snowboard-rentals-avon-3
# 5   sn3dr9Cmk6Q6DdGt3k0ueA                            planet-fitness-denver-2
# 6   Sd-2yXHnc4a-OYE_qSkAPg                 movement-climbing-fitness-denver-5
# 7   oKSC8aTfK1ewUZ4yhNnQPg                           vita-littleton-littleton
# 8   EDi7BwEOkG59wJjkqYf6lQ                          anytime-fitness-aurora-13
# 9   J5GJw6elSqTxZlpVrISziA                     the-king-of-aquariums-lakewood
# 10  cOILywjvy7xpEKGugrGw3w    community-sailing-of-colorado-greenwood-village
# ...

# %%
import json

# Read the text file
with open('Denver_arts_response_fixedcopy.txt', 'r') as file:
    file_contents = file.read()

# Parse the text into a JSON object
json_data = json.loads(file_contents)

# Access and work with the JSON data
#print(json_data)

df7 = pd.DataFrame(json_data["businesses"])
df7.head(100)
# Out:
# {'businesses': [{'id': 'L1QXBchHoza6rEjqx-87RA', 'alias': 'medium-kimberly-denver', 'name': 'Medium Kimberly ', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/S0_FgdTl0f_qzWXgHMVtmw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/medium-kimberly-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w', 'review_count': 5, 'categories': [{'alias': 'psychicmediums', 'title': 'Psychic Mediums'}], 'rating': 5.0, 'coordinates': {'latitude': 39.73367, 'longitude': -104.99736}, 'transactions': [], 'location': {'address1': '', 'address2': '', 'address3': '', 'city': 'Denver', 'zip_code': '80204', 'country': 'US', 'state': 'CO', 'display_address': ['Denver, CO 80204']}, 'phone': '', 'display_phone': '', 'distance': 4819.97350529954}, {'id': 'KwFEBgDC_cvVvAHJ_CKD7A', 'alias': 'lea-marlene-actors-studio-and-the-namastage-theatre-denver', 'name': 'Lea Marlene Actors Studio & The Namastage Theatr
# ...

# %%
import requests

url = "https://api.yelp.com/v3/businesses/search?location=Denver&radius=40000&categories=active&open_now=true&sort_by=rating&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "bearer VLnY10dNyAE5dLbob1YXoLTY4nygV3DWCCZJuk8mDuVI-zTME9om5QjffXfelKG1LqkLeUMt-N6vsp2vtWde_CLYvP28lkWBPjUsvCtbB38cy762UuInOPWvnEh5ZHYx"
}

response = requests.get(url, headers=headers)
data3 = response.json()

with open('D2.json', 'w') as json_file:
            json.dump(data3, json_file)
        
print(data3)
# Out:
# {'businesses': [{'id': 'OrJhLmdE09puDoRu2Z5gKg', 'alias': 'platform-strength-denver', 'name': 'Platform Strength', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dxeIYLUp-zxQ5aXCp6j0sQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/platform-strength-denver?adjust_creative=CSd6XTHR0DfUmDUFsIPk6g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=CSd6XTHR0DfUmDUFsIPk6g', 'review_count': 18, 'categories': [{'alias': 'gyms', 'title': 'Gyms'}, {'alias': 'healthtrainers', 'title': 'Trainers'}], 'rating': 5.0, 'coordinates': {'latitude': 39.76528313669848, 'longitude': -104.98005321904905}, 'transactions': [], 'location': {'address1': '3198 Blake St', 'address2': 'Unit 100', 'address3': '', 'city': 'Denver', 'zip_code': '80205', 'country': 'US', 'state': 'CO', 'display_address': ['3198 Blake St', 'Unit 100', 'Denver, CO 80205']}, 'phone': '+17205064945', 'display_phone': '(720) 506-4945', 'distance': 3413.6169716977483}, {'id': 'f2EAhyKSZjxTBxO6oiRgew
# ...

# %%
import pandas as pd
df = pd.DataFrame(data3["businesses"])
df
# Out:
#                         id                                              alias  \
# 0   OrJhLmdE09puDoRu2Z5gKg                           platform-strength-denver
# 1   f2EAhyKSZjxTBxO6oiRgew  runfree-physical-therapy-and-sports-performanc...
# 2   yj-w2uT764UVjXQioi-Kxg                 denver-racquet-stringing-englewood
# 3   vAQJ5ZTo71txDX9x2jigig          chase-mansmann-personal-training-arvada-2
# 4   RsZzcJ9x26mCRcd_Xo6HDg     lions-den-strength-mobility-performance-denver
# 5   Rp1gQn8BbyGHdh_YARRZ_A                          alpha-life-fitness-denver
# 6   WhAD9eZndK3xbFpIPqeFYQ              the-dance-art-media-studios-littleton
# 7   HHv2fah0WapIL8Kche3AHQ                               wonderbound-denver-2
# 8   0u1xWODmufStTWtNOAFeQg          warriors-call-tactical-solutions-parker-3
# 9   WBHUmYp7wS-jY5IyHLCHKg                           my-nature-lab-louisville
# 10  frqr0wbb0qEzcx4cnFtjJg             colorado-clownfish-swim-club-littleton
# ...

# %%
# Arts
# Data Pull for Denver Arts Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_arts_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Bars
# Data Pull for Denver Bars Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=bars&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_bars_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Read the text file
with open('/Users/josesantos/LearnPython/BCGit/G4_Project4/ResourcesDay2/Denver_bars_response_fixedcopy.txt', 'r') as file:
    file_contents = file.read()

# Parse the text into a JSON object
json_denver_bar_data = json.loads(file_contents)

# Access and work with the JSON data
#print(json_data)

df8 = pd.DataFrame(json_denver_bar_data["businesses"])
df8.head(100)
# Out:
#                         id                                  alias  \
# 0   jNjQfYLJI_SDqE1b4Zb2dA         superfly-golf-lounge-littleton
# 1   IaPb61-o9PhyFepC0rma4A                 the-local-drive-denver
# 2   X915GhIBrsU4NsQe0I09Tg                  taaz-tavern-englewood
# 3   8nkTuIb_L6jVGdhBNaLKmQ                          salita-denver
# 4   q77SiTyr3EYYTD_B2vH_OA                       side-pony-denver
# ..                     ...                                    ...
# 95  fC3XcLuMTWzgj7RO-KWbxQ                  comet-brews-littleton
# 96  tgfFYze1bwPry4ye_XFqtQ                     max-taps-englewood
# 97  nhVEmJ2uilaHJpEvCehifA  western-sky-bar-and-taproom-englewood
# 98  9izE1WR8-2LNDq3RE0dOug      society-sports-and-spirits-denver
# 99  BHpQiNX5LF79RHTCng8TqQ              nola-voodoo-tavern-denver
#
#                           name  \
# 0         Superfly Golf Lounge
# 1              The Local Drive
# 2                  Taaz Tavern
# 3                       Salita
# ...

# %%
import pandas as pd

# Extract data from "categories" column
categories_data = df8['categories'].apply(lambda x: [item['title'] for item in x])

# Add extracted data as a new column
df8['extracted_categories'] = categories_data

# Access and work with the updated DataFrame
df8
# Out:
#                          id                                  alias  \
# 0    jNjQfYLJI_SDqE1b4Zb2dA         superfly-golf-lounge-littleton
# 1    IaPb61-o9PhyFepC0rma4A                 the-local-drive-denver
# 2    X915GhIBrsU4NsQe0I09Tg                  taaz-tavern-englewood
# 3    8nkTuIb_L6jVGdhBNaLKmQ                          salita-denver
# 4    q77SiTyr3EYYTD_B2vH_OA                       side-pony-denver
# ..                      ...                                    ...
# 988  P486ibFoQG_BthvjUY6OBQ         buffalo-wild-wings-castle-rock
# 989  E3L07-lglKZVcf_tlGZWOw         springhill-suites-lobby-aurora
# 990  ByHl2r3QbkwcPkmlWBZmHQ          montview-bar-and-grill-aurora
# 991  uy5DvHdC6HH-byu6emxdRA                   cazadores-bar-aurora
# 992  5P74PSWAnXb01zl3j7mYGQ  round-2-sports-tavern-federal-heights
#
#                         name  \
# 0       Superfly Golf Lounge
# 1            The Local Drive
# 2                Taaz Tavern
# 3                     Salita
# ...

# %%
# Breweries
# Data Pull for Denver Breweries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=breweries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_breweries_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Festivals
# Data Pull for Denver Festivals Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=festivals&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_festivals_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Fitness
# Data Pull for Denver Fitness Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=fitness&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_fitness_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Food
# Data Pull for Denver Food Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=food&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_food_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Museums
# Data Pull for Denver Museums Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=museums&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_museums_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Nightlife
# Data Pull for Denver Nightlife Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=nightlife&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_nightlife_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Restaurants
# Data Pull for Denver Restaurants: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):    
        import requests

        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=restaurants&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_restaurant_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Tours
# Data Pull for Denver Tours Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=tours&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_tours_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Wineries
# Data Pull for Denver Wineries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=wineries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_wineries_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Zoos
# Data Pull for Denver Zoos Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Denver']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=zoos&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Denver_zoos_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %% [markdown]
# #### (End of Denver Pulls)

# %% [markdown]
# ## Miami

# %%
# Active
# Data Pull for Miami Active Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=active&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_active_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Arts
# Data Pull for Miami Arts Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_arts_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Bars
# Data Pull for Miami Bars Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=bars&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_bars_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Breweries
# Data Pull for Miami Breweries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_arts_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Festivals
# Data Pull for Miami Festivals Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=festivals&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_festivals_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Fitness
# Data Pull for Miami Fitness Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=fitness&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_fitness_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Food
# Data Pull for Miami Arts Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=arts&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_arts_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Museums
# Data Pull for Miami Museums Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=museums&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_museums_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Nightlife
# Data Pull for Miami Nightlife Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=nightlife&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_nightlife_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Restaurants
# Data Pull for Miami Restaurants: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):    
        import requests

        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=restaurants&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_restaurant_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Tours
# Data Pull for Miami Tours Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=tours&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_tours_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Wineries
# Data Pull for Miami Wineries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=wineries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_wineries_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Zoos
# Data Pull for Miami Zoos Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['Miami']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=zoos&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("Miami_zoos_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %% [markdown]
# #### (End of Miami Pulls)

# %% [markdown]
# ## New York

# %%
# Active
# Data Pull for New York Active Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=active&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_active_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Bars
# Data Pull for New York Bars Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=bars&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_bars_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Breweries
# Data Pull for New York Breweries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=breweries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_breweries_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Festivals
# Data Pull for New York Festivals Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=festivals&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_festivals_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Fitness
# Data Pull for New York Fitness Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=fitness&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_fitness_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Food
# Data Pull for New York Food Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=food&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_food_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Museums
# Data Pull for New York Museums Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=museums&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_museums_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Nightlife
# Data Pull for New York Nightlife Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=nightlife&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_nightlife_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Restaurants
# Data Pull for New York Restaurants: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):    
        import requests

        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=restaurants&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("restaurant_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Tours
# Data Pull for New York Tours Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=tours&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_tours_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Wineries
# Data Pull for New York Wineries Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=wineries&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_wineries_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %%
# Zoos
# Data Pull for New York Zoos Category: Radius 40000, Open, By Rating
import requests
import time
import pprint as pp

location_list = ['New York']

for location in location_list:
    
    for i in range (0,1000,50):         
        url = f"https://api.yelp.com/v3/businesses/search?location={location}&radius=40000&categories=zoos&open_now=true&sort_by=rating&limit=50&offset={i}"
        headers = {
        "accept": "application/json",
        "Authorization": "Bearer MxUWaphFGThFjTSxdCFBcvxk2i3IBW4g2iQU2jQKQ7-06GXSzfmSa8hkN_yWztLyTRWsCXGNZzFSUzZXYKQrlXM-7cDmOz0mLjAfZ5TTpZGwhHl8aAF1hHwL20V5ZHYx"
        }
        response = requests.get(url, headers=headers)
        
        with open("NewYork_zoos_response.txt", "a") as file:
            file.write(response.text)
        time.sleep(2.4)

# %% [markdown]
# #### (End of New York Pulls)

# %%
import json
import pprint as pp
#import psycopg2

file_path = '/Users/josesantos/LearnPython/BCGit/G4_Project4/Denver_arts_response.txt'

# Open the text file containing the JSON data
with open(file_path, 'r') as file:
    json_data = file.read()

# Parse the JSON data
#data = json.loads(json_data)
pp.pprint(json_data)
# Out:
# ('{"businesses": [{"id": "L1QXBchHoza6rEjqx-87RA", "alias": '
#  '"medium-kimberly-denver", "name": "Medium Kimberly ", "image_url": '
#  '"https://s3-media1.fl.yelpcdn.com/bphoto/S0_FgdTl0f_qzWXgHMVtmw/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/medium-kimberly-denver?adjust_creative=OD45_sigUUSBobJ_eVs01w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=OD45_sigUUSBobJ_eVs01w", '
#  '"review_count": 5, "categories": [{"alias": "psychicmediums", "title": '
#  '"Psychic Mediums"}], "rating": 5.0, "coordinates": {"latitude": 39.73367, '
#  '"longitude": -104.99736}, "transactions": [], "location": {"address1": "", '
#  '"address2": "", "address3": "", "city": "Denver", "zip_code": "80204", '
#  '"country": "US", "state": "CO", "display_address": ["Denver, CO 80204"]}, '
#  '"phone": "", "display_phone": "", "distance": 4819.97350529954}, {"id": '
#  '"KwFEBgDC_cvVvAHJ_CKD7A", "alias": '
# ...

# %%
file_path2 = '/Users/rickygarcia/ModuleChallenges/G4_Project4/output.json'

with open(file_path2, 'r') as json_file: 
    data = json.load(json_file)
    
print(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/jn/tsw927xx3750d14kc_42lhl00000gn/T/ipykernel_99983/3060453452.py in <module>
#       2
#       3 with open(file_path2, 'r') as json_file:
# ----> 4     data = json.load(json_file)
#       5
#       6 print(data)
#
# ~/opt/anaconda3/lib/python3.9/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~/opt/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
# ...
