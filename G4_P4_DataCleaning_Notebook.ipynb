# %% [markdown]
# # Smart Travel App
# ## Notebook 2: Data Read In

# %% [markdown]
# ##### Group 4, Project 4
# ##### Team: Dominique Villarreal, Enrique Garcia, Jose Santos
# ##### Project Due Date: June 12, 2023

# %% [markdown]
# ## Setup Environment

# %%
import json
import pandas as pd
import pprint as pp
import requests
import time

# %% [markdown]
# ## Denver Data

# %%
# Active - Data Pull for Denver Active Category: Radius 40000, Open, By Rating

# Read the text file
with open('Denver_arts_response_fixedcopy.txt', 'r') as file:
    file_contents = file.read()

# Parse the text into a JSON object
json_data = json.loads(file_contents)

# Access and work with the JSON data
#print(json_data)
Denver_Active_df = pd.DataFrame(json_data["businesses"])
Denver_Active_df.head(100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Active - Data Pull for Denver Active Category: Radius 40000, Open, By Rating
#       2
#       3 # Read the text file
# ----> 4 with open('Denver_arts_response_fixedcopy.txt', 'r') as file:
#       5     file_contents = file.read()
#       7 # Parse the text into a JSON object
#
# File /opt/anaconda3/envs/PythonData2/lib/python3.10/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# ...

# %%
# Arts - Data Pull for Denver Active Category: Radius 40000, Open, By Rating

# Read the text file
with open('/Users/josesantos/LearnPython/BCGit/G4_Project4/ResourcesDay2/Denver_arts_response_fixedcopy.txt', 'r') as file:
    file_contents = file.read()

# Parse the text into a JSON object
json_data = json.loads(file_contents)

# Access and work with the JSON data
#print(json_data)
Denver_arts_df = pd.DataFrame(json_data["businesses"])
Denver_arts_df.head(100)
# Out:
#                         id                                              alias  \
# 0   L1QXBchHoza6rEjqx-87RA                             medium-kimberly-denver
# 1   KwFEBgDC_cvVvAHJ_CKD7A  lea-marlene-actors-studio-and-the-namastage-th...
# 2   WhAD9eZndK3xbFpIPqeFYQ              the-dance-art-media-studios-littleton
# 3   HHv2fah0WapIL8Kche3AHQ                               wonderbound-denver-2
# 4   bTx_XCtBCxFDgGPBsQS3Jg                  blizzard-mountain-pinball-conifer
# ..                     ...                                                ...
# 95  91X19_GTZqowfc4C1Q9boA                               kidspace-westminster
# 96  lRW4C_Pv_oJw8yeTB-u7Ug                       turquoise-mesa-winery-denver
# 97  VE4fmiNpfZE5lnNdQOHN-g                             mhor-rc-raceway-aurora
# 98  8CkUCG4esRYiHxhszFD8dQ       gina-self-psychic-medium-and-healer-lakewood
# 99  Tx_KYhIxhQsVU1_xJWXbfw                       art-and-soul-gallery-boulder
#
# ...

# %%
import pandas as pd

# Extract data from "categories" column
categories_data = Denver_arts_df['categories'].apply(lambda x: [item['title'] for item in x])

# Add extracted data as a new column
Denver_arts_df['extracted_categories'] = categories_data

# Access and work with the updated DataFrame
Denver_arts_df
# Out:
#                          id  \
# 0    L1QXBchHoza6rEjqx-87RA
# 1    KwFEBgDC_cvVvAHJ_CKD7A
# 2    WhAD9eZndK3xbFpIPqeFYQ
# 3    HHv2fah0WapIL8Kche3AHQ
# 4    bTx_XCtBCxFDgGPBsQS3Jg
# ..                      ...
# 545  4ZcfFLIp9gVeR7aKRlvAtA
# 546  MfQAHfw_ePPG90q_JjO2zQ
# 547  4wzFrZxvGPE1mq44FcVl6g
# 548  Z75iDHOSSk6uGCfDDjiEjQ
# 549  SXLQPwzIuZ2xoeNF0xocjA
#
#                                                  alias  \
# 0                               medium-kimberly-denver
# 1    lea-marlene-actors-studio-and-the-namastage-th...
# 2                the-dance-art-media-studios-littleton
# 3                                 wonderbound-denver-2
# 4                    blizzard-mountain-pinball-conifer
# ..                                                 ...
# 545                    best-psychic-experiences-denver
# 546                      charley-takaya-psychic-denver
# 547        vca-southeast-area-animal-hospital-denver-3
# 548                  american-pride-skill-games-denver
# ...
